# %% [markdown]
# **How to identify position players on a given date?**
#
# **Problem:**
# <br>
# In daily fantasy baseball, a participant sets up their team against another player of their league. Some position players are stars and should play nearly all the time, but often a position is shared between other players on your roster. How do you choose which platooning player to start (especially if there is a limited sample size for the batter facing that pitcher)?
#
# **Strategy:**
# <br>
# - Focus on features of the batter (e.g. historical batting average) and pitcher (e.g. historical ERA, WHIP) to predict whether the batter would output a hit (or HR, single, double, etc.) in a given batter-pitcher at-bat matchup.
#
# - If you choose a given date (e.g. May 9), you know the starting pitcher a batter would face. Use data to build a model taht predicts how well a batter would do against the pitcher as a guide for a decision. (Lower priority: If the matchup for a particular batter-pitcher is small, find similar players to serve as a guide. Similar players can be found by using Erdos score.)
#
# - How do I know if my strategy is improved over other models? Look at which player one would choose from a simple player ranking.
#
# - Validation: Historical data
#
# This notebook was created within my "insight" virtual environment.

# %% [markdown]
# **Inputs and outputs**
#
# *Version 1:*
# - Input: Two players under consideration for one position and a date of interest (2019 season for historical validation).
# - Output: Player recommendation for that position with a predicted score.
#
# *Version 2:*
# - Input: A participant's player roster (e.g. 20 players)
# - Output: A recommended lineup.

# %% [markdown]
# Order of features of product to incorporate: (still to be determined)
#
# 0.  Try a simple model where each at-bat batter-pitcher matchup is simply its own row and selected features are done. (DONE)
# 1.	Roster’s “basic” baseball statistics from 2018 season? Or 50 games (including previous season) - (minimum viable product level) (DONE)
# 2.	Specific matchup against that pitcher - “basic” baseball statistics
# 3.	Roster’s statcast statistics from last 50 games (including previous season) (DONE)
# 4.	Limit to more recent performance (last 100 at-bats games - dataframe for model does 200 rows)
# 5.	Weather, park effects, team defense, night/day, lineup order
# 6. Use batted ball characteristics as a feature of player and pitcher (launch angle average, launch speed average)
# 7.	Use of player similarity (lower priority)
#
# Similar idea
# https://community.fangraphs.com/the-outcome-machine-predicting-at-bats-before-they-happen/
#
#
# EDA, do HR over time and by date for each player

# %% [markdown]
# **Product pitch**
#
# I'm creating a fantasy baseball application that suggests players on a given day. Fantasy baseball has over 11 million participants with the winners of leagues collecting entry fees and host platforms receiving a commission. The projected market for fantasy baseball in 2020 is over 8 billion dollars. A participant's success depends in part on daily player selection. For player selection, participants must rely on their own research or use a site's recommendation, which uses black-box algorithms behind pay walls. I'm developing an alternative algorithm to assist in player selection to save participants time and expose the important features in player performance prediction.

# %% [markdown]
# # Ideas
#
# - Will hit happen based on pitch count
# - Use last 100 at-bats from the date of interest.
# - Use Bayesian?
# - EDA  - plot someone's hits over game-dates as a time series
# - Look at the player's last 100 hits
#
# Other:
# - Use all info for at-bat and then do backwards selection.
#
# **Motivation: Learning analytics requries some skills I can develop here**

# %% [markdown]
# # Setup

# %%
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

from termcolor import colored

# Web/database stuff
import urllib.request
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup

# Multiprocessing/threading
import multiprocess
import threading
from threading import Thread

# %%
# Web/database stuff
# import urllib.request
# import xml.etree.ElementTree as ET
# from bs4 import BeautifulSoup
import sqlalchemy
import sqlalchemy_utils
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

# Multiprocessing/threading
import multiprocess
import threading   # included in base

# %%
# Stats
from scipy.stats import mannwhitneyu
from scipy.stats import ttest_ind

# %%
# ML
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
# Check versioning
print('numpy: ', np.__version__)
print('pandas: ', pd.__version__)
print('matplotlib: ', matplotlib.__version__)
print('seaborn: ', sns.__version__)
print('sklearn: ', sklearn.__version__)

print('psycopg2: ', psycopg2.__version__)
print('sqlalchemy: ', sqlalchemy.__version__)
print('sqlalchemy_utils: ', sqlalchemy_utils.__version__)
print('multiprocess: ', multiprocess.__version__)
# Out:
# numpy:  1.17.4
# pandas:  0.25.3
# matplotlib:  3.1.1
# seaborn:  0.9.0
# sklearn:  0.22
# psycopg2:  2.8.4 (dt dec pq3 ext lo64)
# sqlalchemy:  1.3.11
# sqlalchemy_utils:  0.36.1
# multiprocess:  0.70.9

# %%
# Code formatting with Jupyter black
# %load_ext nb_black
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
from pybaseball import pitching_stats
from pybaseball import batting_stats
from pybaseball import statcast_pitcher
from pybaseball import playerid_lookup
from pybaseball import statcast
from pybaseball import playerid_reverse_lookup

# %% [markdown]
# # Database info

# %%
# Define a database name
# Set your postgres username
dbname = "baseball"
username = "lacar"  # change this to your username

# %%
## 'engine' is a connection to a database
## Here, we're using postgres, but sqlalchemy can connect to other things too.
engine = create_engine("postgres://%s@localhost/%s" % (username, dbname))
print(engine.url)
# Out:
# postgres://lacar@localhost/baseball

# %% [markdown]
# **Statcast data to database**
# <br>
# (done already, see previous versions of notebooks)

# %%
## create a database (if it doesn't exist)
# if not database_exists(engine.url):
#     create_database(engine.url)
# print(database_exists(engine.url))

# %%
# This is done, but note it's out of order

# date_list = [
#     ("2019-03-20", "2019-09-29"),
#     ("2018-03-29", "2018-10-01"),
#     ("2017-04-02", "2017-10-01"),
# ]

# Above gave **2,174,906** pitch-by-pitch results in the database

#     ("2016-04-03", "2016-10-02"),   # didn't get
#     ("2015-04-05", "2015-10-04"),   # didn't get 


# for i, date_pair in enumerate(date_list):
#     if i < 1:
#         df_sc = statcast(date_pair[0], date_pair[1])
#         df_sc.to_sql("statcast", engine, if_exists="replace")
#         print(date_pair, "replace mode")
#     else:
#         df_sc = statcast(date_pair[0], date_pair[1])
#         df_sc.to_sql("statcast", engine, if_exists="append")
#         print(date_pair, "append mode")

# %%
# Working with PostgreSQL in Python
# Connect to make queries using psycopg2
con = None
con = psycopg2.connect(database=dbname, user=username)

# %% [markdown]
# See other notebook for more info

# %%
# Get player id
sql_query = """
SELECT * FROM player_id;
"""

df_player_id = pd.read_sql_query(sql_query, con)

# %%
# Batting stats

sql_query = """
SELECT * FROM batting_stats18_wpid;
"""

df_batting_stats_wpid = pd.read_sql_query(sql_query, con)

# %%
df_batting_stats_wpid.shape
# Out:
# (955, 300)

# %%
df_batting_stats_wpid.head()
# Out:
#    index  index_x  Season          Name     Team   Age      G     AB     PA  \
# 0      0       63  2018.0  Mookie Betts  Red Sox  25.0  136.0  520.0  614.0
# 1      1       67  2018.0    Mike Trout   Angels  26.0  140.0  471.0  608.0
# 2      2      153  2018.0  Jose Ramirez  Indians  25.0  157.0  578.0  698.0
# 3     68       38  2018.0   Ryder Jones   Giants  24.0    5.0    8.0    8.0
# 4      3      153  2018.0  Jose Ramirez  Indians  25.0  157.0  578.0  698.0
#
#        H  ...  first_name  index_y  name_last  name_first  key_mlbam  \
# 0  180.0  ...      mookie      166      betts      mookie     605141
# 1  147.0  ...        mike     1789      trout        mike     545361
# 2  156.0  ...        jose     1417    ramirez        jose     542432
# 3    3.0  ...       ryder      903      jones       ryder     624507
# 4  156.0  ...        jose     1418    ramirez        jose     608070
#
#    key_retro  key_bbref  key_fangraphs  mlb_played_first  mlb_played_last
# 0   bettm001  bettsmo01          13611            2014.0           2019.0
# 1   troum001  troutmi01          10155            2011.0           2019.0
# 2   ramij004  ramirjo02          10171            2014.0           2018.0
# 3   joner005  jonesry01          15982            2017.0           2018.0
# 4   ramij003  ramirjo01          13510            2013.0           2019.0
#
# [5 rows x 300 columns]

# %%
# Pitching stats

sql_query = """
SELECT * FROM pitching_stats_wpid;
"""

df_pitching_stats_wpid = pd.read_sql_query(sql_query, con)
# Limit to 2018, like with baseball stats
df_pitching_stats_wpid = df_pitching_stats_wpid[
    df_pitching_stats_wpid["Season"] == 2018
].copy()

# %%
df_pitching_stats_wpid.shape
# Out:
# (789, 310)

# %%
df_pitching_stats_wpid.head()
# Out:
#    index  Season           Name       Team   Age     W    L    ERA  WAR     G  \
# 0      0  2018.0   Jacob deGrom       Mets  30.0  10.0  9.0   1.70  9.0  32.0
# 1      1  2017.0     Chris Sale    Red Sox  28.0  17.0  8.0   2.90  7.6  32.0
# 2      2  2018.0   Max Scherzer  Nationals  33.0  18.0  7.0   2.53  7.5  33.0
# 3      3  2019.0    Gerrit Cole     Astros  28.0  20.0  5.0   2.50  7.4  33.0
# 4   1587  2018.0  Scott Kingery   Phillies  24.0   0.0  0.0  13.50  0.0   1.0
#
#    ...  first_name  last_name  name_last  name_first  key_mlbam  key_retro  \
# 0  ...       jacob     degrom     degrom       jacob   594798.0   degrj001
# 1  ...       chris       sale       sale       chris   519242.0   salec001
# 2  ...         max   scherzer   scherzer         max   453286.0   schem001
# 3  ...      gerrit       cole       cole      gerrit   543037.0   coleg001
# 4  ...       scott    kingery    kingery       scott   664068.0   kings001
#
#    key_bbref  key_fangraphs  mlb_played_first  mlb_played_last
# 0  degroja01        10954.0            2014.0           2019.0
# 1   salech01        10603.0            2010.0           2019.0
# 2  scherma01         3137.0            2008.0           2019.0
# 3   colege01        13125.0            2013.0           2019.0
# 4  kingesc01        17975.0            2018.0           2019.0
#
# [5 rows x 310 columns]

# %%
# Pitching stats

sql_query = """
SELECT * FROM pitching_stats_wpid;
"""

df_pitching_stats_wpid = pd.read_sql_query(sql_query, con)
# Limit to 2019, like with baseball stats
df_pitching_stats19_wpid = df_pitching_stats_wpid[
    df_pitching_stats_wpid["Season"] == 2019
].copy()

# %%
df_pitching_stats19_wpid.head()
# Out:
#     index  Season              Name       Team   Age     W     L   ERA  WAR  \
# 3       3  2019.0       Gerrit Cole     Astros  28.0  20.0   5.0  2.50  7.4
# 6       5  2019.0      Jacob deGrom       Mets  31.0  11.0   8.0  2.43  7.0
# 7       6  2019.0        Lance Lynn    Rangers  32.0  16.0  11.0  3.67  6.8
# 9       8  2019.0      Max Scherzer  Nationals  34.0  11.0   7.0  2.92  6.5
# 10      9  2019.0  Justin Verlander     Astros  36.0  21.0   6.0  2.58  6.4
#
#        G  ...  first_name  last_name  name_last  name_first  key_mlbam  \
# 3   33.0  ...      gerrit       cole       cole      gerrit   543037.0
# 6   32.0  ...       jacob     degrom     degrom       jacob   594798.0
# 7   33.0  ...       lance       lynn       lynn       lance   458681.0
# 9   27.0  ...         max   scherzer   scherzer         max   453286.0
# 10  34.0  ...      justin  verlander  verlander      justin   434378.0
#
#     key_retro  key_bbref  key_fangraphs  mlb_played_first  mlb_played_last
# 3    coleg001   colege01        13125.0            2013.0           2019.0
# 6    degrj001  degroja01        10954.0            2014.0           2019.0
# 7    lynnl001   lynnla01         2520.0            2011.0           2019.0
# 9    schem001  scherma01         3137.0            2008.0           2019.0
# 10   verlj001  verlaju01         8700.0            2005.0           2019.0
#
# [5 rows x 310 columns]

# %%
df_pitching_stats19_wpid.shape
# Out:
# (789, 310)

# %% [markdown]
# # Notes

# %% [markdown]
# ## Contingencies
#
# 1. What if player has day off? or no game is scheduled?
# 2. What if player or pitcher doesn't have minimum nback at-bats?
# 3. What if player doesn't have minimum nback at-bats against same or opposite handedness?

# %% [markdown]
# **Quora answer on number of plate appearances**
# https://www.quora.com/How-many-at-bats-does-the-average-MLB-player-go-through-per-year
#
# One direction to go with is how many PA wpild a player accumulate if theu were to play every day, and not rest. That would be around 725. Though that total is not really an average as few players exceed such a total each year.
#
# A second number would be how many plate appearances bases on normal rest during a season if a player never was injured, about 145-150 games for position players other then the catcher and 110 to 115 for catchers. Those totals would be around 650 and 450 respectively.
#
# Yet another way to answer this would be the number of PA by all position players on a roster that were supposed to be starters, but may receive less playing time due to injury or a team developing, trading for or discovering a better player. That would probably be closer to 400.
#
# You could also thing about all position players on a team including bench players, if we include them our total now is closer to 200-250.
#
# Yet another way to look at this is to include all players on the roster including pitcher who may notbat intentionally. Include them and tour total is closer to 100-120.

# %% [markdown]
# ## Other ideas

# %% [markdown]
# - Look at probabilities, instead of looking for 1 (done - not strong)
# - Aggregate per game (potentially something there - not sure)
# - Look at Ty France
# - Add in pitcher info
# - See what pitches they're hitting, then see how that matches with pitchers
# - Remember that ultimately, we want to see that we're picking the right player - someone who has a higher probability overall will be better choice
#
#
# **Motivation: Learning analytics requries some skills I can develop here**

# %% [markdown]
# ## Questions to ask
#
# - Am I inputting handedness correctly? How to input values if they're transformed in the model? (L -1.41421356, R 0.70710678)
# - Add pitcher specific ID as a factor?

# %% [markdown]
# ## Things to fix
#
# - Why is dataframe model going to <200 - cause of the day of separation.
# - Standardize train-test before split

# %% [markdown]
# # Valid for higher probability of predicting 1 identifies better player?
#
# - Do models for each player and look at probabilities of outputting 1
#
# - try joining DFs?
# - weighting?

# %% [markdown]
# ## Input both batters and date
#
# SQL query gets everything **before** the date. The validation and checking gets data on the day of.

# %%
# FUNCTION FOR GETTING STATCAST DATA

# Enter key_mlbam (Mike Trout, ESPN rank 1)
# pid_of_interest1 = 545361
# Enter key_mlbam (Jesse Winker, ESPN rank 280)
# pid_of_interest2 = 608385

# Enter key_mlbam (Mookie Betts, ESPN rank 2?)
# pid_of_interest1 = 605141

# Reynolds (668804, Bryan Reynolds (PIT))
pid_of_interest1 = 668804

# Enter key_mlbam (Leury Garcia, ESPN rank 300)
pid_of_interest2 = 544725

date_of_interest = "'2019-09-04'"  # Note internal single quotes

no_total_ab_events = 1000

# Note: SQL union of two different searches doesn't preserve order
# It's easier to make a dataframe for each player
# https://stackoverflow.com/questions/21181664/sql-server-union-but-keep-order/21181766
# ---------------------------------------------------

# %%
def get_sc_batter_df(player_id, date, n_ab_events):
    sql_query = (
        """
    (SELECT * FROM statcast 
    JOIN player_id ON statcast.batter=player_id.key_mlbam 
    WHERE statcast.batter= 
    """
        + str(player_id)
        + """
    AND statcast.game_date<=
    """
        + str(date)
        + """ 
    AND statcast.events IS NOT NULL 
    ORDER BY statcast.game_date DESC, statcast.inning DESC, statcast.outs_when_up DESC 
    LIMIT
    """
        + str(n_ab_events)
        + ");"
    )

    # print(sql_query)

    df_sc_events = pd.read_sql_query(sql_query, con)
    df_sc_events.drop(["level_0", "index"], axis=1, inplace=True)  # Clean up df

    return df_sc_events

# %%
df_sc_events_b1 = get_sc_batter_df(pid_of_interest1, date_of_interest, 1000)
df_sc_events_b2 = get_sc_batter_df(pid_of_interest2, date_of_interest, 1000)

# %%
df_sc_events_b1.head(10)
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SL 2019-09-04           85.8        -1.9598         5.8343
# 1         FF 2019-09-04           95.7         3.0704         5.9168
# 2         CU 2019-09-04           72.4        -2.5206         4.9159
# 3         FF 2019-09-04           89.4        -2.3685         4.9172
# 4         FT 2019-09-04           90.4        -2.5811         4.8695
# 5         FT 2019-09-03           97.6        -2.1865         5.7700
# 6         FF 2019-09-03           95.0         1.9998         5.8492
# 7         FF 2019-09-03           95.8        -2.2007         5.8480
# 8         FF 2019-09-03           96.5        -2.4874         5.8048
# 9         FF 2019-09-03           96.9        -2.4392         6.0714
#
#        player_name    batter   pitcher       events           description  \
# 0       Jose Urena  668804.0  570632.0       single   hit_into_play_score
# 1      Adam Conley  668804.0  543045.0    strikeout       swinging_strike
# 2    Robert Dugger  668804.0  667498.0    field_out         hit_into_play
# 3    Robert Dugger  668804.0  667498.0       double  hit_into_play_no_out
# 4    Robert Dugger  668804.0  667498.0  field_error  hit_into_play_no_out
# 5       Jose Urena  668804.0  570632.0    field_out         hit_into_play
# 6    Jarlin Garcia  668804.0  606424.0    strikeout         called_strike
# 7  Sandy Alcantara  668804.0  645261.0    field_out         hit_into_play
# 8  Sandy Alcantara  668804.0  645261.0    field_out         hit_into_play
# 9  Sandy Alcantara  668804.0  645261.0    strikeout         called_strike
#
#    ... if_fielding_alignment of_fielding_alignment name_last name_first  \
# 0  ...              Standard              Standard  reynolds      bryan
# 1  ...              Standard              Standard  reynolds      bryan
# 2  ...             Strategic              Standard  reynolds      bryan
# 3  ...              Standard              Standard  reynolds      bryan
# 4  ...             Strategic              Standard  reynolds      bryan
# 5  ...              Standard             Strategic  reynolds      bryan
# 6  ...             Strategic              Standard  reynolds      bryan
# 7  ...             Strategic              Standard  reynolds      bryan
# 8  ...         Infield shift              Standard  reynolds      bryan
# 9  ...         Infield shift              Standard  reynolds      bryan
#
#    key_mlbam key_retro  key_bbref key_fangraphs mlb_played_first  \
# 0     668804  reynb001  reynobr01         19326           2019.0
# 1     668804  reynb001  reynobr01         19326           2019.0
# 2     668804  reynb001  reynobr01         19326           2019.0
# 3     668804  reynb001  reynobr01         19326           2019.0
# 4     668804  reynb001  reynobr01         19326           2019.0
# 5     668804  reynb001  reynobr01         19326           2019.0
# 6     668804  reynb001  reynobr01         19326           2019.0
# 7     668804  reynb001  reynobr01         19326           2019.0
# 8     668804  reynb001  reynobr01         19326           2019.0
# 9     668804  reynb001  reynobr01         19326           2019.0
#
#   mlb_played_last
# 0          2019.0
# 1          2019.0
# 2          2019.0
# 3          2019.0
# 4          2019.0
# 5          2019.0
# 6          2019.0
# 7          2019.0
# 8          2019.0
# 9          2019.0
#
# [10 rows x 97 columns]

# %%
df_sc_events_b2.head()
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF 2019-09-04           91.9         2.8175         6.0013
# 1         KC 2019-09-04           83.2        -1.3917         5.7539
# 2         KC 2019-09-04           82.5        -1.5268         5.7392
# 3         KC 2019-09-04           83.7        -1.4992         5.8262
# 4         CH 2019-09-04           87.6        -1.6473         5.7523
#
#     player_name    batter   pitcher     events              description  ...  \
# 0     Brad Hand  544725.0  543272.0     single     hit_into_play_no_out  ...
# 1  Shane Bieber  544725.0  669456.0  strikeout  swinging_strike_blocked  ...
# 2  Shane Bieber  544725.0  669456.0  force_out            hit_into_play  ...
# 3  Shane Bieber  544725.0  669456.0  strikeout  swinging_strike_blocked  ...
# 4  Shane Bieber  544725.0  669456.0     single     hit_into_play_no_out  ...
#
#   if_fielding_alignment of_fielding_alignment name_last name_first  key_mlbam  \
# 0              Standard              Standard    garcia      leury     544725
# 1              Standard              Standard    garcia      leury     544725
# 2              Standard              Standard    garcia      leury     544725
# 3              Standard              Standard    garcia      leury     544725
# 4              Standard              Standard    garcia      leury     544725
#
#   key_retro  key_bbref key_fangraphs mlb_played_first mlb_played_last
# 0  garcl004  garcile02          5913           2013.0          2019.0
# 1  garcl004  garcile02          5913           2013.0          2019.0
# 2  garcl004  garcile02          5913           2013.0          2019.0
# 3  garcl004  garcile02          5913           2013.0          2019.0
# 4  garcl004  garcile02          5913           2013.0          2019.0
#
# [5 rows x 97 columns]

# %%
def plot_events_over_time(sc_events_df, ev_list):
    df_temp = sc_events_df.copy()
    df_temp = df_temp[df_temp["game_date"].between("2019-04-01", "2019-09-09")]
    df_temp.reset_index(inplace=True)

    # Encode on-base events, including walks
    df_temp["event_code"] = 0
    df_temp.loc[df_temp["events"].isin(ev_list), "event_code"] = 1

    f, ax1 = plt.subplots()
    ax1.scatter(
        df_temp["game_date"],
        df_temp["event_code"] + np.random.normal(0, 0.01, len(df_temp)),
        facecolors="none",
        edgecolors="black",
    )

    # figure out date formatting
    # ax1.xticks(rotation=45)
    #     xlocs, xlabels = ax1.xticks()
    #     ax1.set_xticklabels(xlabels, rotation=45)  # to Rotate Xticks Label Text

    return df_temp[["events", "event_code"]].head(10)

# %%
event_list = ["walk", "single", "double", "triple", "home_run"]
plot_events_over_time(df_sc_events_b1, event_list)
# Out:
#         events  event_code
# 0       single           1
# 1    strikeout           0
# 2    field_out           0
# 3       double           1
# 4  field_error           0
# 5    field_out           0
# 6    strikeout           0
# 7    field_out           0
# 8    field_out           0
# 9    strikeout           0

# %%
event_list = ["walk", "single", "double", "triple", "home_run"]
plot_events_over_time(df_sc_events_b2, event_list)
# Out:
#       events  event_code
# 0     single           1
# 1  strikeout           0
# 2  force_out           0
# 3  strikeout           0
# 4     single           1
# 5  strikeout           0
# 6     single           1
# 7  field_out           0
# 8  strikeout           0
# 9  strikeout           0

# %%
# def get_model_prob(df4model)

# Output probabilities of

# %%
def get_df4model(df, n_back_PA, m_size):
    """
    Function for getting summarized DF
    """
    # sample values -----------
    # n_back_PA = 100
    # df = df_sc_events.copy()
    # pid = pid_of_interest1
    # m_size = 200
    # -------------------------

    # Reset index so that code below works
    df.reset_index(inplace=True)

    # Encode on-base events, including walks
    ob_list = ["walk", "single", "double", "triple", "home_run"]
    df["event_code"] = 0
    df.loc[df["events"].isin(ob_list), "event_code"] = 1

    # Sum of on-base events - critical that order matters! (should be addressed above)
    # rolling was close, but needed to tweak
    df["num_events_sum_nback"] = (
        df["event_code"].iloc[::-1].rolling(n_back_PA).sum().iloc[::-1]
    )

    # Percent of on-base events (overall)
    df["prop_events_nback"] = df["num_events_sum_nback"] / n_back_PA

    # Percent of on-base events against handedness of pitcher
    for i in df.index:
        p_throws = df["p_throws"].iloc[i]  # Get handedness of pitcher
        df_pt_throw = df[df["p_throws"] == p_throws]
        n_pt_events = df_pt_throw["event_code"].iloc[i : i + n_back_PA].sum()
        df.loc[i, "num_events_sum_nback_pt"] = n_pt_events
        df.loc[i, "prop_events_sum_nback_pt"] = n_pt_events / n_back_PA

    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
    ]

    df_4model = df[col4model].copy()
    df_4model_overall = df_4model.loc[:m_size]

    df_meta_w_model_overall = pd.merge(
        df[["game_date", "inning", "outs_when_up", "events", "player_name", "pitcher"]],
        df_4model_overall,
        left_index=True,
        right_index=True,
    )

    return df_meta_w_model_overall

# %%
df_sc_events_b1.head()
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SL 2019-09-04           85.8        -1.9598         5.8343
# 1         FF 2019-09-04           95.7         3.0704         5.9168
# 2         CU 2019-09-04           72.4        -2.5206         4.9159
# 3         FF 2019-09-04           89.4        -2.3685         4.9172
# 4         FT 2019-09-04           90.4        -2.5811         4.8695
#
#      player_name    batter   pitcher       events           description  ...  \
# 0     Jose Urena  668804.0  570632.0       single   hit_into_play_score  ...
# 1    Adam Conley  668804.0  543045.0    strikeout       swinging_strike  ...
# 2  Robert Dugger  668804.0  667498.0    field_out         hit_into_play  ...
# 3  Robert Dugger  668804.0  667498.0       double  hit_into_play_no_out  ...
# 4  Robert Dugger  668804.0  667498.0  field_error  hit_into_play_no_out  ...
#
#   if_fielding_alignment of_fielding_alignment name_last name_first  key_mlbam  \
# 0              Standard              Standard  reynolds      bryan     668804
# 1              Standard              Standard  reynolds      bryan     668804
# 2             Strategic              Standard  reynolds      bryan     668804
# 3              Standard              Standard  reynolds      bryan     668804
# 4             Strategic              Standard  reynolds      bryan     668804
#
#   key_retro  key_bbref key_fangraphs mlb_played_first mlb_played_last
# 0  reynb001  reynobr01         19326           2019.0          2019.0
# 1  reynb001  reynobr01         19326           2019.0          2019.0
# 2  reynb001  reynobr01         19326           2019.0          2019.0
# 3  reynb001  reynobr01         19326           2019.0          2019.0
# 4  reynb001  reynobr01         19326           2019.0          2019.0
#
# [5 rows x 97 columns]

# %%
df4model_b1 = get_df4model(df=df_sc_events_b1.copy(), n_back_PA=100, m_size=200)

# %%
df4model_b1.head()
# Out:
#    game_date  inning  outs_when_up       events    player_name   pitcher  \
# 0 2019-09-04     9.0           0.0       single     Jose Urena  570632.0
# 1 2019-09-04     7.0           0.0    strikeout    Adam Conley  543045.0
# 2 2019-09-04     4.0           2.0    field_out  Robert Dugger  667498.0
# 3 2019-09-04     3.0           0.0       double  Robert Dugger  667498.0
# 4 2019-09-04     1.0           1.0  field_error  Robert Dugger  667498.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt
# 0           1        R               0.36                      0.42
# 1           0        L               0.35                      0.26
# 2           0        R               0.35                      0.42
# 3           1        R               0.35                      0.41
# 4           0        R               0.35                      0.41

# %%
print(df4model_b1.head())
print(df4model_b1.shape)
# Out:
#    game_date  inning  outs_when_up       events    player_name   pitcher  \
# 0 2019-09-04     9.0           0.0       single     Jose Urena  570632.0
# 1 2019-09-04     7.0           0.0    strikeout    Adam Conley  543045.0
# 2 2019-09-04     4.0           2.0    field_out  Robert Dugger  667498.0
# 3 2019-09-04     3.0           0.0       double  Robert Dugger  667498.0
# 4 2019-09-04     1.0           1.0  field_error  Robert Dugger  667498.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt
# 0           1        R               0.36                      0.42
# 1           0        L               0.35                      0.26
# 2           0        R               0.35                      0.42
# 3           1        R               0.35                      0.41
# 4           0        R               0.35                      0.41
# (201, 10)

# %%
df4model_b2 = get_df4model(df=df_sc_events_b2.copy(), n_back_PA=100, m_size=200)

# %%
print(df4model_b2.head())
print(df4model_b2.shape)
# Out:
#    game_date  inning  outs_when_up     events   player_name   pitcher  \
# 0 2019-09-04     9.0           1.0     single     Brad Hand  543272.0
# 1 2019-09-04     7.0           2.0  strikeout  Shane Bieber  669456.0
# 2 2019-09-04     5.0           0.0  force_out  Shane Bieber  669456.0
# 3 2019-09-04     2.0           2.0  strikeout  Shane Bieber  669456.0
# 4 2019-09-04     1.0           0.0     single  Shane Bieber  669456.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt
# 0           1        L               0.23                      0.29
# 1           0        R               0.22                      0.24
# 2           0        R               0.22                      0.24
# 3           0        R               0.23                      0.25
# 4           1        R               0.23                      0.24
# (201, 10)

# %%
print(pid_of_interest1, pid_of_interest2)
# Out:
# 668804 544725

# %% [markdown]
# ## EDA

# %%
# Lineplot of each player

# Sanity checking that df is in order
f, (ax1) = plt.subplots(1, 1, figsize=(12, 6))
ax1.plot(df4model_b1["game_date"], df4model_b1["prop_events_nback"], c='red', label='Player A (M. Trout)')
ax1.set_xlabel("game_date")

ax1.plot(df4model_b2["game_date"], df4model_b2["prop_events_nback"], c='black', label='Player B (L. Garcia)')
ax1.set_xlabel("game_date")
ax1.set_ylabel('event rate')
# Out:
# Text(0, 0.5, 'event rate')

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 6), sharex=True)
df4model_b1["prop_events_nback"].hist(ax=ax1)
ax1.set_xlim([0.15, 0.5])
ax1.set_title("Player A")

df4model_b2["prop_events_nback"].hist(ax=ax2)
ax2.set_xlim([0.15, 0.5])
ax2.set_title("Player B")
ax2.set_xlabel("proportion of event")
# Out:
# Text(0.5, 0, 'proportion of event')

# %%
print(
    round(df4model_b1["prop_events_nback"].mean(), 3),
    round(df4model_b2["prop_events_nback"].mean(), 3),
)
# Out:
# 0.373 0.279

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.scatter(
    df4model_b1["prop_events_nback"],
    df4model_b1["event_code"] + np.random.normal(0, 0.025, len(df4model_b1)),
    facecolors="none",
    edgecolors="black",
)
ax1.set_title("Player 1 (overall)")

ax2.scatter(
    df4model_b2["prop_events_nback"],
    df4model_b2["event_code"] + np.random.normal(0, 0.025, len(df4model_b2)),
    facecolors="none",
    edgecolors="black",
)
ax2.set_title("Player 2 (overall)")
# Out:
# Text(0.5, 1.0, 'Player 2 (overall)')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
c_hand_list = ["blue", "red"]

for i, hand in enumerate(["L", "R"]):
    df4model_b1_hand = df4model_b1[df4model_b1["p_throws"] == hand].copy()
    df4model_b2_hand = df4model_b2[df4model_b2["p_throws"] == hand].copy()

    ax1.scatter(
        df4model_b1_hand["prop_events_nback"],
        df4model_b1_hand["event_code"]
        + +np.random.normal(0, 0.05, len(df4model_b1_hand)),
        facecolors="none",
        edgecolors=c_hand_list[i],
    )
    ax1.set_title("Player 1 (by pitcher hand)")

    ax2.scatter(
        df4model_b2_hand["prop_events_nback"],
        df4model_b2_hand["event_code"]
        + np.random.normal(0, 0.05, len(df4model_b2_hand)),
        facecolors="none",
        edgecolors=c_hand_list[i],
    )
    ax2.set_title("Player 2 (by pitcher hand)")

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4), sharey=True)

sns.boxplot(
    x="p_throws",
    hue="event_code",
    y="prop_events_nback",
    data=df4model_b1,
    palette=["w", "teal"],
    order=["L", "R"],
    hue_order=[0, 1],
    ax=ax1,
)
ax1.set_title("Player 1")
ax1.get_legend().remove()

sns.boxplot(
    x="p_throws",
    hue="event_code",
    y="prop_events_nback",
    data=df4model_b2,
    palette=["w", "teal"],
    order=["L", "R"],
    hue_order=[0, 1],
    ax=ax2,
)
ax2.set_title("Player 2")
ax2.get_legend().remove()

# %%
groupA1_vals = df4model_b1.loc[(df4model_b1["p_throws"] == 'L') & (df4model_b1["event_code"] == 0), "prop_events_nback"]
groupA2_vals = df4model_b1.loc[(df4model_b1["p_throws"] == 'L') & (df4model_b1["event_code"] == 1), "prop_events_nback"]

mw_p_A = mannwhitneyu(groupA1_vals, groupA2_vals)[1]
# Welch's test (does not assume variances are equal)
ttest_p_A = ttest_ind(groupA1_vals, groupA2_vals, equal_var=False)[1]
print("Player A vs. LHP, MW: ", mw_p_A, "Player A vs. LHP, t-test: ", ttest_p_A)

groupB1_vals = df4model_b1.loc[(df4model_b1["p_throws"] == 'R') & (df4model_b1["event_code"] == 0), "prop_events_nback"]
groupB2_vals = df4model_b1.loc[(df4model_b1["p_throws"] == 'R') & (df4model_b1["event_code"] == 1), "prop_events_nback"]

mw_p_B = mannwhitneyu(groupB1_vals, groupB2_vals)[1]
# Welch's test (does not assume variances are equal)
ttest_p_B = ttest_ind(groupB1_vals, groupB2_vals, equal_var=False)[1]
print("Player A vs. RHP, MW: ", mw_p_B, "Player A vs. RHP, t-test: ", ttest_p_B)
# Out:
# Player A vs. LHP, MW:  0.1570198037267942 Player A vs. LHP, t-test:  0.43794222978048614
# Player A vs. RHP, MW:  0.3902744111238652 Player A vs. RHP, t-test:  0.791958996767719

# %%
groupA1_vals = df4model_b2.loc[(df4model_b2["p_throws"] == 'L') & (df4model_b2["event_code"] == 0), "prop_events_nback"]
groupA2_vals = df4model_b2.loc[(df4model_b2["p_throws"] == 'L') & (df4model_b2["event_code"] == 1), "prop_events_nback"]

mw_p_A = mannwhitneyu(groupA1_vals, groupA2_vals)[1]
# Welch's test (does not assume variances are equal)
ttest_p_A = ttest_ind(groupA1_vals, groupA2_vals, equal_var=False)[1]
print("Player B vs. LHP, MW: ", mw_p_A, "Player B vs. LHP, t-test: ", ttest_p_A)

groupb2_vals = df4model_b2.loc[(df4model_b2["p_throws"] == 'R') & (df4model_b2["event_code"] == 0), "prop_events_nback"]
groupB2_vals = df4model_b2.loc[(df4model_b2["p_throws"] == 'R') & (df4model_b2["event_code"] == 1), "prop_events_nback"]

mw_p_B = mannwhitneyu(groupb2_vals, groupB2_vals)[1]
# Welch's test (does not assume variances are equal)
ttest_p_B = ttest_ind(groupb2_vals, groupB2_vals, equal_var=False)[1]
print("Player B vs. RHP, MW: ", mw_p_B, "Player B vs. RHP, t-test: ", ttest_p_B)
# Out:
# Player B vs. LHP, MW:  0.08498558771377174 Player B vs. LHP, t-test:  0.1949851865051548
# Player B vs. RHP, MW:  0.17369298762047164 Player B vs. RHP, t-test:  0.522985948121288

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# ### Separate "day of" from "pre-date" data

# %%
df4model_dayof_b1 = df4model_b1[df4model_b1["game_date"] == date_of_interest].copy()
df4model_dayof_b1
# Out:
#    game_date  inning  outs_when_up       events    player_name   pitcher  \
# 0 2019-09-04     9.0           0.0       single     Jose Urena  570632.0
# 1 2019-09-04     7.0           0.0    strikeout    Adam Conley  543045.0
# 2 2019-09-04     4.0           2.0    field_out  Robert Dugger  667498.0
# 3 2019-09-04     3.0           0.0       double  Robert Dugger  667498.0
# 4 2019-09-04     1.0           1.0  field_error  Robert Dugger  667498.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt
# 0           1        R               0.36                      0.42
# 1           0        L               0.35                      0.26
# 2           0        R               0.35                      0.42
# 3           1        R               0.35                      0.41
# 4           0        R               0.35                      0.41

# %%
df4model_dayof_b2 = df4model_b2[df4model_b2["game_date"] == date_of_interest].copy()
df4model_dayof_b2
# Out:
#    game_date  inning  outs_when_up     events   player_name   pitcher  \
# 0 2019-09-04     9.0           1.0     single     Brad Hand  543272.0
# 1 2019-09-04     7.0           2.0  strikeout  Shane Bieber  669456.0
# 2 2019-09-04     5.0           0.0  force_out  Shane Bieber  669456.0
# 3 2019-09-04     2.0           2.0  strikeout  Shane Bieber  669456.0
# 4 2019-09-04     1.0           0.0     single  Shane Bieber  669456.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt
# 0           1        L               0.23                      0.29
# 1           0        R               0.22                      0.24
# 2           0        R               0.22                      0.24
# 3           0        R               0.23                      0.25
# 4           1        R               0.23                      0.24

# %%
col4model = ["event_code", "p_throws", "prop_events_nback", "prop_events_sum_nback_pt"]
df4model_b1_lim = df4model_b1.loc[
    df4model_b1["game_date"] < date_of_interest, col4model
].copy()

df4model_b2_lim = df4model_b2.loc[
    df4model_b2["game_date"] < date_of_interest, col4model
].copy()


# df4model_b1_lim = df4model_b1[col4model].copy()
# df4model_b2_lim = df4model_b2[col4model].copy()

# %%
pd.concat([df4model_b1_lim.head(), df4model_b2_lim.head()], axis=1)
# Out:
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  \
# 5           0        R               0.36                      0.41
# 6           0        L               0.37                      0.29
# 7           0        R               0.38                      0.41
# 8           0        R               0.38                      0.41
# 9           0        R               0.39                      0.42
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt
# 5           0        R               0.22                      0.24
# 6           1        R               0.22                      0.23
# 7           0        R               0.22                      0.24
# 8           0        R               0.22                      0.24
# 9           0        R               0.23                      0.24

# %%
# FUNCTION TO REPLACE CATEGORICAL INPUT
df4model_b1_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
df4model_b2_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

# %%
# f, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(12, 6))

# df4model_b1_lim["prop_events_nback"].hist(ax=ax1)
# ax1.set_title("overall events, player 1")

# df_temp = df4model_b1_lim[df4model_b1_lim["p_throws"] == 0]
# df_temp["prop_events_nback"].hist(ax=ax2)
# ax2.set_title("events against left-handers, player 1")

# df_temp = df4model_b1_lim[df4model_b1_lim["p_throws"] == 1]
# df_temp["prop_events_nback"].hist(ax=ax3)
# ax3.set_title("events against right-handers, player 1")

# df4model_p2["prop_events_nback"].hist(ax=ax4)
# ax4.set_title("overall events, player 2")

# df_temp = df4model_p2[df4model_p2["p_throws"] == 0]
# df_temp["prop_events_nback"].hist(ax=ax5)
# ax5.set_title("events against left-handers, player 2")

# df_temp = df4model_p2[df4model_p2["p_throws"] == 1]
# df_temp["prop_events_nback"].hist(ax=ax6)
# ax6.set_title("events against right-handers, player 2")

# plt.tight_layout()

# %%
def get_split_data(df4model, testsize):
    y = df4model["event_code"]
    X = df4model.iloc[:, 1::]

    # Scale features based on training data
    std_scale = StandardScaler()
    X_scale = std_scale.fit_transform(X)

    X_train_scale, X_test_scale, y_train, y_test = train_test_split(
        X_scale, y, test_size=testsize, random_state=19
    )

    return X_train_scale, X_test_scale, y_train, y_test

# %%
df4model_b1_lim.shape
# Out:
# (196, 4)

# %%
df4model_b2_lim.shape
# Out:
# (196, 4)

# %%
X_train_scale_b1, X_test_scale_b1, y_train_b1, y_test_b1 = get_split_data(
    df4model_b1_lim, 0.4
)
X_train_scale_b2, X_test_scale_b2, y_train_b2, y_test_b2 = get_split_data(
    df4model_b2_lim, 0.4
)

# %%
print(X_train_scale_b1.shape, X_test_scale_b1.shape, y_train_b1.shape, y_test_b1.shape)
print(X_train_scale_b2.shape, X_test_scale_b2.shape, y_train_b2.shape, y_test_b2.shape)
# Out:
# (117, 3) (79, 3) (117,) (79,)
# (117, 3) (79, 3) (117,) (79,)

# %%
def run_logreg_model(X_train_scale_set, y_train_set, X_test_scale_set, y_test_set):

    log_reg = LogisticRegression()
    log_reg.fit(X_train_scale_set, y_train_set)

    y_pred = log_reg.predict(X_test_scale_set)
    y_predprob = log_reg.predict_proba(X_test_scale_set)[:, 1]
    df_eval = pd.DataFrame({"test": y_test_set, "pred": y_pred, "predprob": y_predprob})

    return log_reg, df_eval

# %%
# Run models
log_reg_b1, df_eval_b1 = run_logreg_model(
    X_train_scale_b1, y_train_b1, X_test_scale_b1, y_test_b1
)

log_reg_b2, df_eval_b2 = run_logreg_model(
    X_train_scale_b2, y_train_b2, X_test_scale_b2, y_test_b2
)

# %%
pd.concat([df_eval_b1.reset_index().head(), df_eval_b2.reset_index().head()], axis=1)
# Out:
#    index  test  pred  predprob  index  test  pred  predprob
# 0     36     1     0  0.265110     36     0     0  0.234481
# 1    155     1     0  0.464191    155     0     0  0.198830
# 2    149     1     0  0.445860    149     1     0  0.227086
# 3     42     1     0  0.230213     42     0     0  0.272737
# 4    141     0     0  0.099927    141     0     0  0.250035

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.scatter(
    df_eval_b1["predprob"],
    df_eval_b1["test"] + np.random.normal(0, 0.025, len(df_eval_b1)),
    facecolors="none",
    edgecolors="black",
)

ax2.scatter(
    df_eval_b2["predprob"],
    df_eval_b2["test"] + np.random.normal(0, 0.025, len(df_eval_b2)),
    facecolors="none",
    edgecolors="black",
)

# %%
print("Player 1 coefficients: ", log_reg_b1.coef_)
print("Player 2 coefficients: ", log_reg_b2.coef_)
# Out:
# Player 1 coefficients:  [[0.14236542 0.00191787 0.58597128]]
# Player 2 coefficients:  [[-0.03456852  0.34511474 -0.40894548]]

# %%
# INPUT HANDEDNESS CORRECTLY - it's transformed

# L -1.41421356
# R 0.70710678

# %% [markdown]
# ## Output for new case - check this

# %%
# "Day of" data was extracted above

# col4model = ["event_code", "p_throws", "prop_events_nback", "prop_events_sum_nback_pt"]
# This variable was already assigned above - just put here as a reminder

# Get up to last 3 at-bats for the input
df4model_dayof_4model_b1 = df4model_dayof_b1[col4model].iloc[-3:, :].copy()
df4model_dayof_4model_b2 = df4model_dayof_b2[col4model].iloc[-3:, :].copy()

# replace categorical input
df4model_dayof_4model_b1["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
df4model_dayof_4model_b2["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

# %% [markdown]
# ### Predict and compare to real performance

# %%
df4model_dayof_4model_b1
# Out:
#    event_code  p_throws  prop_events_nback  prop_events_sum_nback_pt
# 2           0         1               0.35                      0.42
# 3           1         1               0.35                      0.41
# 4           0         1               0.35                      0.41

# %%
df4model_dayof_4model_b2
# Out:
#    event_code  p_throws  prop_events_nback  prop_events_sum_nback_pt
# 2           0         1               0.22                      0.24
# 3           0         1               0.23                      0.25
# 4           1         1               0.23                      0.24

# %%
def return_series_of_player_prediction(
    df4model_dayof_b1, df4model_dayof_b2, log_reg_b1, log_reg_b2
):
    s_new_case = pd.Series()

    df4model_dayof_b1 = df4model_dayof_4model_b1.copy()
    df4model_dayof_b2 = df4model_dayof_4model_b2.copy()

    # actual performance
    s_new_case["actual_performance_batterA"] = df4model_dayof_b1.reset_index()[
        "event_code"
    ].mean()
    s_new_case["actual_performance_batterB"] = df4model_dayof_b2.reset_index()[
        "event_code"
    ].mean()

    # ADD VARIANCE - TBD
    s_new_case["pred_var_batterA"] = None
    s_new_case["pred_var_batterB"] = None

    # vs actual pitcher
    s_new_case["pred_vs_gamepitcher_batterA"] = log_reg_b1.predict_proba(
        df4model_dayof_b1.iloc[:, 1:]
    )[:, 1].mean()

    s_new_case["pred_vs_gamepitcher_batterB"] = log_reg_b2.predict_proba(
        df4model_dayof_b2.iloc[:, 1:]
    )[:, 1].mean()

    # Prediction
    if (
        s_new_case["pred_vs_gamepitcher_batterA"]
        > s_new_case["pred_vs_gamepitcher_batterB"]
    ):
        predict_for_day = "predict_A"
    elif (
        s_new_case["pred_vs_gamepitcher_batterA"]
        == s_new_case["pred_vs_gamepitcher_batterB"]
    ):
        predict_for_day = "even"
    else:
        predict_for_day = "predict_B"

    # Actual case
    if (
        s_new_case["actual_performance_batterA"]
        > s_new_case["actual_performance_batterB"]
    ):
        actual_for_day = "actual_A"

    elif (
        s_new_case["actual_performance_batterA"]
        == s_new_case["actual_performance_batterB"]
    ):
        actual_for_day = "even"
    else:
        actual_for_day = "actual_B"

    validation_entries = (
        date_of_interest,
        pid_of_interest1,
        pid_of_interest2,
        predict_for_day,
        actual_for_day,
    )

    return s_new_case, validation_entries

# %%
# May not need
# def return_df_of_player_prediction(df4model_dayof_b1, df4model_dayof_b2):

#     df_new_case = pd.DataFrame()

#     # actual performance
#     df_new_case["actual_performance_batterA"] = df4model_dayof_b1.reset_index()[
#         "event_code"
#     ]
#     df_new_case["actual_performance_batterB"] = df4model_dayof_b2.reset_index()[
#         "event_code"
#     ]

#     # ADD VARIANCE - TBD
#     df_new_case["pred_var_batterA"] = None
#     df_new_case["pred_var_batterB"] = None

#     # vs actual pitcher
#     df_new_case["pred_vs_gamepitcher_batterA"] = log_reg_b1.predict_proba(
#         df4model_dayof_b1.iloc[:, 1:]
#     )[:, 1]

#     df_new_case["pred_vs_gamepitcher_batterB"] = log_reg_b2.predict_proba(
#         df4model_dayof_b2.iloc[:, 1:]
#     )[:, 1]

#     #     # vs LHP pitcher - player A
#     #     df_temp_left = df4model_dayof_b1.iloc[:, 1:]
#     #     df_temp_left.loc[:, "p_throws"] = [0] * len(df4model_dayof_4model_b1)
#     #     df_new_case["pred_vs_LHP_batterA"] = log_reg_b1.predict_proba(df_temp_left)[:, 1]

#     #     # vs LHP pitcher - player B
#     #     df_temp_left = df4model_dayof_b2.iloc[:, 1:]
#     #     df_temp_left.loc[:, "p_throws"] = [0] * len(df4model_dayof_b2)
#     #     df_new_case["pred_vs_LHP_batterB"] = log_reg_b2.predict_proba(df_temp_left)[:, 1]

#     #     # vs RHP pitcher - player A
#     #     df_temp_left = df4model_dayof_b1.iloc[:, 1:]
#     #     df_temp_left.loc[:, "p_throws"] = [1] * len(df4model_dayof_b1)
#     #     df_new_case["pred_vs_RHP_batterA"] = log_reg_b1.predict_proba(df_temp_left)[:, 1]

#     #     # vs RHP pitcher - player B
#     #     df_temp_left = df4model_dayof_b2.iloc[:, 1:]
#     #     df_temp_left.loc[:, "p_throws"] = [1] * len(df4model_dayof_b2)
#     #     df_new_case["pred_vs_RHP_batterB"] = log_reg_b2.predict_proba(df_temp_left)[:, 1]

#     # Prediction
#     if (
#         df_new_case["pred_vs_gamepitcher_batterA"].mean()
#         > df_new_case["pred_vs_gamepitcher_batterB"].mean()
#     ):
#         predict_for_day = "predict_A"
#     else:
#         predict_for_day = "predict_B"

#     # Actual case
#     if (
#         df_new_case["actual_performance_batterA"].mean()
#         > df_new_case["actual_performance_batterB"].mean()
#     ):
#         actual_for_day = "actual_A"
#     else:
#         actual_for_day = "actual_B"

#     validation_entries = (
#         date_of_interest,
#         pid_of_interest1,
#         pid_of_interest2,
#         predict_for_day,
#         actual_for_day,
#     )

#     return df_new_case, validation_entries

# %%
return_series_of_player_prediction(
    df4model_dayof_4model_b1, df4model_dayof_4model_b2, log_reg_b1, log_reg_b2
)
# Out:
# (actual_performance_batterA     0.333333
#  actual_performance_batterB     0.333333
#  pred_var_batterA                   None
#  pred_var_batterB                   None
#  pred_vs_gamepitcher_batterA    0.436708
#  pred_vs_gamepitcher_batterB    0.231098
#  dtype: object, ("'2019-09-04'", 668804, 544725, 'predict_A', 'even'))

# %% [markdown]
# ## Assessments

# %%
# Look at r2 value  - predicts variance - but there's lots of zeros

log_reg_p1.score(X_train_scale_p1, y_train_p1)
# Out:
# 0.625

# %%
log_reg_p1.score(X_test_scale_p1, y_test_p1)
# Out:
# 0.6172839506172839

# %%
print(metrics.classification_report(y_test_p1, y_pred_p1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.76        50
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.62        81
#    macro avg       0.31      0.50      0.38        81
# weighted avg       0.38      0.62      0.47        81
# /Users/lacar/anaconda/envs/insight/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
log_reg_p2.score(X_train_scale_p2, y_train_p2)
# Out:
# 0.725

# %%
log_reg_p2.score(X_test_scale_p2, y_test_p2)
# Out:
# 0.7283950617283951

# %%
print(metrics.classification_report(y_test_p2, y_pred_p2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.97      0.84        61
#            1       0.00      0.00      0.00        20
#
#     accuracy                           0.73        81
#    macro avg       0.37      0.48      0.42        81
# weighted avg       0.56      0.73      0.63        81

# %%
# Add validation for similar players and different dates
# Use a set of outfielders and dates

# %% [markdown]
# ## VALIDATION with multiple dates

# %% [markdown]
# ### Easy case - one player excellent, one not as good

# %%
# Betts and Garcia (605141, 544725)
pid1 = 605141
pid2 = 544725

# (43 dates)
# date_list = ["'2019-07-16'",
#  "'2019-07-17'",
#  "'2019-07-18'",
#  "'2019-07-19'",
#  "'2019-07-20'",
#  "'2019-07-21'",
#  "'2019-07-22'",
#  "'2019-07-23'",
#  "'2019-07-24'",
#  "'2019-07-25'",
#  "'2019-07-26'",
#  "'2019-07-27'",
#  "'2019-07-28'",
#  "'2019-07-30'",
#  "'2019-07-31'",
#  "'2019-08-01'",
#  "'2019-08-02'",
#  "'2019-08-03'",
#  "'2019-08-04'",
#  "'2019-08-05'",
#  "'2019-08-06'",
#  "'2019-08-07'",
#  "'2019-08-09'",
#  "'2019-08-10'",
#  "'2019-08-16'",
#  "'2019-08-17'",
#  "'2019-08-18'",
#  "'2019-08-20'",
#  "'2019-08-21'",
#  "'2019-08-23'",
#  "'2019-08-24'",
#  "'2019-08-25'",
#  "'2019-08-27'",
#  "'2019-08-28'",
#  "'2019-08-30'",
#  "'2019-08-31'",
#  "'2019-09-01'",
#  "'2019-09-03'",
#  "'2019-09-04'",
#  "'2019-09-10'",
#  "'2019-09-12'",
#  "'2019-09-21'",
#  "'2019-09-24']

# (12 dates)
date_list = [
    "'2019-08-25'",
    "'2019-08-27'",
    "'2019-08-28'",
    "'2019-08-30'",
    "'2019-08-31'",
    "'2019-09-01'",
    "'2019-09-03'",
    "'2019-09-04'",
    "'2019-09-10'",
    "'2019-09-12'",
    "'2019-09-21'",
    "'2019-09-24'",
]

no_total_ab_events = 1000

# GOAL
# Tabulate the prediction and the actual performance
# prediction A, prediction B, performance A, performance B

df_pred_actual_bydate = pd.DataFrame()

for date_of_interest in date_list:

    print(date_of_interest)

    # Input batters, date
    df_sc_events_b1 = get_sc_batter_df(pid1, date_of_interest, 1000)
    df_sc_events_b2 = get_sc_batter_df(pid2, date_of_interest, 1000)

    # Build model dataframe
    df4model_b1 = get_df4model(df=df_sc_events_b1.copy(), n_back_PA=100, m_size=200)
    df4model_b2 = get_df4model(df=df_sc_events_b2.copy(), n_back_PA=100, m_size=200)

    # Separate "day of" from "pre-date"
    df4model_dayof_b1 = df4model_b1[df4model_b1["game_date"] == date_of_interest].copy()
    df4model_dayof_b2 = df4model_b2[df4model_b2["game_date"] == date_of_interest].copy()

    # Format dataframe for model
    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
    ]
    df4model_b1_lim = df4model_b1.loc[
        df4model_b1["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b2_lim = df4model_b2.loc[
        df4model_b2["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b1_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
    df4model_b2_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

    X_train_scale_b1, X_test_scale_b1, y_train_b1, y_test_b1 = get_split_data(
        df4model_b1_lim, 0.4
    )
    X_train_scale_b2, X_test_scale_b2, y_train_b2, y_test_b2 = get_split_data(
        df4model_b2_lim, 0.4
    )

    # Run models
    log_reg_b1, df_eval_b1 = run_logreg_model(
        X_train_scale_b1, y_train_b1, X_test_scale_b1, y_test_b1
    )

    log_reg_b2, df_eval_b2 = run_logreg_model(
        X_train_scale_b2, y_train_b2, X_test_scale_b2, y_test_b2
    )

    print("Player 1 coefficients: ", log_reg_b1.coef_)
    print("Player 2 coefficients: ", log_reg_b2.coef_)

    # Assess day of performance  ---------
    # Get last 2 at-bats for the input
    df4model_dayof_4model_b1 = df4model_dayof_b1[col4model].iloc[-3:, :].copy()
    df4model_dayof_4model_b2 = df4model_dayof_b2[col4model].iloc[-3:, :].copy()

    # replace categorical input
    df4model_dayof_4model_b1["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
    df4model_dayof_4model_b2["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

    df_pred_actual, val_entries = return_series_of_player_prediction(
        df4model_dayof_4model_b1, df4model_dayof_4model_b2, log_reg_b1, log_reg_b2
    )

    colname = "A_vs_B_" + str(date_of_interest).strip("'")
    df_pred_actual_bydate[colname] = [i for i in val_entries]

    df_pred_actual_bydate.index = [
        "game_date",
        "key_batterA",
        "key_batterB",
        "prediction",
        "actual",
    ]

    if date_of_interest == date_list[-1]:
        print("done getting dates")
# Out:
# '2019-08-25'
# Player 1 coefficients:  [[-0.24881358  0.32428513 -0.00377914]]
# Player 2 coefficients:  [[ 0.08885514 -0.21810405  0.28497823]]
# '2019-08-27'
# Player 1 coefficients:  [[0.04350833 0.31440355 0.09238499]]
# Player 2 coefficients:  [[ 0.12684457  0.14242856 -0.05828517]]
# '2019-08-28'
# Player 1 coefficients:  [[-0.14442304  0.24069658  0.10030525]]
# Player 2 coefficients:  [[-0.0686821   0.53307119  0.39361812]]
# '2019-08-30'
# Player 1 coefficients:  [[-0.01051304  0.02495303  0.0944581 ]]
# Player 2 coefficients:  [[0.01412476 0.18815795 0.20289096]]
# '2019-08-31'
# Player 1 coefficients:  [[0.01774847 0.19180012 0.14352855]]
# Player 2 coefficients:  [[0.03850722 0.49034283 0.05851864]]
# '2019-09-01'
# Player 1 coefficients:  [[-0.23835762 -0.13763341  0.07846669]]
# Player 2 coefficients:  [[-0.14082798  0.28504299 -0.05526436]]
# '2019-09-03'
# Player 1 coefficients:  [[-0.29567287  0.40906969 -0.2279361 ]]
# Player 2 coefficients:  [[-0.14162716  0.85450561 -0.69842035]]
# '2019-09-04'
# Player 1 coefficients:  [[-0.18090405  0.03527459  0.19690786]]
# Player 2 coefficients:  [[-0.02890432  0.3899991  -0.41811302]]
# '2019-09-10'
# Player 1 coefficients:  [[-0.35508744  0.32553199 -0.07321985]]
# Player 2 coefficients:  [[-0.09884784  0.46756796 -0.3059968 ]]
# '2019-09-12'
# Player 1 coefficients:  [[-0.18660099  0.32789762 -0.07382484]]
# Player 2 coefficients:  [[ 0.0605822   0.68096994 -0.22498146]]
# '2019-09-21'
# Player 1 coefficients:  [[ 0.03140303  0.07050101 -0.05316559]]
# Player 2 coefficients:  [[ 0.27651973 -0.08529109  0.04497934]]
# '2019-09-24'
# Player 1 coefficients:  [[-0.24146957  0.07315068 -0.21828962]]
# Player 2 coefficients:  [[-0.06084687  0.20645047 -0.02396882]]
# done getting dates

# %% [markdown]
# **The model made a correct prediction (always A) for 8 of the 12 dates.**

# %%
df_pred_actual_bydate
# Out:
#             A_vs_B_2019-08-25 A_vs_B_2019-08-27 A_vs_B_2019-08-28  \
# game_date        '2019-08-25'      '2019-08-27'      '2019-08-28'
# key_batterA            605141            605141            605141
# key_batterB            544725            544725            544725
# prediction          predict_A         predict_A         predict_A
# actual               actual_B          actual_A          actual_B
#
#             A_vs_B_2019-08-30 A_vs_B_2019-08-31 A_vs_B_2019-09-01  \
# game_date        '2019-08-30'      '2019-08-31'      '2019-09-01'
# key_batterA            605141            605141            605141
# key_batterB            544725            544725            544725
# prediction          predict_A         predict_A         predict_A
# actual               actual_A          actual_A          actual_A
#
#             A_vs_B_2019-09-03 A_vs_B_2019-09-04 A_vs_B_2019-09-10  \
# game_date        '2019-09-03'      '2019-09-04'      '2019-09-10'
# key_batterA            605141            605141            605141
# key_batterB            544725            544725            544725
# prediction          predict_A         predict_A         predict_A
# actual               actual_B          actual_A          actual_A
#
#             A_vs_B_2019-09-12 A_vs_B_2019-09-21 A_vs_B_2019-09-24
# game_date        '2019-09-12'      '2019-09-21'      '2019-09-24'
# key_batterA            605141            605141            605141
# key_batterB            544725            544725            544725
# prediction          predict_A         predict_A         predict_A
# actual               actual_A          actual_B          actual_A

# %%
df_pred_actual_bydate.shape
# Out:
# (5, 12)

# %%
(df_pred_actual_bydate.loc["actual", :] == "actual_A").sum()
# Out:
# 8

# %% [markdown]
# ### Medium case - one player average, one not as good

# %%
# Reynolds and Garcia (668804, 544725)
# Bryan Reynolds (PIT)

pid1 = 668804
pid2 = 544725

# (10 dates)
date_list = [
 "'2019-09-04'",
 "'2019-09-10'",
 "'2019-09-11'",
 "'2019-09-12'",
 "'2019-09-13'",
 "'2019-09-18'",
 "'2019-09-21'",
 "'2019-09-22'",
 "'2019-09-24'",
 "'2019-09-25'"]

no_total_ab_events = 1000

# GOAL
# Tabulate the prediction and the actual performance
# prediction A, prediction B, performance A, performance B

df_pred_actual_bydate = pd.DataFrame()

for date_of_interest in date_list:

    print(date_of_interest)

    # Input batters, date
    df_sc_events_b1 = get_sc_batter_df(pid1, date_of_interest, 1000)
    df_sc_events_b2 = get_sc_batter_df(pid2, date_of_interest, 1000)

    # Build model dataframe
    df4model_b1 = get_df4model(df=df_sc_events_b1.copy(), n_back_PA=100, m_size=200)
    df4model_b2 = get_df4model(df=df_sc_events_b2.copy(), n_back_PA=100, m_size=200)

    # Separate "day of" from "pre-date"
    df4model_dayof_b1 = df4model_b1[df4model_b1["game_date"] == date_of_interest].copy()
    df4model_dayof_b2 = df4model_b2[df4model_b2["game_date"] == date_of_interest].copy()

    # Format dataframe for model
    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
    ]
    df4model_b1_lim = df4model_b1.loc[
        df4model_b1["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b2_lim = df4model_b2.loc[
        df4model_b2["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b1_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
    df4model_b2_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

    X_train_scale_b1, X_test_scale_b1, y_train_b1, y_test_b1 = get_split_data(
        df4model_b1_lim, 0.4
    )
    X_train_scale_b2, X_test_scale_b2, y_train_b2, y_test_b2 = get_split_data(
        df4model_b2_lim, 0.4
    )

    # Run models
    log_reg_b1, df_eval_b1 = run_logreg_model(
        X_train_scale_b1, y_train_b1, X_test_scale_b1, y_test_b1
    )

    log_reg_b2, df_eval_b2 = run_logreg_model(
        X_train_scale_b2, y_train_b2, X_test_scale_b2, y_test_b2
    )

    print("Player 1 coefficients: ", log_reg_b1.coef_)
    print("Player 2 coefficients: ", log_reg_b2.coef_)

    # Assess day of performance  ---------
    # Get last 2 at-bats for the input
    df4model_dayof_4model_b1 = df4model_dayof_b1[col4model].iloc[-3:, :].copy()
    df4model_dayof_4model_b2 = df4model_dayof_b2[col4model].iloc[-3:, :].copy()

    # replace categorical input
    df4model_dayof_4model_b1["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
    df4model_dayof_4model_b2["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

    df_pred_actual, val_entries = return_series_of_player_prediction(
        df4model_dayof_4model_b1, df4model_dayof_4model_b2, log_reg_b1, log_reg_b2
    )

    colname = "A_vs_B_" + str(date_of_interest).strip("'")
    df_pred_actual_bydate[colname] = [i for i in val_entries]

    df_pred_actual_bydate.index = [
        "game_date",
        "key_batterA",
        "key_batterB",
        "prediction",
        "actual",
    ]

    if date_of_interest == date_list[-1]:
        print("done getting dates")
# Out:
# '2019-09-04'
# Player 1 coefficients:  [[0.14236542 0.00191787 0.58597128]]
# Player 2 coefficients:  [[-0.03456852  0.34511474 -0.40894548]]
# '2019-09-10'
# Player 1 coefficients:  [[0.04334415 0.25728826 0.28985815]]
# Player 2 coefficients:  [[-0.10128357  0.4383019  -0.29617528]]
# '2019-09-11'
# Player 1 coefficients:  [[-0.44933511  0.49806653  0.57496996]]
# Player 2 coefficients:  [[-0.30400136  0.1216691  -0.29519645]]
# '2019-09-12'
# Player 1 coefficients:  [[ 0.23155709 -0.11502046  0.02581148]]
# Player 2 coefficients:  [[ 0.04362555  0.7196835  -0.27039   ]]
# '2019-09-13'
# Player 1 coefficients:  [[-0.27087977  0.26818208  0.47517779]]
# Player 2 coefficients:  [[-0.46479727  0.57442249 -0.69506079]]
# '2019-09-18'
# Player 1 coefficients:  [[-0.17683546  0.19843019  0.26926683]]
# Player 2 coefficients:  [[-0.23354343  0.65799609 -0.62038385]]
# '2019-09-21'
# Player 1 coefficients:  [[-0.05402152  0.25044675  0.1813268 ]]
# Player 2 coefficients:  [[ 0.27651973 -0.08529109  0.04497934]]
# '2019-09-22'
# Player 1 coefficients:  [[ 0.31763765  0.25244862 -0.03757199]]
# Player 2 coefficients:  [[ 0.05175702  0.48424306 -0.25737318]]
# '2019-09-24'
# Player 1 coefficients:  [[-0.34305838  0.59323995  0.657729  ]]
# Player 2 coefficients:  [[-0.06084687  0.20645047 -0.02396882]]
# '2019-09-25'
# Player 1 coefficients:  [[-0.35046192  0.42045784  0.5194703 ]]
# Player 2 coefficients:  [[-0.28171127  0.4656303  -0.44636526]]
# done getting dates

# %%
df_pred_actual_bydate
# Out:
#             A_vs_B_2019-09-04 A_vs_B_2019-09-10 A_vs_B_2019-09-11  \
# game_date        '2019-09-04'      '2019-09-10'      '2019-09-11'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction          predict_A         predict_A         predict_A
# actual                   even              even          actual_B
#
#             A_vs_B_2019-09-12 A_vs_B_2019-09-13 A_vs_B_2019-09-18  \
# game_date        '2019-09-12'      '2019-09-13'      '2019-09-18'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction          predict_A         predict_A         predict_A
# actual               actual_A          actual_B          actual_B
#
#             A_vs_B_2019-09-21 A_vs_B_2019-09-22 A_vs_B_2019-09-24  \
# game_date        '2019-09-21'      '2019-09-22'      '2019-09-24'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction          predict_A         predict_A         predict_A
# actual               actual_B              even          actual_B
#
#             A_vs_B_2019-09-25
# game_date        '2019-09-25'
# key_batterA            668804
# key_batterB            544725
# prediction          predict_A
# actual               actual_B

# %% [markdown]
# **When looking at 11 common playing dates after September 1, the model made a correct prediction 1 of the 11 dates when putting Reynolds as the first player listed (predict all A), but 5 of the 11 when listing him second.**

# %%
df_eval_b1
# Out:
#      test  pred  predprob
# 41      0     0  0.274096
# 141     1     0  0.248559
# 34      0     0  0.239243
# 92      1     0  0.372372
# 14      1     0  0.153745
# ..    ...   ...       ...
# 198     0     0  0.494873
# 19      0     0  0.195789
# 172     1     0  0.423505
# 190     0     0  0.423505
# 122     0     0  0.385989
#
# [80 rows x 3 columns]

# %%
df_eval_b2
# Out:
#      test  pred  predprob
# 34      1     0  0.191440
# 78      0     0  0.192407
# 149     0     0  0.289083
# 40      1     0  0.236161
# 85      0     0  0.216773
# ..    ...   ...       ...
# 172     0     0  0.403339
# 190     1     0  0.274596
# 145     1     0  0.336623
# 71      1     0  0.127556
# 122     0     0  0.156877
#
# [80 rows x 3 columns]

# %% [markdown]
# # Add pitcher features, at-bat level
#
# - Use same dataframe.
# - Identify the batter's DF and how it can be joined to pitcher's DF.

# %%
# goes to 100
df_sc_events_b1.head()
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FC 2019-09-25           87.4         2.7441         5.7888
# 1         SI 2019-09-24           94.8         2.6869         6.0305
# 2         CH 2019-09-24           81.0         2.8359         5.4730
# 3         FF 2019-09-24           85.2        -2.5214         5.8412
# 4         CH 2019-09-24           76.7        -2.4278         6.0267
#
#       player_name    batter   pitcher           events          description  \
# 0      Jon Lester  668804.0  452657.0        field_out        hit_into_play
# 1   Derek Holland  668804.0  502706.0        field_out        hit_into_play
# 2   Danny Hultzen  668804.0  543343.0  fielders_choice  hit_into_play_score
# 3  Kyle Hendricks  668804.0  543294.0        field_out        hit_into_play
# 4  Kyle Hendricks  668804.0  543294.0        field_out        hit_into_play
#
#    ... if_fielding_alignment of_fielding_alignment name_last name_first  \
# 0  ...              Standard              Standard  reynolds      bryan
# 1  ...              Standard              Standard  reynolds      bryan
# 2  ...              Standard              Standard  reynolds      bryan
# 3  ...              Standard              Standard  reynolds      bryan
# 4  ...              Standard              Standard  reynolds      bryan
#
#    key_mlbam key_retro  key_bbref key_fangraphs mlb_played_first  \
# 0     668804  reynb001  reynobr01         19326           2019.0
# 1     668804  reynb001  reynobr01         19326           2019.0
# 2     668804  reynb001  reynobr01         19326           2019.0
# 3     668804  reynb001  reynobr01         19326           2019.0
# 4     668804  reynb001  reynobr01         19326           2019.0
#
#   mlb_played_last
# 0          2019.0
# 1          2019.0
# 2          2019.0
# 3          2019.0
# 4          2019.0
#
# [5 rows x 97 columns]

# %%
# goes to 200
df4model_dayof_b1.head()
# Out:
#    game_date  inning  outs_when_up     events player_name   pitcher  \
# 0 2019-09-25     1.0           1.0  field_out  Jon Lester  452657.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt
# 0           0        L               0.28                      0.26

# %%
# This will capture starting pitcher most of the time
# Not completely right (somoene could start but leave game before hitter's at-bat)
# but will leave this for validation

# INPUT DATE AND DF OF PITCHER

# date_of_interest = date_of_interest
# df4_bp_match = df_sc_events1.copy()

# bool_pitcher = df_sc_events1["game_date"] == date_of_interest
# pid_opp_pitcher = df4_bp_match.loc[bool_pitcher, "pitcher"].iloc[-1]

# %% [markdown]
# ## Add pitcher info

# %%
def get_df4sc_info_opp_pitcher(pitcher_id, date):

    # (Save info for doing pitcher level)
    # Estimated no. pitches in a season - 34 starts x 100 pitches
    # number of at-bats

    no_ab = 500

    # Getting all the at-bats BEFORE facing the batter (< game date)

    sql_query = (
        """
    (SELECT * FROM statcast 
    JOIN player_id ON statcast.pitcher=player_id.key_mlbam 
    WHERE statcast.pitcher= 
    """
        + str(pitcher_id)
        + """
    AND statcast.game_date<
    """
        + str(date_of_interest)
        + """ 
    AND statcast.events IS NOT NULL 
    ORDER BY statcast.game_date DESC, 
    statcast.index ASC 
    LIMIT 
    """
        + str(no_ab)
        + ");"
    )

    # print(sql_query)

    df_sc_pitcher = pd.read_sql_query(sql_query, con)
    df_sc_pitcher.drop(["level_0", "index"], axis=1, inplace=True)  # Clean up df

    # print("head: ", df_sc_pitcher.head())

    return df_sc_pitcher

# %%
# Get pitch characteristics - lower priority

# fastball velocity, fastball proportion, breaking ball velocity
# df_sc_pitcher.groupby("pitch_type")["release_speed"].mean()

# df_sc_pitcher.groupby("pitch_type")["release_speed"].mean()

# %%
def get_series4model_4pitcher_for_ab(df, n_back_PA):
    """
    Function for getting summarized series for that pitcher
    """
    # sample values -----------
    # n_back_PA = 100
    # df = df_sc_events.copy()
    # pid = pid_of_interest1
    # m_size = 200

    # -------------------------

    # Reset index so that code below works
    # df.reset_index(inplace=True)

    # Encode on-base events, including walks
    ob_list = ["walk", "single", "double", "triple", "home_run"]
    df["event_code"] = 0
    df.loc[df["events"].isin(ob_list), "event_code"] = 1

    # Sum of on-base events - critical that order matters! (should be addressed above)
    # rolling was close, but needed to tweak

    s_for_summary = pd.Series()

    # Total number of events
    s_for_summary["num_events_sum_nback_bs"] = df["event_code"].iloc[0:n_back_PA].sum()
    # Percent of on-base events (overall)
    s_for_summary["prop_events_nback_bs"] = (
        s_for_summary["num_events_sum_nback_bs"] / n_back_PA
    )

    # Percent of on-base events against handedness of batter
    # Tweaked code from old function, just need first row
    for i_stand in ["L", "R"]:
        df_b_stand = df[df["stand"] == i_stand].copy()
        n_bat_events = df_b_stand["event_code"].iloc[0:n_back_PA].sum()
        s_for_summary["num_events_sum_nback_bs" + "_" + i_stand] = n_bat_events
        s_for_summary["prop_events_sum_nback_bs" + "_" + i_stand] = (
            n_bat_events / n_back_PA
        )

    return s_for_summary

# %% [markdown]
# Get pitcher info separately then merge on its own

# %%
def merge_batter_pitcher_dfs(df_sc_events4func, batter_df):
    col2add2df = [
        "num_events_sum_nback_bs",
        "prop_events_nback_bs",
        "num_events_sum_nback_bs_L",
        "prop_events_sum_nback_bs_L",
        "num_events_sum_nback_bs_R",
        "prop_events_sum_nback_bs_R",
    ]

    # Limit this to the length of the batter_df
    df_sc_events4func = df_sc_events4func.iloc[0 : len(batter_df), :].copy()

    for col in col2add2df:
        df_sc_events4func[col] = None

    for i, pitcher in enumerate(df_sc_events4func["pitcher"]):

        date2stop = df_sc_events4func["game_date"].iloc[i]
        if i == 0:
            pid_opp_in_mem = pitcher
            print(i, "starting pitcher list: ", pitcher)

            # Get data from SQL
            df_p_info4date = get_df4sc_info_opp_pitcher(pid_opp_in_mem, date2stop)
            p_summary = get_series4model_4pitcher_for_ab(df_p_info4date, 100)

            # Add series to df
            df_sc_events4func.loc[i, col2add2df] = p_summary

        elif (pitcher == pid_opp_in_mem) & (i > 0):
            print(i, "same pitcher: ", pitcher)
            pid_opp_in_mem = pitcher

            # Add series to df
            df_sc_events4func.loc[i, col2add2df] = p_summary

        else:
            print(i, "new pitcher: from ", pid_opp_in_mem, "to ", pitcher)
            pid_opp_in_mem = pitcher

            # SQL entry
            # Get data from SQL
            df_p_info4date = get_df4sc_info_opp_pitcher(pid_opp_in_mem, date2stop)
            p_summary = get_series4model_4pitcher_for_ab(df_p_info4date, 100)

            # Add series to df
            df_sc_events4func.loc[i, col2add2df] = p_summary

    col2add2df = [
        "prop_events_nback_bs",
        "prop_events_sum_nback_bs_L",
        "prop_events_sum_nback_bs_R",
    ]
    # Join dfs on index
    df_merged = pd.merge(
        batter_df,
        df_sc_events4func[col2add2df],
        how="left",
        left_index=True,
        right_index=True,
    )

    print("Done merging")

    return df_merged

# %%
# TRY THREADING?

df_b_p_merged = merge_batter_pitcher_dfs(df_sc_events_b1, df4model_b1)
# Out:
# 0 starting pitcher list:  452657.0
# 1 new pitcher: from  452657.0 to  502706.0
# 2 new pitcher: from  502706.0 to  543343.0
# 3 new pitcher: from  543343.0 to  543294.0
# 4 same pitcher:  543294.0
# 5 same pitcher:  543294.0
# 6 new pitcher: from  543294.0 to  623352.0
# 7 new pitcher: from  623352.0 to  461829.0
# 8 same pitcher:  461829.0
# 9 new pitcher: from  461829.0 to  605540.0
# 10 new pitcher: from  605540.0 to  448855.0
# 11 new pitcher: from  448855.0 to  608718.0
# 12 new pitcher: from  608718.0 to  605200.0
# 13 same pitcher:  605200.0
# 14 new pitcher: from  605200.0 to  607188.0
# 15 new pitcher: from  607188.0 to  502624.0
# 16 same pitcher:  502624.0
# 17 same pitcher:  502624.0
# 18 new pitcher: from  502624.0 to  542914.0
# 19 new pitcher: from  542914.0 to  607555.0
# 20 new pitcher: from  607555.0 to  579328.0
# 21 same pitcher:  579328.0
# 22 same pitcher:  579328.0
# 23 new pitcher: from  579328.0 to  542914.0
# 24 new pitcher: from  542914.0 to  543548.0
# 25 same pitcher:  543548.0
# 26 new pitcher: from  543548.0 to  643290.0
# 27 new pitcher: from  643290.0 to  656803.0
# 28 new pitcher: from  656803.0 to  543022.0
# 29 same pitcher:  543022.0
# 30 new pitcher: from  543022.0 to  500779.0
# 31 same pitcher:  500779.0
# 32 new pitcher: from  500779.0 to  656803.0
# 33 new pitcher: from  656803.0 to  543294.0
# 34 same pitcher:  543294.0
# 35 same pitcher:  543294.0
# 36 new pitcher: from  543294.0 to  623364.0
# 37 new pitcher: from  623364.0 to  452657.0
# 38 same pitcher:  452657.0
# 39 same pitcher:  452657.0
# 40 new pitcher: from  452657.0 to  605498.0
# 41 new pitcher: from  605498.0 to  502188.0
# 42 same pitcher:  502188.0
# 43 same pitcher:  502188.0
# 44 new pitcher: from  502188.0 to  607457.0
# 45 new pitcher: from  607457.0 to  656322.0
# 46 new pitcher: from  656322.0 to  657277.0
# 47 same pitcher:  657277.0
# 48 same pitcher:  657277.0
# 49 new pitcher: from  657277.0 to  656322.0
# 50 new pitcher: from  656322.0 to  605498.0
# 51 new pitcher: from  605498.0 to  456501.0
# 52 same pitcher:  456501.0
# 53 new pitcher: from  456501.0 to  594311.0
# 54 new pitcher: from  594311.0 to  518516.0
# 55 same pitcher:  518516.0
# 56 same pitcher:  518516.0
# 57 same pitcher:  518516.0
# 58 new pitcher: from  518516.0 to  656427.0
# 59 same pitcher:  656427.0
# 60 same pitcher:  656427.0
# 61 same pitcher:  656427.0
# 62 new pitcher: from  656427.0 to  658551.0
# 63 new pitcher: from  658551.0 to  425794.0
# 64 same pitcher:  425794.0
# 65 same pitcher:  425794.0
# 66 new pitcher: from  425794.0 to  594577.0
# 67 new pitcher: from  594577.0 to  453192.0
# 68 new pitcher: from  453192.0 to  571945.0
# 69 same pitcher:  571945.0
# 70 same pitcher:  571945.0
# 71 new pitcher: from  571945.0 to  606424.0
# 72 new pitcher: from  606424.0 to  650671.0
# 73 new pitcher: from  650671.0 to  572383.0
# 74 new pitcher: from  572383.0 to  622694.0
# 75 same pitcher:  622694.0
# 76 new pitcher: from  622694.0 to  570632.0
# 77 new pitcher: from  570632.0 to  543045.0
# 78 new pitcher: from  543045.0 to  667498.0
# 79 same pitcher:  667498.0
# 80 same pitcher:  667498.0
# 81 new pitcher: from  667498.0 to  570632.0
# 82 new pitcher: from  570632.0 to  606424.0
# 83 new pitcher: from  606424.0 to  645261.0
# 84 same pitcher:  645261.0
# 85 same pitcher:  645261.0
# 86 new pitcher: from  645261.0 to  545064.0
# 87 new pitcher: from  545064.0 to  622786.0
# 88 new pitcher: from  622786.0 to  656546.0
# 89 same pitcher:  656546.0
# 90 same pitcher:  656546.0
# 91 new pitcher: from  656546.0 to  607572.0
# 92 new pitcher: from  607572.0 to  459429.0
# 93 new pitcher: from  459429.0 to  641149.0
# 94 same pitcher:  641149.0
# 95 new pitcher: from  641149.0 to  543532.0
# 96 same pitcher:  543532.0
# 97 new pitcher: from  543532.0 to  451584.0
# 98 new pitcher: from  451584.0 to  543766.0
# 99 new pitcher: from  543766.0 to  622608.0
# 100 same pitcher:  622608.0
# 101 same pitcher:  622608.0
# 102 new pitcher: from  622608.0 to  459429.0
# 103 new pitcher: from  459429.0 to  622786.0
# 104 new pitcher: from  622786.0 to  622075.0
# 105 same pitcher:  622075.0
# 106 new pitcher: from  622075.0 to  592346.0
# 107 new pitcher: from  592346.0 to  592826.0
# 108 same pitcher:  592826.0
# 109 same pitcher:  592826.0
# 110 new pitcher: from  592826.0 to  593576.0
# 111 new pitcher: from  593576.0 to  624133.0
# 112 new pitcher: from  624133.0 to  592767.0
# 113 same pitcher:  592767.0
# 114 same pitcher:  592767.0
# 115 new pitcher: from  592767.0 to  593576.0
# 116 new pitcher: from  593576.0 to  453172.0
# 117 new pitcher: from  453172.0 to  450306.0
# 118 same pitcher:  450306.0
# 119 same pitcher:  450306.0
# 120 new pitcher: from  450306.0 to  607237.0
# 121 new pitcher: from  607237.0 to  596112.0
# 122 new pitcher: from  596112.0 to  545333.0
# 123 same pitcher:  545333.0
# 124 same pitcher:  545333.0
# 125 new pitcher: from  545333.0 to  595798.0
# 126 new pitcher: from  595798.0 to  592332.0
# 127 new pitcher: from  592332.0 to  622072.0
# 128 same pitcher:  622072.0
# 129 same pitcher:  622072.0
# 130 new pitcher: from  622072.0 to  607237.0
# 131 new pitcher: from  607237.0 to  543101.0
# 132 same pitcher:  543101.0
# 133 same pitcher:  543101.0
# 134 new pitcher: from  543101.0 to  407845.0
# 135 new pitcher: from  407845.0 to  593833.0
# 136 new pitcher: from  593833.0 to  453286.0
# 137 same pitcher:  453286.0
# 138 new pitcher: from  453286.0 to  663432.0
# 139 new pitcher: from  663432.0 to  571578.0
# 140 same pitcher:  571578.0
# 141 same pitcher:  571578.0
# 142 new pitcher: from  571578.0 to  543339.0
# 143 new pitcher: from  543339.0 to  544931.0
# 144 same pitcher:  544931.0
# 145 same pitcher:  544931.0
# 146 new pitcher: from  544931.0 to  663432.0
# 147 new pitcher: from  663432.0 to  457915.0
# 148 new pitcher: from  457915.0 to  605452.0
# 149 same pitcher:  605452.0
# 150 new pitcher: from  605452.0 to  518886.0
# 151 new pitcher: from  518886.0 to  500779.0
# 152 same pitcher:  500779.0
# 153 same pitcher:  500779.0
# 154 new pitcher: from  500779.0 to  592858.0
# 155 new pitcher: from  592858.0 to  543022.0
# 156 new pitcher: from  543022.0 to  452657.0
# 157 same pitcher:  452657.0
# 158 same pitcher:  452657.0
# 159 new pitcher: from  452657.0 to  594986.0
# 160 new pitcher: from  594986.0 to  543294.0
# 161 same pitcher:  543294.0
# 162 same pitcher:  543294.0
# 163 new pitcher: from  543294.0 to  592135.0
# 164 new pitcher: from  592135.0 to  596071.0
# 165 same pitcher:  596071.0
# 166 same pitcher:  596071.0
# 167 new pitcher: from  596071.0 to  657228.0
# 168 same pitcher:  657228.0
# 169 new pitcher: from  657228.0 to  472610.0
# 170 new pitcher: from  472610.0 to  656288.0
# 171 same pitcher:  656288.0
# 172 same pitcher:  656288.0
# 173 new pitcher: from  656288.0 to  472610.0
# 174 new pitcher: from  472610.0 to  642578.0
# 175 same pitcher:  642578.0
# 176 new pitcher: from  642578.0 to  660761.0
# 177 same pitcher:  660761.0
# 178 new pitcher: from  660761.0 to  453192.0
# 179 new pitcher: from  453192.0 to  607231.0
# 180 new pitcher: from  607231.0 to  571945.0
# 181 same pitcher:  571945.0
# 182 same pitcher:  571945.0
# 183 new pitcher: from  571945.0 to  606149.0
# 184 new pitcher: from  606149.0 to  425794.0
# 185 same pitcher:  425794.0
# 186 same pitcher:  425794.0
# 187 new pitcher: from  425794.0 to  453192.0
# 188 new pitcher: from  453192.0 to  643778.0
# 189 new pitcher: from  643778.0 to  641712.0
# 190 same pitcher:  641712.0
# 191 new pitcher: from  641712.0 to  642207.0
# 192 same pitcher:  642207.0
# 193 new pitcher: from  642207.0 to  448855.0
# 194 new pitcher: from  448855.0 to  519141.0
# 195 new pitcher: from  519141.0 to  607188.0
# 196 new pitcher: from  607188.0 to  502624.0
# 197 same pitcher:  502624.0
# 198 same pitcher:  502624.0
# 199 new pitcher: from  502624.0 to  623352.0
# 200 new pitcher: from  623352.0 to  642547.0
# Done merging

# %%
df4model_dayof_b1.head()
# Out:
#    game_date  inning  outs_when_up     events player_name   pitcher  \
# 0 2019-09-25     1.0           1.0  field_out  Jon Lester  452657.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt
# 0           0        L               0.28                      0.26

# %%
df_b_p_merged.head()
# Out:
#    game_date  inning  outs_when_up           events     player_name   pitcher  \
# 0 2019-09-25     1.0           1.0        field_out      Jon Lester  452657.0
# 1 2019-09-24     8.0           2.0        field_out   Derek Holland  502706.0
# 2 2019-09-24     7.0           1.0  fielders_choice   Danny Hultzen  543343.0
# 3 2019-09-24     6.0           1.0        field_out  Kyle Hendricks  543294.0
# 4 2019-09-24     4.0           0.0        field_out  Kyle Hendricks  543294.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  \
# 0           0        L               0.28                      0.26
# 1           0        L               0.29                      0.26
# 2           0        L               0.29                      0.26
# 3           0        R               0.29                      0.33
# 4           0        R               0.29                      0.33
#
#   prop_events_nback_bs prop_events_sum_nback_bs_L prop_events_sum_nback_bs_R
# 0                  0.4                       0.37                       0.41
# 1                 0.28                       0.27                        0.3
# 2                 0.06                       0.03                       0.03
# 3                  0.3                       0.23                       0.33
# 4                  0.3                       0.23                       0.33

# %%
df_b_p_merged_b2 = merge_batter_pitcher_dfs(df_sc_events_b2, df4model_b2)
# Out:
# 0 starting pitcher list:  669456.0
# 1 same pitcher:  669456.0
# 2 same pitcher:  669456.0
# 3 new pitcher: from  669456.0 to  605182.0
# 4 same pitcher:  605182.0
# 5 same pitcher:  605182.0
# 6 new pitcher: from  605182.0 to  641729.0
# 7 new pitcher: from  641729.0 to  670167.0
# 8 new pitcher: from  670167.0 to  571510.0
# 9 same pitcher:  571510.0
# 10 same pitcher:  571510.0
# 11 new pitcher: from  571510.0 to  650530.0
# 12 new pitcher: from  650530.0 to  641853.0
# 13 new pitcher: from  641853.0 to  641302.0
# 14 same pitcher:  641302.0
# 15 same pitcher:  641302.0
# 16 new pitcher: from  641302.0 to  664054.0
# 17 new pitcher: from  664054.0 to  543606.0
# 18 same pitcher:  543606.0
# 19 same pitcher:  543606.0
# 20 new pitcher: from  543606.0 to  607560.0
# 21 new pitcher: from  607560.0 to  641793.0
# 22 new pitcher: from  641793.0 to  573124.0
# 23 new pitcher: from  573124.0 to  543507.0
# 24 new pitcher: from  543507.0 to  527048.0
# 25 same pitcher:  527048.0
# 26 same pitcher:  527048.0
# 27 new pitcher: from  527048.0 to  621244.0
# 28 same pitcher:  621244.0
# 29 same pitcher:  621244.0
# 30 same pitcher:  621244.0
# 31 new pitcher: from  621244.0 to  657024.0
# 32 new pitcher: from  657024.0 to  592165.0
# 33 new pitcher: from  592165.0 to  453281.0
# 34 new pitcher: from  453281.0 to  579328.0
# 35 same pitcher:  579328.0
# 36 new pitcher: from  579328.0 to  453178.0
# 37 new pitcher: from  453178.0 to  642100.0
# 38 new pitcher: from  642100.0 to  453178.0
# 39 new pitcher: from  453178.0 to  534910.0
# 40 new pitcher: from  534910.0 to  642098.0
# 41 same pitcher:  642098.0
# 42 same pitcher:  642098.0
# 43 new pitcher: from  642098.0 to  642100.0
# 44 new pitcher: from  642100.0 to  641838.0
# 45 new pitcher: from  641838.0 to  596001.0
# 46 same pitcher:  596001.0
# 47 same pitcher:  596001.0
# 48 new pitcher: from  596001.0 to  543272.0
# 49 new pitcher: from  543272.0 to  669456.0
# 50 same pitcher:  669456.0
# 51 same pitcher:  669456.0
# 52 same pitcher:  669456.0
# 53 new pitcher: from  669456.0 to  624586.0
# 54 new pitcher: from  624586.0 to  471911.0
# 55 new pitcher: from  471911.0 to  605182.0
# 56 same pitcher:  605182.0
# 57 same pitcher:  605182.0
# 58 new pitcher: from  605182.0 to  621295.0
# 59 new pitcher: from  621295.0 to  580792.0
# 60 new pitcher: from  580792.0 to  650644.0
# 61 same pitcher:  650644.0
# 62 same pitcher:  650644.0
# 63 new pitcher: from  650644.0 to  592426.0
# 64 new pitcher: from  592426.0 to  527054.0
# 65 same pitcher:  527054.0
# 66 same pitcher:  527054.0
# 67 new pitcher: from  527054.0 to  461872.0
# 68 new pitcher: from  461872.0 to  572971.0
# 69 same pitcher:  572971.0
# 70 same pitcher:  572971.0
# 71 same pitcher:  572971.0
# 72 new pitcher: from  572971.0 to  461872.0
# 73 new pitcher: from  461872.0 to  592426.0
# 74 new pitcher: from  592426.0 to  608331.0
# 75 same pitcher:  608331.0
# 76 same pitcher:  608331.0
# 77 new pitcher: from  608331.0 to  677976.0
# 78 same pitcher:  677976.0
# 79 new pitcher: from  677976.0 to  621244.0
# 80 same pitcher:  621244.0
# 81 same pitcher:  621244.0
# 82 new pitcher: from  621244.0 to  664054.0
# 83 new pitcher: from  664054.0 to  543507.0
# 84 new pitcher: from  543507.0 to  543606.0
# 85 same pitcher:  543606.0
# 86 same pitcher:  543606.0
# 87 new pitcher: from  543606.0 to  608648.0
# 88 new pitcher: from  608648.0 to  501381.0
# 89 same pitcher:  501381.0
# 90 same pitcher:  501381.0
# 91 new pitcher: from  501381.0 to  661403.0
# 92 new pitcher: from  661403.0 to  656271.0
# 93 same pitcher:  656271.0
# 94 same pitcher:  656271.0
# 95 new pitcher: from  656271.0 to  606160.0
# 96 new pitcher: from  606160.0 to  663465.0
# 97 same pitcher:  663465.0
# 98 same pitcher:  663465.0
# 99 new pitcher: from  663465.0 to  608652.0
# 100 new pitcher: from  608652.0 to  458681.0
# 101 same pitcher:  458681.0
# 102 same pitcher:  458681.0
# 103 same pitcher:  458681.0
# 104 new pitcher: from  458681.0 to  642558.0
# 105 same pitcher:  642558.0
# 106 same pitcher:  642558.0
# 107 same pitcher:  642558.0
# 108 new pitcher: from  642558.0 to  543507.0
# 109 new pitcher: from  543507.0 to  607560.0
# 110 new pitcher: from  607560.0 to  543606.0
# 111 same pitcher:  543606.0
# 112 same pitcher:  543606.0
# 113 new pitcher: from  543606.0 to  608648.0
# 114 new pitcher: from  608648.0 to  501381.0
# 115 same pitcher:  501381.0
# 116 same pitcher:  501381.0
# 117 new pitcher: from  501381.0 to  626929.0
# 118 new pitcher: from  626929.0 to  607560.0
# 119 new pitcher: from  607560.0 to  502043.0
# 120 same pitcher:  502043.0
# 121 same pitcher:  502043.0
# 122 new pitcher: from  502043.0 to  621142.0
# 123 new pitcher: from  621142.0 to  656288.0
# 124 same pitcher:  656288.0
# 125 same pitcher:  656288.0
# 126 new pitcher: from  656288.0 to  570663.0
# 127 new pitcher: from  570663.0 to  518566.0
# 128 new pitcher: from  518566.0 to  660761.0
# 129 same pitcher:  660761.0
# 130 new pitcher: from  660761.0 to  598287.0
# 131 new pitcher: from  598287.0 to  502239.0
# 132 new pitcher: from  502239.0 to  606167.0
# 133 new pitcher: from  606167.0 to  663776.0
# 134 same pitcher:  663776.0
# 135 same pitcher:  663776.0
# 136 new pitcher: from  663776.0 to  502239.0
# 137 new pitcher: from  502239.0 to  571760.0
# 138 same pitcher:  571760.0
# 139 same pitcher:  571760.0
# 140 new pitcher: from  571760.0 to  488748.0
# 141 new pitcher: from  488748.0 to  543699.0
# 142 same pitcher:  543699.0
# 143 same pitcher:  543699.0
# 144 new pitcher: from  543699.0 to  518617.0
# 145 new pitcher: from  518617.0 to  571666.0
# 146 same pitcher:  571666.0
# 147 same pitcher:  571666.0
# 148 new pitcher: from  571666.0 to  641525.0
# 149 new pitcher: from  641525.0 to  572096.0
# 150 new pitcher: from  572096.0 to  621592.0
# 151 new pitcher: from  621592.0 to  641302.0
# 152 same pitcher:  641302.0
# 153 same pitcher:  641302.0
# 154 new pitcher: from  641302.0 to  543278.0
# 155 new pitcher: from  543278.0 to  571656.0
# 156 new pitcher: from  571656.0 to  598286.0
# 157 new pitcher: from  598286.0 to  542585.0
# 158 new pitcher: from  542585.0 to  572403.0
# 159 new pitcher: from  572403.0 to  596057.0
# 160 new pitcher: from  596057.0 to  572403.0
# 161 new pitcher: from  572403.0 to  596057.0
# 162 new pitcher: from  596057.0 to  572403.0
# 163 new pitcher: from  572403.0 to  596057.0
# 164 new pitcher: from  596057.0 to  621592.0
# 165 new pitcher: from  621592.0 to  571656.0
# 166 new pitcher: from  571656.0 to  642397.0
# 167 same pitcher:  642397.0
# 168 new pitcher: from  642397.0 to  605513.0
# 169 same pitcher:  605513.0
# 170 new pitcher: from  605513.0 to  453284.0
# 171 new pitcher: from  453284.0 to  573046.0
# 172 new pitcher: from  573046.0 to  592767.0
# 173 same pitcher:  592767.0
# 174 same pitcher:  592767.0
# 175 new pitcher: from  592767.0 to  601713.0
# 176 new pitcher: from  601713.0 to  605400.0
# 177 same pitcher:  605400.0
# 178 same pitcher:  605400.0
# 179 new pitcher: from  605400.0 to  596451.0
# 180 new pitcher: from  596451.0 to  621107.0
# 181 new pitcher: from  621107.0 to  453284.0
# 182 new pitcher: from  453284.0 to  601713.0
# 183 new pitcher: from  601713.0 to  450306.0
# 184 same pitcher:  450306.0
# 185 same pitcher:  450306.0
# 186 new pitcher: from  450306.0 to  501593.0
# 187 new pitcher: from  501593.0 to  554430.0
# 188 same pitcher:  554430.0
# 189 same pitcher:  554430.0
# 190 new pitcher: from  554430.0 to  621242.0
# 191 new pitcher: from  621242.0 to  594798.0
# 192 same pitcher:  594798.0
# 193 same pitcher:  594798.0
# 194 same pitcher:  594798.0
# 195 new pitcher: from  594798.0 to  607229.0
# 196 new pitcher: from  607229.0 to  592789.0
# 197 same pitcher:  592789.0
# 198 same pitcher:  592789.0
# 199 same pitcher:  592789.0
# 200 new pitcher: from  592789.0 to  607560.0
# Done merging

# %%
df_b_p_merged_b2.head()
# Out:
#    game_date  inning  outs_when_up                 events     player_name  \
# 0 2019-09-25     4.0           1.0              strikeout    Shane Bieber
# 1 2019-09-25     2.0           1.0  strikeout_double_play    Shane Bieber
# 2 2019-09-25     1.0           0.0               home_run    Shane Bieber
# 3 2019-09-24     5.0           2.0              field_out  Mike Clevinger
# 4 2019-09-24     3.0           2.0                 double  Mike Clevinger
#
#     pitcher  event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  \
# 0  669456.0           0        R               0.26                      0.26
# 1  669456.0           0        R               0.27                      0.26
# 2  669456.0           1        R               0.28                      0.26
# 3  605182.0           0        R               0.27                      0.25
# 4  605182.0           1        R               0.27                      0.25
#
#   prop_events_nback_bs prop_events_sum_nback_bs_L prop_events_sum_nback_bs_R
# 0                 0.28                       0.29                       0.25
# 1                 0.28                       0.29                       0.25
# 2                 0.28                       0.29                       0.25
# 3                 0.26                       0.27                       0.18
# 4                 0.26                       0.27                       0.18

# %% [markdown]
# ## EDA

# %%
# Just do joins on pitcher quality

# %%
# Hitter performance with pitcher historical performance

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.scatter(df_b_p_merged["prop_events_nback_bs"], df_b_p_merged["prop_events_nback"],
               facecolors="none",
    edgecolors="black")
ax1.set_xlabel("OB rate against pitcher")
ax1.set_ylabel("OB rate for batter")

ax2.scatter(df_b_p_merged_b2["prop_events_nback_bs"], df_b_p_merged_b2["prop_events_nback"],
               facecolors="none",
    edgecolors="black")
ax2.set_xlabel("OB rate against pitcher")
ax2.set_ylabel("OB rate for batter")
# Out:
# Text(0, 0.5, 'OB rate for batter')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.scatter(
    df_b_p_merged["prop_events_nback_bs"],
    df_b_p_merged["event_code"] + np.random.normal(0, 0.025, len(df_b_p_merged)),
    facecolors="none",
    edgecolors="black",
)
ax1.set_title("Player 1 (overall)")

ax2.scatter(
    df_b_p_merged_b2["prop_events_nback_bs"],
    df_b_p_merged_b2["event_code"] + np.random.normal(0, 0.025, len(df_b_p_merged_b2)),
    facecolors="none",
    edgecolors="black",
)
ax2.set_title("Player 2 (overall)")
# Out:
# Text(0.5, 1.0, 'Player 1 (overall)')

# %%
# # verify it's not the same data
# f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
# ax1.scatter(
#     df_b_p_merged["prop_events_nback_bs"], df_b_p_merged_b2["prop_events_nback_bs"]
# )

# ax2.scatter(df_b_p_merged["event_code"], df_b_p_merged_b2["event_code"])

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# ### Separate "day of" from "pre-date" data

# %%
df4model_dayof_bpm1 = df_b_p_merged[df_b_p_merged["game_date"] == date_of_interest].copy()
df4model_dayof_bpm1

# %%
df4model_dayof_bpm2 = df4model_b2[df4model_b2["game_date"] == date_of_interest].copy()
df4model_dayof_bpm2

# %%
col4model = ["event_code", "p_throws", "prop_events_nback", "prop_events_sum_nback_pt"]
df4model_b1_lim = df4model_b1.loc[
    df4model_b1["game_date"] < date_of_interest, col4model
].copy()

df4model_b2_lim = df4model_b2.loc[
    df4model_b2["game_date"] < date_of_interest, col4model
].copy()


# df4model_b1_lim = df4model_b1[col4model].copy()
# df4model_b2_lim = df4model_b2[col4model].copy()

# %%
pd.concat([df4model_b1_lim.head(), df4model_b2_lim.head()], axis=1)
# Out:
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  \
# 5           0        R               0.36                      0.41
# 6           0        L               0.37                      0.29
# 7           0        R               0.38                      0.41
# 8           0        R               0.38                      0.41
# 9           0        R               0.39                      0.42
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt
# 5           0        R               0.22                      0.24
# 6           1        R               0.22                      0.23
# 7           0        R               0.22                      0.24
# 8           0        R               0.22                      0.24
# 9           0        R               0.23                      0.24

# %%
# FUNCTION TO REPLACE CATEGORICAL INPUT
df4model_b1_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
df4model_b2_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

# %%
X_train_scale_b1, X_test_scale_b1, y_train_b1, y_test_b1 = get_split_data(
    df4model_b1_lim, 0.4
)
X_train_scale_b2, X_test_scale_b2, y_train_b2, y_test_b2 = get_split_data(
    df4model_b2_lim, 0.4
)

# %%
df_b_p_merged.shape
# Out:
# (201, 7)

# %%
print(X_train_scale_b1.shape, X_test_scale_b1.shape, y_train_b1.shape, y_test_b1.shape)
print(X_train_scale_b2.shape, X_test_scale_b2.shape, y_train_b2.shape, y_test_b2.shape)

# %%
log_reg_p1_wp = LogisticRegression()
log_reg_p1_wp.fit(X_train_scale_p1, y_train_p1)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_p1 = log_reg_p1_wp.predict(X_test_scale_p1)
y_predprob_p1 = log_reg_p1_wp.predict_proba(X_test_scale_p1)[:, 1]

# %%
df_eval_p1 = pd.DataFrame(
    {"test": y_test_p1, "pred": y_pred_p1, "predprob": y_predprob_p1}
)
df_eval_p1.head()
# Out:
#      test  pred  predprob
# 40      1     0  0.315222
# 141     0     0  0.327202
# 33      0     0  0.296921
# 91      1     0  0.466917
# 13      0     0  0.260403

# %%
f, ax1 = plt.subplots()

#
ax1.scatter(
    df_eval_p1["predprob"],
    df_eval_p1["test"] + np.random.normal(0, 0.025, len(df_eval_p1)),
    facecolors="none",
    edgecolors="black",
)

# %%
log_reg_p1_wp.coef_
# Out:
# array([[-0.28088299,  0.06408509,  0.01514172,  0.20912622, -0.30236944,
#         -0.59698024]])

# %%
# print(
#     "low prob, 0: ", ((df_eval_p1["predprob"] < 0.29) & (df_eval_p1["test"] == 0)).sum()
# )
# print(
#     "low prob, 1: ", ((df_eval_p1["predprob"] < 0.29) & (df_eval_p1["test"] == 1)).sum()
# )
# print(
#     "high prob, 0: ",
#     ((df_eval_p1["predprob"] > 0.29) & (df_eval_p1["test"] == 0)).sum(),
# )
# print(
#     "high prob, 1: ",
#     ((df_eval_p1["predprob"] > 0.29) & (df_eval_p1["test"] == 1)).sum(),
# )
# Out:
# low prob, 0:  16
# low prob, 1:  9
# high prob, 0:  24
# high prob, 1:  12

# %%
# The number of right-handed pitchers matches the "high probability"
# X_test_p1["p_throws"].sum()
# Out:
# 48

# %% [markdown]
# # Add pitcher feature - simple

# %%
# # Reynolds (668804, Bryan Reynolds (PIT))
# pid_of_interest1 = 668804

# # Enter key_mlbam (Leury Garcia, ESPN rank 300)
# pid_of_interest2 = 544725

# %%
df_sc_events_b1.head()
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FC 2019-09-25           87.4         2.7441         5.7888
# 1         SI 2019-09-24           94.8         2.6869         6.0305
# 2         CH 2019-09-24           81.0         2.8359         5.4730
# 3         FF 2019-09-24           85.2        -2.5214         5.8412
# 4         CH 2019-09-24           76.7        -2.4278         6.0267
#
#       player_name    batter   pitcher           events          description  \
# 0      Jon Lester  668804.0  452657.0        field_out        hit_into_play
# 1   Derek Holland  668804.0  502706.0        field_out        hit_into_play
# 2   Danny Hultzen  668804.0  543343.0  fielders_choice  hit_into_play_score
# 3  Kyle Hendricks  668804.0  543294.0        field_out        hit_into_play
# 4  Kyle Hendricks  668804.0  543294.0        field_out        hit_into_play
#
#    ... if_fielding_alignment of_fielding_alignment name_last name_first  \
# 0  ...              Standard              Standard  reynolds      bryan
# 1  ...              Standard              Standard  reynolds      bryan
# 2  ...              Standard              Standard  reynolds      bryan
# 3  ...              Standard              Standard  reynolds      bryan
# 4  ...              Standard              Standard  reynolds      bryan
#
#    key_mlbam key_retro  key_bbref key_fangraphs mlb_played_first  \
# 0     668804  reynb001  reynobr01         19326           2019.0
# 1     668804  reynb001  reynobr01         19326           2019.0
# 2     668804  reynb001  reynobr01         19326           2019.0
# 3     668804  reynb001  reynobr01         19326           2019.0
# 4     668804  reynb001  reynobr01         19326           2019.0
#
#   mlb_played_last
# 0          2019.0
# 1          2019.0
# 2          2019.0
# 3          2019.0
# 4          2019.0
#
# [5 rows x 97 columns]

# %%
[print(i) for i in df_pitching_stats19_wpid.columns]
# Out:
# index
# Season
# Name
# Team
# Age
# W
# L
# ERA
# WAR
# G
# GS
# CG
# ShO
# SV
# BS
# IP
# TBF
# H
# R
# ER
# HR
# BB
# IBB
# HBP
# WP
# BK
# SO
# GB
# FB
# LD
# IFFB
# Balls
# Strikes
# Pitches
# RS
# IFH
# BU
# BUH
# K/9
# BB/9
# K/BB
# H/9
# HR/9
# AVG
# WHIP
# BABIP
# LOB_perc
# FIP
# GB/FB
# LD_perc
# GB_perc
# IFFB_perc
# HR/FB
# IFH_perc
# BUH_perc
# Starting
# Start-IP
# Relieving
# Relief-IP
# RAR
# Dollars
# tERA
# xFIP
# WPA
# -WPA
# +WPA
# RE24
# REW
# pLI
# inLI
# gmLI
# exLI
# Pulls
# WPA/LI
# Clutch
# FB_perc
# FBv
# SL_perc
# SLv
# CT_perc
# CTv
# CB_perc
# CBv
# CH_perc
# CHv
# SF_perc
# SFv
# KN_perc
# KNv
# XX_perc
# PO_perc
# wFB
# wSL
# wCT
# wCB
# wCH
# wSF
# wKN
# wFB/C
# wSL/C
# wCT/C
# wCB/C
# wCH/C
# wSF/C
# wKN/C
# O-Swing_perc
# Z-Swing_perc
# Swing_perc
# O-Contact_perc
# Z-Contact_perc
# Contact_perc
# Zone_perc
# F-Strike_perc
# SwStr_perc
# HLD
# SD
# MD
# ERA-
# FIP-
# xFIP-
# K_perc
# BB_perc
# SIERA
# RS/9
# E-F
# FA_perc _pfx
# FT_perc _pfx
# FC_perc _pfx
# FS_perc _pfx
# FO_perc _pfx
# SI_perc _pfx
# SL_perc _pfx
# CU_perc _pfx
# KC_perc _pfx
# EP_perc _pfx
# CH_perc _pfx
# SC_perc _pfx
# KN_perc _pfx
# UN_perc _pfx
# vFA _pfx
# vFT _pfx
# vFC _pfx
# vFS _pfx
# vFO _pfx
# vSI _pfx
# vSL _pfx
# vCU _pfx
# vKC _pfx
# vEP _pfx
# vCH _pfx
# vSC _pfx
# vKN _pfx
# FA-X _pfx
# FT-X _pfx
# FC-X _pfx
# FS-X _pfx
# FO-X _pfx
# SI-X _pfx
# SL-X _pfx
# CU-X _pfx
# KC-X _pfx
# EP-X _pfx
# CH-X _pfx
# SC-X _pfx
# KN-X _pfx
# FA-Z _pfx
# FT-Z _pfx
# FC-Z _pfx
# FS-Z _pfx
# FO-Z _pfx
# SI-Z _pfx
# SL-Z _pfx
# CU-Z _pfx
# KC-Z _pfx
# EP-Z _pfx
# CH-Z _pfx
# SC-Z _pfx
# KN-Z _pfx
# wFA _pfx
# wFT _pfx
# wFC _pfx
# wFS _pfx
# wFO _pfx
# wSI _pfx
# wSL _pfx
# wCU _pfx
# wKC _pfx
# wEP _pfx
# wCH _pfx
# wSC _pfx
# wKN _pfx
# wFA/C _pfx
# wFT/C _pfx
# wFC/C _pfx
# wFS/C _pfx
# wFO/C _pfx
# wSI/C _pfx
# wSL/C _pfx
# wCU/C _pfx
# wKC/C _pfx
# wEP/C _pfx
# wCH/C _pfx
# wSC/C _pfx
# wKN/C _pfx
# O-Swing_perc _pfx
# Z-Swing_perc _pfx
# Swing_perc _pfx
# O-Contact_perc _pfx
# Z-Contact_perc _pfx
# Contact_perc _pfx
# Zone_perc _pfx
# Pace
# RA9-WAR
# BIP-Wins
# LOB-Wins
# FDP-Wins
# Age Rng
# K-BB_perc
# Pull_perc
# Cent_perc
# Oppo_perc
# Soft_perc
# Med_perc
# Hard_perc
# kwERA
# TTO_perc
# CH_perc _pi
# CS_perc _pi
# CU_perc _pi
# FA_perc _pi
# FC_perc _pi
# FS_perc _pi
# KN_perc _pi
# SB_perc _pi
# SI_perc _pi
# SL_perc _pi
# XX_perc _pi
# vCH _pi
# vCS _pi
# vCU _pi
# vFA _pi
# vFC _pi
# vFS _pi
# vKN _pi
# vSB _pi
# vSI _pi
# vSL _pi
# vXX _pi
# CH-X _pi
# CS-X _pi
# CU-X _pi
# FA-X _pi
# FC-X _pi
# FS-X _pi
# KN-X _pi
# SB-X _pi
# SI-X _pi
# SL-X _pi
# XX-X _pi
# CH-Z _pi
# CS-Z _pi
# CU-Z _pi
# FA-Z _pi
# FC-Z _pi
# FS-Z _pi
# KN-Z _pi
# SB-Z _pi
# SI-Z _pi
# SL-Z _pi
# XX-Z _pi
# wCH _pi
# wCS _pi
# wCU _pi
# wFA _pi
# wFC _pi
# wFS _pi
# wKN _pi
# wSB _pi
# wSI _pi
# wSL _pi
# wXX _pi
# wCH/C _pi
# wCS/C _pi
# wCU/C _pi
# wFA/C _pi
# wFC/C _pi
# wFS/C _pi
# wKN/C _pi
# wSB/C _pi
# wSI/C _pi
# wSL/C _pi
# wXX/C _pi
# O-Swing_perc _pi
# Z-Swing_perc _pi
# Swing_perc _pi
# O-Contact_perc _pi
# Z-Contact_perc _pi
# Contact_perc _pi
# Zone_perc _pi
# Pace _pi
# first_name
# last_name
# name_last
# name_first
# key_mlbam
# key_retro
# key_bbref
# key_fangraphs
# mlb_played_first
# mlb_played_last
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
col4pitch2merge = ["Name", "key_mlbam", "WAR", "FIP", "K/9", "BB/9", "H/9", "HR/9"]

# %%
df_sc_events_b1_wp = pd.merge(
    df_sc_events_b1,
    df_pitching_stats19_wpid[col4pitch2merge],
    left_on="pitcher",
    right_on="key_mlbam",
)

# %%
df_sc_events_b1_wp.head(5)
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FC 2019-09-25           87.4         2.7441         5.7888
# 1         FF 2019-09-13           91.5         2.7389         5.5907
# 2         CH 2019-09-13           83.4         2.5857         5.7340
# 3         FC 2019-09-13           89.0         2.6932         5.6271
# 4         FC 2019-08-17           89.5         2.9043         5.5325
#
#   player_name    batter   pitcher     events    description  ...  \
# 0  Jon Lester  668804.0  452657.0  field_out  hit_into_play  ...
# 1  Jon Lester  668804.0  452657.0  strikeout  called_strike  ...
# 2  Jon Lester  668804.0  452657.0  field_out  hit_into_play  ...
# 3  Jon Lester  668804.0  452657.0       walk           ball  ...
# 4  Jon Lester  668804.0  452657.0  strikeout  called_strike  ...
#
#   mlb_played_first mlb_played_last        Name key_mlbam_y  WAR   FIP   K/9  \
# 0           2019.0          2019.0  Jon Lester    452657.0  2.8  4.26  8.65
# 1           2019.0          2019.0  Jon Lester    452657.0  2.8  4.26  8.65
# 2           2019.0          2019.0  Jon Lester    452657.0  2.8  4.26  8.65
# 3           2019.0          2019.0  Jon Lester    452657.0  2.8  4.26  8.65
# 4           2019.0          2019.0  Jon Lester    452657.0  2.8  4.26  8.65
#
#    BB/9    H/9  HR/9
# 0  2.73  10.75  1.36
# 1  2.73  10.75  1.36
# 2  2.73  10.75  1.36
# 3  2.73  10.75  1.36
# 4  2.73  10.75  1.36
#
# [5 rows x 105 columns]

# %%
df_sc_events_b2_wp = pd.merge(
    df_sc_events_b2,
    df_pitching_stats19_wpid[col4pitch2merge],
    left_on="pitcher",
    right_on="key_mlbam",
)

# %%
df_sc_events_b2_wp.head(5)
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         KC 2019-09-25           83.4        -1.4102         5.7922
# 1         SL 2019-09-25           85.6        -1.4502         5.7454
# 2         FF 2019-09-25           94.3        -1.3690         5.8501
# 3         KC 2019-09-04           83.2        -1.3917         5.7539
# 4         KC 2019-09-04           82.5        -1.5268         5.7392
#
#     player_name    batter   pitcher                 events  \
# 0  Shane Bieber  544725.0  669456.0              strikeout
# 1  Shane Bieber  544725.0  669456.0  strikeout_double_play
# 2  Shane Bieber  544725.0  669456.0               home_run
# 3  Shane Bieber  544725.0  669456.0              strikeout
# 4  Shane Bieber  544725.0  669456.0              force_out
#
#                description  ... mlb_played_first mlb_played_last  \
# 0  swinging_strike_blocked  ...           2013.0          2019.0
# 1          swinging_strike  ...           2013.0          2019.0
# 2      hit_into_play_score  ...           2013.0          2019.0
# 3  swinging_strike_blocked  ...           2013.0          2019.0
# 4            hit_into_play  ...           2013.0          2019.0
#
#            Name key_mlbam_y  WAR   FIP    K/9  BB/9   H/9 HR/9
# 0  Shane Bieber    669456.0  5.6  3.32  10.88  1.68  7.81  1.3
# 1  Shane Bieber    669456.0  5.6  3.32  10.88  1.68  7.81  1.3
# 2  Shane Bieber    669456.0  5.6  3.32  10.88  1.68  7.81  1.3
# 3  Shane Bieber    669456.0  5.6  3.32  10.88  1.68  7.81  1.3
# 4  Shane Bieber    669456.0  5.6  3.32  10.88  1.68  7.81  1.3
#
# [5 rows x 105 columns]

# %%
def get_df4model_wp(df, n_back_PA, m_size):
    """
    Function for getting summarized DF
    """
    # sample values -----------
    # n_back_PA = 100
    # df = df_sc_events.copy()
    # pid = pid_of_interest1
    # m_size = 200
    # -------------------------

    # Reset index so that code below works
    df.reset_index(inplace=True)

    # Encode on-base events, including walks
    ob_list = ["walk", "single", "double", "triple", "home_run"]
    df["event_code"] = 0
    df.loc[df["events"].isin(ob_list), "event_code"] = 1

    # Sum of on-base events - critical that order matters! (should be addressed above)
    # rolling was close, but needed to tweak
    df["num_events_sum_nback"] = (
        df["event_code"].iloc[::-1].rolling(n_back_PA).sum().iloc[::-1]
    )

    # Percent of on-base events (overall)
    df["prop_events_nback"] = df["num_events_sum_nback"] / n_back_PA

    # Percent of on-base events against handedness of pitcher
    for i in df.index:
        p_throws = df["p_throws"].iloc[i]  # Get handedness of pitcher
        df_pt_throw = df[df["p_throws"] == p_throws]
        n_pt_events = df_pt_throw["event_code"].iloc[i : i + n_back_PA].sum()
        df.loc[i, "num_events_sum_nback_pt"] = n_pt_events
        df.loc[i, "prop_events_sum_nback_pt"] = n_pt_events / n_back_PA

    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
    ]

    # Pitcher col
    col_p_4model = ["WAR", "FIP", "K/9", "BB/9", "H/9", "HR/9"]

    df_4model = df[col4model + col_p_4model].copy()
    df_4model_overall = df_4model.loc[:m_size]

    df_meta_w_model_overall = pd.merge(
        df[["game_date", "inning", "outs_when_up", "events", "player_name", "pitcher"]],
        df_4model_overall,
        left_index=True,
        right_index=True,
    )

    return df_meta_w_model_overall

# %%
df4model_b1_wp = get_df4model_wp(
    df=df_sc_events_b1_wp.copy(), n_back_PA=100, m_size=200
)

# %%
df4model_b1_wp.head()
# Out:
#    game_date  inning  outs_when_up     events player_name   pitcher  \
# 0 2019-09-25     1.0           1.0  field_out  Jon Lester  452657.0
# 1 2019-09-13     4.0           2.0  strikeout  Jon Lester  452657.0
# 2 2019-09-13     2.0           1.0  field_out  Jon Lester  452657.0
# 3 2019-09-13     1.0           0.0       walk  Jon Lester  452657.0
# 4 2019-08-17     5.0           1.0  strikeout  Jon Lester  452657.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  WAR  \
# 0           0        L               0.26                      0.27  2.8
# 1           0        L               0.26                      0.27  2.8
# 2           0        L               0.26                      0.27  2.8
# 3           1        L               0.27                      0.27  2.8
# 4           0        L               0.26                      0.27  2.8
#
#     FIP   K/9  BB/9    H/9  HR/9
# 0  4.26  8.65  2.73  10.75  1.36
# 1  4.26  8.65  2.73  10.75  1.36
# 2  4.26  8.65  2.73  10.75  1.36
# 3  4.26  8.65  2.73  10.75  1.36
# 4  4.26  8.65  2.73  10.75  1.36

# %%
df4model_b2_wp = get_df4model_wp(
    df=df_sc_events_b2_wp.copy(), n_back_PA=100, m_size=200
)

# %%
df4model_b2_wp.head()
# Out:
#    game_date  inning  outs_when_up                 events   player_name  \
# 0 2019-09-25     4.0           1.0              strikeout  Shane Bieber
# 1 2019-09-25     2.0           1.0  strikeout_double_play  Shane Bieber
# 2 2019-09-25     1.0           0.0               home_run  Shane Bieber
# 3 2019-09-04     7.0           2.0              strikeout  Shane Bieber
# 4 2019-09-04     5.0           0.0              force_out  Shane Bieber
#
#     pitcher  event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  \
# 0  669456.0           0        R               0.30                      0.24
# 1  669456.0           0        R               0.30                      0.24
# 2  669456.0           1        R               0.31                      0.24
# 3  669456.0           0        R               0.30                      0.24
# 4  669456.0           0        R               0.30                      0.25
#
#    WAR   FIP    K/9  BB/9   H/9  HR/9
# 0  5.6  3.32  10.88  1.68  7.81   1.3
# 1  5.6  3.32  10.88  1.68  7.81   1.3
# 2  5.6  3.32  10.88  1.68  7.81   1.3
# 3  5.6  3.32  10.88  1.68  7.81   1.3
# 4  5.6  3.32  10.88  1.68  7.81   1.3

# %% [markdown]
# ## EDA
#
# - Are bad pitchers more likely to allow someone to get on base?

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.scatter(
    df4model_b1_wp["WAR"],
    df4model_b1_wp["event_code"] + np.random.normal(0, 0.025, len(df4model_b1)),
    facecolors="none",
    edgecolors="black",
)
ax1.set_title("Player 1 (overall)")
ax1.set_xlabel("pitcher WAR")

ax2.scatter(
    df4model_b2_wp["WAR"],
    df4model_b2_wp["event_code"] + np.random.normal(0, 0.025, len(df4model_b2)),
    facecolors="none",
    edgecolors="black",
)
ax2.set_title("Player 2 (overall)")
ax2.set_xlabel("pitcher WAR")
# Out:
# Text(0.5, 0, 'pitcher WAR')

# %% [markdown]
# ## Logistic regression

# %% [markdown]
# ### Separate "day of" rows

# %%
date_of_interest
# Out:
# "'2019-09-25'"

# %%
df4model_b1_wp_dayof = df4model_b1_wp[
    df4model_b1_wp["game_date"] == date_of_interest
].copy()
df4model_b1_wp_dayof
# Out:
#    game_date  inning  outs_when_up     events player_name   pitcher  \
# 0 2019-09-25     1.0           1.0  field_out  Jon Lester  452657.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  WAR  \
# 0           0        L               0.26                      0.27  2.8
#
#     FIP   K/9  BB/9    H/9  HR/9
# 0  4.26  8.65  2.73  10.75  1.36

# %%
df4model_b2_wp_dayof = df4model_b2_wp[
    df4model_b2_wp["game_date"] == date_of_interest
].copy()
df4model_b2_wp_dayof
# Out:
#    game_date  inning  outs_when_up                 events   player_name  \
# 0 2019-09-25     4.0           1.0              strikeout  Shane Bieber
# 1 2019-09-25     2.0           1.0  strikeout_double_play  Shane Bieber
# 2 2019-09-25     1.0           0.0               home_run  Shane Bieber
#
#     pitcher  event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  \
# 0  669456.0           0        R               0.30                      0.24
# 1  669456.0           0        R               0.30                      0.24
# 2  669456.0           1        R               0.31                      0.24
#
#    WAR   FIP    K/9  BB/9   H/9  HR/9
# 0  5.6  3.32  10.88  1.68  7.81   1.3
# 1  5.6  3.32  10.88  1.68  7.81   1.3
# 2  5.6  3.32  10.88  1.68  7.81   1.3

# %%
col4model = ["event_code", "p_throws", "prop_events_nback", "prop_events_sum_nback_pt", 'WAR', 'FIP', 'K/9', 'BB/9', 'H/9', 'HR/9']

df4model_b1_wp_lim = df4model_b1_wp.loc[
    df4model_b1["game_date"] < date_of_interest, col4model
].copy()

df4model_b2_wp_lim = df4model_b2_wp.loc[
    df4model_b2_wp["game_date"] < date_of_interest, col4model
].copy()

# %%
# FUNCTION TO REPLACE CATEGORICAL INPUT
df4model_b1_wp_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
df4model_b2_wp_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

# %% [markdown]
# ### Split and run model

# %%
X_train_scale_b1, X_test_scale_b1, y_train_b1, y_test_b1 = get_split_data(
    df4model_b1_wp_lim, 0.4
)
X_train_scale_b2, X_test_scale_b2, y_train_b2, y_test_b2 = get_split_data(
    df4model_b2_wp_lim, 0.4
)

# %%
print(X_train_scale_b1.shape, X_test_scale_b1.shape, y_train_b1.shape, y_test_b1.shape)
print(X_train_scale_b2.shape, X_test_scale_b2.shape, y_train_b2.shape, y_test_b2.shape)
# Out:
# (120, 9) (80, 9) (120,) (80,)
# (118, 9) (80, 9) (118,) (80,)

# %%
log_reg_b1_wps = LogisticRegression()
log_reg_b1_wps.fit(X_train_scale_b1, y_train_b1)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_b1 = log_reg_b1_wps.predict(X_test_scale_b1)
y_predprob_b1 = log_reg_b1_wps.predict_proba(X_test_scale_b1)[:, 1]

# %%
df_eval_b1 = pd.DataFrame(
    {"test": y_test_b1, "pred": y_pred_b1, "predprob": y_predprob_b1}
)
df_eval_b1.head()
# Out:
#      test  pred  predprob
# 41      1     0  0.285650
# 141     0     0  0.289125
# 34      0     0  0.097618
# 92      1     0  0.156098
# 14      0     0  0.123454

# %%
f, ax1 = plt.subplots()

ax1.scatter(
    df_eval_b1["predprob"],
    df_eval_b1["test"] + np.random.normal(0, 0.025, len(df_eval_b1)),
    facecolors="none",
    edgecolors="black",
)

# %%
log_reg_b2_wps = LogisticRegression()
log_reg_b2_wps.fit(X_train_scale_b2, y_train_b2)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_b2 = log_reg_b2_wps.predict(X_test_scale_b2)
y_predprob_b2 = log_reg_b2_wps.predict_proba(X_test_scale_b2)[:, 1]

# %%
df_eval_b2 = pd.DataFrame(
    {"test": y_test_b2, "pred": y_pred_b2, "predprob": y_predprob_b2}
)
df_eval_b2.head()
# Out:
#      test  pred  predprob
# 34      0     0  0.197808
# 78      1     0  0.325605
# 149     0     0  0.237386
# 40      0     0  0.110332
# 85      1     0  0.205866

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.scatter(
    df_eval_b2["predprob"],
    df_eval_b2["test"] + np.random.normal(0, 0.025, len(df_eval_b2)),
    facecolors="none",
    edgecolors="black",
)

ax2.scatter(
    df_eval_b2["predprob"],
    df_eval_b2["test"] + np.random.normal(0, 0.025, len(df_eval_b2)),
    facecolors="none",
    edgecolors="black",
)

# %%
df4model_b1_wp_lim.head()
# Out:
#    event_code  p_throws  prop_events_nback  prop_events_sum_nback_pt  WAR  \
# 1           0         0               0.26                      0.27  2.8
# 2           0         0               0.26                      0.27  2.8
# 3           1         0               0.27                      0.27  2.8
# 4           0         0               0.26                      0.27  2.8
# 5           0         0               0.26                      0.27  2.8
#
#     FIP   K/9  BB/9    H/9  HR/9
# 1  4.26  8.65  2.73  10.75  1.36
# 2  4.26  8.65  2.73  10.75  1.36
# 3  4.26  8.65  2.73  10.75  1.36
# 4  4.26  8.65  2.73  10.75  1.36
# 5  4.26  8.65  2.73  10.75  1.36

# %%
df4model_b1_wp.head()
# Out:
#    game_date  inning  outs_when_up     events player_name   pitcher  \
# 0 2019-09-25     1.0           1.0  field_out  Jon Lester  452657.0
# 1 2019-09-13     4.0           2.0  strikeout  Jon Lester  452657.0
# 2 2019-09-13     2.0           1.0  field_out  Jon Lester  452657.0
# 3 2019-09-13     1.0           0.0       walk  Jon Lester  452657.0
# 4 2019-08-17     5.0           1.0  strikeout  Jon Lester  452657.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  WAR  \
# 0           0        L               0.26                      0.27  2.8
# 1           0        L               0.26                      0.27  2.8
# 2           0        L               0.26                      0.27  2.8
# 3           1        L               0.27                      0.27  2.8
# 4           0        L               0.26                      0.27  2.8
#
#     FIP   K/9  BB/9    H/9  HR/9
# 0  4.26  8.65  2.73  10.75  1.36
# 1  4.26  8.65  2.73  10.75  1.36
# 2  4.26  8.65  2.73  10.75  1.36
# 3  4.26  8.65  2.73  10.75  1.36
# 4  4.26  8.65  2.73  10.75  1.36

# %% [markdown]
# ## Output for new case

# %%
def get_df_ab_vs_startingp(df_day_of):
    # Get up to last 5 at-bats for the input
    df_day_of_last5 = df_day_of.loc[-5:, :]

    # Get starting opposing pitcher
    startingp = df_day_of_last5["pitcher"].iloc[-1]

    # Limit ab to those against that pithcer
    df_day_of_last5_vs_startingp = df_day_of_last5[
        df_day_of_last5["pitcher"] == startingp
    ].copy()

    # replace categorical input
    df_day_of_last5_vs_startingp["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

    return df_day_of_last5_vs_startingp

# %%
df4model_b1_wp_dayof_sp = get_df_ab_vs_startingp(df4model_b1_wp_dayof)
df4model_b1_wp_dayof_sp
# Out:
#    game_date  inning  outs_when_up     events player_name   pitcher  \
# 0 2019-09-25     1.0           1.0  field_out  Jon Lester  452657.0
#
#    event_code p_throws  prop_events_nback  prop_events_sum_nback_pt  WAR  \
# 0           0        0               0.26                      0.27  2.8
#
#     FIP   K/9  BB/9    H/9  HR/9
# 0  4.26  8.65  2.73  10.75  1.36

# %%
df4model_b2_wp_dayof_sp = get_df_ab_vs_startingp(df4model_b2_wp_dayof)
df4model_b2_wp_dayof_sp
# Out:
#    game_date  inning  outs_when_up                 events   player_name  \
# 0 2019-09-25     4.0           1.0              strikeout  Shane Bieber
# 1 2019-09-25     2.0           1.0  strikeout_double_play  Shane Bieber
# 2 2019-09-25     1.0           0.0               home_run  Shane Bieber
#
#     pitcher  event_code  p_throws  prop_events_nback  \
# 0  669456.0           0         1               0.30
# 1  669456.0           0         1               0.30
# 2  669456.0           1         1               0.31
#
#    prop_events_sum_nback_pt  WAR   FIP    K/9  BB/9   H/9  HR/9
# 0                      0.24  5.6  3.32  10.88  1.68  7.81   1.3
# 1                      0.24  5.6  3.32  10.88  1.68  7.81   1.3
# 2                      0.24  5.6  3.32  10.88  1.68  7.81   1.3

# %%
col4model = [
    "event_code",
    "p_throws",
    "prop_events_nback",
    "prop_events_sum_nback_pt",
    "WAR",
    "FIP",
    "K/9",
    "BB/9",
    "H/9",
    "HR/9",
]

df4model_b1_wp_dayof_sp_lim = df4model_b1_wp_dayof_sp.loc[:, col4model].copy()
df4model_b2_wp_dayof_sp_lim = df4model_b2_wp_dayof_sp.loc[:, col4model].copy()

# %%
def return_series_of_player_prediction_counts(
    df4model_dayof_b1, df4model_dayof_b2, log_reg_b1, log_reg_b2
):
    s_new_case = pd.Series()

    # actual performance
    s_new_case["actual_performance_batterA"] = df4model_dayof_b1.reset_index()[
        "event_code"
    ].sum()
    s_new_case["actual_performance_batterB"] = df4model_dayof_b2.reset_index()[
        "event_code"
    ].sum()

    # ADD VARIANCE - TBD
    s_new_case["pred_var_batterA"] = None
    s_new_case["pred_var_batterB"] = None

    # vs actual pitcher
    s_new_case["pred_vs_gamepitcher_batterA"] = log_reg_b1.predict_proba(
        df4model_dayof_b1.iloc[:, 1:]
    )[:, 1].mean()

    s_new_case["pred_vs_gamepitcher_batterB"] = log_reg_b2.predict_proba(
        df4model_dayof_b2.iloc[:, 1:]
    )[:, 1].mean()

    # Prediction
    if (
        s_new_case["pred_vs_gamepitcher_batterA"]
        > s_new_case["pred_vs_gamepitcher_batterB"]
    ):
        predict_for_day = "A"
    elif (
        s_new_case["pred_vs_gamepitcher_batterA"]
        == s_new_case["pred_vs_gamepitcher_batterB"]
    ):
        predict_for_day = "even"
    else:
        predict_for_day = "B"

    # Actual case
    if (
        s_new_case["actual_performance_batterA"]
        > s_new_case["actual_performance_batterB"]
    ):
        actual_for_day = "A"

    elif (
        s_new_case["actual_performance_batterA"]
        == s_new_case["actual_performance_batterB"]
    ):
        actual_for_day = "even"
    else:
        actual_for_day = "B"

    validation_entries = (
        date_of_interest,
        pid_of_interest1,
        pid_of_interest2,
        predict_for_day,
        actual_for_day,
    )

    return s_new_case, validation_entries

# %%
# Look at variance of prediction

# %% [markdown]
# ## VALIDATION with multiple dates

# %% [markdown]
# ### Easy case

# %%
# Betts and Garcia (668804, 544725)

pid1 = 605141
pid2 = 544725

# (20ish dates)
date_list = [
    "'2019-08-05'",
    "'2019-08-06'",
    "'2019-08-07'",
    "'2019-08-09'",
    "'2019-08-10'",
    "'2019-08-16'",
    "'2019-08-17'",
    "'2019-08-18'",
    "'2019-08-20'",
    "'2019-08-21'",
    "'2019-08-23'",
    "'2019-08-24'",
    "'2019-08-25'",
    "'2019-08-27'",
    "'2019-08-28'",
    "'2019-08-30'",
    "'2019-08-31'",
    "'2019-09-01'",
    "'2019-09-03'",
    "'2019-09-04'",
    "'2019-09-10'",
    "'2019-09-12'",
    "'2019-09-21'",
    "'2019-09-24'",
]


# # (12 dates)
# date_list = [
#     "'2019-08-25'",
#     "'2019-08-27'",
#     "'2019-08-28'",
#     "'2019-08-30'",
#     "'2019-08-31'",
#     "'2019-09-01'",
#     "'2019-09-03'",
#     "'2019-09-04'",
#     "'2019-09-10'",
#     "'2019-09-12'",
#     "'2019-09-21'",
#     "'2019-09-24'",
# ]

no_total_ab_events = 1000

# GOAL
# Tabulate the prediction and the actual performance
# prediction A, prediction B, performance A, performance B

df_player1_coef = pd.DataFrame()
df_player2_coef = pd.DataFrame()
df_pred_actual_bydate = pd.DataFrame()
df_pred_actual_bydate_detail = pd.DataFrame()


for date_of_interest in date_list:

    print(date_of_interest)

    # Input batters, date
    df_sc_events_b1 = get_sc_batter_df(pid1, date_of_interest, 1000)
    df_sc_events_b2 = get_sc_batter_df(pid2, date_of_interest, 1000)

    # Add pitcher features
    col4pitch2merge = ["Name", "key_mlbam", "WAR", "FIP", "K/9", "BB/9", "H/9", "HR/9"]
    df_sc_events_b1_wp = pd.merge(
        df_sc_events_b1,
        df_pitching_stats19_wpid[col4pitch2merge],
        left_on="pitcher",
        right_on="key_mlbam",
    )

    df_sc_events_b2_wp = pd.merge(
        df_sc_events_b2,
        df_pitching_stats19_wpid[col4pitch2merge],
        left_on="pitcher",
        right_on="key_mlbam",
    )

    # Build model dataframe
    df4model_b1_wp = get_df4model_wp(
        df=df_sc_events_b1_wp.copy(), n_back_PA=100, m_size=200
    )
    df4model_b2_wp = get_df4model_wp(
        df=df_sc_events_b2_wp.copy(), n_back_PA=100, m_size=200
    )

    # Separate "day of" from "pre-date"
    df4model_b1_wp_dayof = df4model_b1_wp[
        df4model_b1_wp["game_date"] == date_of_interest
    ].copy()
    df4model_b2_wp_dayof = df4model_b2_wp[
        df4model_b2_wp["game_date"] == date_of_interest
    ].copy()

    # Format dataframe for model
    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
        "WAR",
        "FIP",
        "K/9",
        "BB/9",
        "H/9",
        "HR/9",
    ]

    df4model_b1_wp_lim = df4model_b1_wp.loc[
        df4model_b1_wp["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b2_wp_lim = df4model_b2_wp.loc[
        df4model_b2_wp["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b1_wp_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
    df4model_b2_wp_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

    # Split data
    X_train_scale_b1, X_test_scale_b1, y_train_b1, y_test_b1 = get_split_data(
        df4model_b1_wp_lim, 0.4
    )
    X_train_scale_b2, X_test_scale_b2, y_train_b2, y_test_b2 = get_split_data(
        df4model_b2_wp_lim, 0.4
    )

    # Run models
    log_reg_b1, df_eval_b1 = run_logreg_model(
        X_train_scale_b1, y_train_b1, X_test_scale_b1, y_test_b1
    )

    log_reg_b2, df_eval_b2 = run_logreg_model(
        X_train_scale_b2, y_train_b2, X_test_scale_b2, y_test_b2
    )

    #     print("Player 1 coefficients: ", log_reg_b1.coef_)
    #     print(
    #         colored("perc. RHP: " + str(df4model_b1_wp_lim["p_throws"].sum() / 200), "red")
    #     )
    #     print("Player 2 coefficients: ", log_reg_b2.coef_)
    #     print(
    #         colored("perc. RHP: " + str(df4model_b2_wp_lim["p_throws"].sum() / 200), "red")
    #     )

    # Assess day of performance  ---------
    # Get at-bats against first pitcher
    df4model_b1_wp_dayof_sp = get_df_ab_vs_startingp(df4model_b1_wp_dayof)
    df4model_b2_wp_dayof_sp = get_df_ab_vs_startingp(df4model_b2_wp_dayof)

    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
        "WAR",
        "FIP",
        "K/9",
        "BB/9",
        "H/9",
        "HR/9",
    ]

    df4model_b1_wp_dayof_sp_lim = df4model_b1_wp_dayof_sp.loc[:, col4model].copy()
    df4model_b2_wp_dayof_sp_lim = df4model_b2_wp_dayof_sp.loc[:, col4model].copy()

    # Return series of player prediction counts

    df_pred_actual, val_entries = return_series_of_player_prediction_counts(
        df4model_b1_wp_dayof_sp_lim,
        df4model_b2_wp_dayof_sp_lim,
        log_reg_b1_wps,
        log_reg_b2_wps,
    )

    colname = "A_vs_B_" + str(date_of_interest).strip("'")
    df_pred_actual_bydate[colname] = [i for i in val_entries]

    df_pred_actual_bydate.index = [
        "game_date",
        "key_batterA",
        "key_batterB",
        "prediction",
        "actual",
    ]

    df_pred_actual_bydate_detail[colname] = df_pred_actual

    # Coefficients
    colname = "PlayerA_" + str(date_of_interest).strip("'")
    df_player1_coef[colname] = log_reg_b1.coef_[0]
    df_player1_coef.index = df4model_b1_wp_lim.columns[1:]
    colname = "PlayerB_" + str(date_of_interest).strip("'")
    df_player2_coef[colname] = log_reg_b2.coef_[0]
    df_player2_coef.index = df4model_b2_wp_lim.columns[1:]

    if date_of_interest == date_list[-1]:
        print("done getting dates")
# Out:
# '2019-08-05'
# '2019-08-06'
# '2019-08-07'
# '2019-08-09'
# '2019-08-10'
# '2019-08-16'
# '2019-08-17'
# '2019-08-18'
# '2019-08-20'
# '2019-08-21'
# '2019-08-23'
# '2019-08-24'
# '2019-08-25'
# '2019-08-27'
# '2019-08-28'
# '2019-08-30'
# '2019-08-31'
# '2019-09-01'
# '2019-09-03'
# '2019-09-04'
# '2019-09-10'
# '2019-09-12'
# '2019-09-21'
# '2019-09-24'
# done getting dates

# %%
df_pred_actual_bydate_detail
# Out:
#                             A_vs_B_2019-08-05 A_vs_B_2019-08-06  \
# actual_performance_batterA                  1                 1
# actual_performance_batterB                  0                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00979079         0.0035043
# pred_vs_gamepitcher_batterB       0.000901451        0.00160232
#
#                             A_vs_B_2019-08-07 A_vs_B_2019-08-09  \
# actual_performance_batterA                  2                 2
# actual_performance_batterB                  0                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA         0.0255779        0.00996721
# pred_vs_gamepitcher_batterB       0.000911455        0.00242629
#
#                             A_vs_B_2019-08-10 A_vs_B_2019-08-16  \
# actual_performance_batterA                  1                 1
# actual_performance_batterB                  0                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00116124         0.0114099
# pred_vs_gamepitcher_batterB       0.000861417        0.00103315
#
#                             A_vs_B_2019-08-17 A_vs_B_2019-08-18  \
# actual_performance_batterA                  2                 1
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA         0.0044869         0.0099223
# pred_vs_gamepitcher_batterB        0.00104088        0.00116427
#
#                             A_vs_B_2019-08-20 A_vs_B_2019-08-21  ...  \
# actual_performance_batterA                  1                 1  ...
# actual_performance_batterB                  1                 2  ...
# pred_var_batterA                         None              None  ...
# pred_var_batterB                         None              None  ...
# pred_vs_gamepitcher_batterA       0.000947715         0.0042905  ...
# pred_vs_gamepitcher_batterB        0.00171282        0.00169803  ...
#
#                             A_vs_B_2019-08-28 A_vs_B_2019-08-30  \
# actual_performance_batterA                  1                 2
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA         0.0167007         0.0080758
# pred_vs_gamepitcher_batterB        0.00172662        0.00138525
#
#                             A_vs_B_2019-08-31 A_vs_B_2019-09-01  \
# actual_performance_batterA                  2                 1
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA          0.011601         0.0011516
# pred_vs_gamepitcher_batterB        0.00140436        0.00129422
#
#                             A_vs_B_2019-09-03 A_vs_B_2019-09-04  \
# actual_performance_batterA                  0                 3
# actual_performance_batterB                  0                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00655838        0.00109063
# pred_vs_gamepitcher_batterB        0.00190223        0.00249377
#
#                             A_vs_B_2019-09-10 A_vs_B_2019-09-12  \
# actual_performance_batterA                  0                 1
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00350085         0.0165423
# pred_vs_gamepitcher_batterB       0.000773826       0.000688593
#
#                             A_vs_B_2019-09-21 A_vs_B_2019-09-24
# actual_performance_batterA                  1                 0
# actual_performance_batterB                  1                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA       0.000911834         0.0204884
# pred_vs_gamepitcher_batterB       0.000898512        0.00196865
#
# [6 rows x 24 columns]

# %%
df_pred_actual_bydate
# Out:
#             A_vs_B_2019-08-05 A_vs_B_2019-08-06 A_vs_B_2019-08-07  \
# game_date        '2019-08-05'      '2019-08-06'      '2019-08-07'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      A                 A                 A
#
#             A_vs_B_2019-08-09 A_vs_B_2019-08-10 A_vs_B_2019-08-16  \
# game_date        '2019-08-09'      '2019-08-10'      '2019-08-16'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      A                 A              even
#
#             A_vs_B_2019-08-17 A_vs_B_2019-08-18 A_vs_B_2019-08-20  \
# game_date        '2019-08-17'      '2019-08-18'      '2019-08-20'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 B
# actual                      A                 A              even
#
#             A_vs_B_2019-08-21  ... A_vs_B_2019-08-28 A_vs_B_2019-08-30  \
# game_date        '2019-08-21'  ...      '2019-08-28'      '2019-08-30'
# key_batterA            668804  ...            668804            668804
# key_batterB            544725  ...            544725            544725
# prediction                  A  ...                 A                 A
# actual                      B  ...              even                 A
#
#             A_vs_B_2019-08-31 A_vs_B_2019-09-01 A_vs_B_2019-09-03  \
# game_date        '2019-08-31'      '2019-09-01'      '2019-09-03'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 B                 A
# actual                      A                 A              even
#
#             A_vs_B_2019-09-04 A_vs_B_2019-09-10 A_vs_B_2019-09-12  \
# game_date        '2019-09-04'      '2019-09-10'      '2019-09-12'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  B                 A                 A
# actual                      A                 B                 A
#
#             A_vs_B_2019-09-21 A_vs_B_2019-09-24
# game_date        '2019-09-21'      '2019-09-24'
# key_batterA            668804            668804
# key_batterB            544725            544725
# prediction                  A                 A
# actual                   even                 B
#
# [5 rows x 24 columns]

# %%
df_player1_coef
# Out:
#                           PlayerA_2019-08-05  PlayerA_2019-08-06  \
# p_throws                            0.151500            0.083363
# prop_events_nback                   0.111550           -0.000232
# prop_events_sum_nback_pt           -0.088036            0.236166
# WAR                                 0.002715           -0.133825
# FIP                                -0.361379           -0.475387
# K/9                                -0.058741           -0.066310
# BB/9                                0.462258            0.297799
# H/9                                -0.173032           -0.049079
# HR/9                                0.257105            0.150465
#
#                           PlayerA_2019-08-07  PlayerA_2019-08-09  \
# p_throws                            0.317408            0.450145
# prop_events_nback                   0.269909            0.222501
# prop_events_sum_nback_pt           -0.113138           -0.454966
# WAR                                -0.027082            0.561632
# FIP                                -0.116262           -0.017919
# K/9                                -0.072562           -0.226234
# BB/9                                0.412484            0.279004
# H/9                                 0.031971            0.011440
# HR/9                               -0.255438            0.043391
#
#                           PlayerA_2019-08-10  PlayerA_2019-08-16  \
# p_throws                            0.764716           -0.112756
# prop_events_nback                   0.328365           -0.072402
# prop_events_sum_nback_pt           -0.594090           -0.216223
# WAR                                 0.214071           -0.177572
# FIP                                 0.043510            0.133407
# K/9                                -0.294485            0.738282
# BB/9                                0.532365            0.391083
# H/9                                -0.177470            0.011856
# HR/9                               -0.043991            0.164919
#
#                           PlayerA_2019-08-17  PlayerA_2019-08-18  \
# p_throws                           -0.028536           -0.327588
# prop_events_nback                   0.064005           -0.464709
# prop_events_sum_nback_pt           -0.103758           -0.219670
# WAR                                 0.172304           -0.309229
# FIP                                 0.140570            0.060465
# K/9                                 0.407910            0.701705
# BB/9                                0.386439            0.329603
# H/9                                 0.009735           -0.043453
# HR/9                                0.162198            0.209124
#
#                           PlayerA_2019-08-20  PlayerA_2019-08-21  ...  \
# p_throws                           -0.408769           -0.509686  ...
# prop_events_nback                  -0.137014           -0.030761  ...
# prop_events_sum_nback_pt           -0.095350            0.162668  ...
# WAR                                -0.839500           -0.511570  ...
# FIP                                -0.030773            0.414670  ...
# K/9                                 0.655843            0.687638  ...
# BB/9                                0.045029            0.125307  ...
# H/9                                -0.355242           -0.463016  ...
# HR/9                                0.128830            0.242883  ...
#
#                           PlayerA_2019-08-28  PlayerA_2019-08-30  \
# p_throws                           -0.288767           -0.246023
# prop_events_nback                  -0.059950           -0.224971
# prop_events_sum_nback_pt           -0.101329            0.017909
# WAR                                -0.276942           -0.211370
# FIP                                 0.198182            0.397292
# K/9                                 0.675136            0.597569
# BB/9                               -0.255268            0.206332
# H/9                                 0.104898           -0.093373
# HR/9                                0.154080           -0.171244
#
#                           PlayerA_2019-08-31  PlayerA_2019-09-01  \
# p_throws                           -0.537094           -0.311087
# prop_events_nback                  -0.270906           -0.007830
# prop_events_sum_nback_pt           -0.205276            0.131277
# WAR                                -0.528318           -0.550445
# FIP                                -0.067362            0.286577
# K/9                                 0.421885            0.481154
# BB/9                               -0.406817           -0.182075
# H/9                                -0.230267           -0.414114
# HR/9                                0.340673            0.086921
#
#                           PlayerA_2019-09-03  PlayerA_2019-09-04  \
# p_throws                           -0.551889           -0.606954
# prop_events_nback                  -0.046809            0.301403
# prop_events_sum_nback_pt            0.213977            0.208667
# WAR                                -0.207859            0.021108
# FIP                                 0.113759            0.162402
# K/9                                 0.618029            0.051844
# BB/9                               -0.042269           -0.025482
# H/9                                -0.081545           -0.236414
# HR/9                                0.258677            0.176369
#
#                           PlayerA_2019-09-10  PlayerA_2019-09-12  \
# p_throws                            0.016958           -0.246442
# prop_events_nback                   0.413694            0.364174
# prop_events_sum_nback_pt           -0.016881           -0.056614
# WAR                                 0.282297            0.008411
# FIP                                -0.033034           -0.149713
# K/9                                -0.577392           -0.428573
# BB/9                               -0.003063           -0.097484
# H/9                                 0.007069           -0.087060
# HR/9                               -0.269030           -0.012638
#
#                           PlayerA_2019-09-21  PlayerA_2019-09-24
# p_throws                           -0.016200           -0.156639
# prop_events_nback                   0.252731            0.581519
# prop_events_sum_nback_pt           -0.184640           -0.452475
# WAR                                 0.087836           -0.179335
# FIP                                -0.196715           -0.660921
# K/9                                 0.103482           -0.261312
# BB/9                               -0.056370            0.055584
# H/9                                 0.417835            0.071181
# HR/9                               -0.197203            0.198290
#
# [9 rows x 24 columns]

# %%
df_player2_coef
# Out:
#                           PlayerB_2019-08-05  PlayerB_2019-08-06  \
# p_throws                           -0.159734            0.168425
# prop_events_nback                   0.352738            0.534147
# prop_events_sum_nback_pt           -0.216620            0.331290
# WAR                                 0.156948            0.007244
# FIP                                -0.131659           -0.194384
# K/9                                -0.228874           -0.097084
# BB/9                                0.367046            0.069881
# H/9                                -0.048571            0.294537
# HR/9                                0.005521            0.290114
#
#                           PlayerB_2019-08-07  PlayerB_2019-08-09  \
# p_throws                            0.053448           -0.302823
# prop_events_nback                   0.319624            0.446627
# prop_events_sum_nback_pt            0.157505           -0.032668
# WAR                                -0.011537           -0.109462
# FIP                                -0.257982           -0.444602
# K/9                                -0.268433            0.024653
# BB/9                                0.139056            0.079165
# H/9                                -0.049966           -0.132286
# HR/9                                0.260040            0.182712
#
#                           PlayerB_2019-08-10  PlayerB_2019-08-16  \
# p_throws                           -0.190940           -0.248984
# prop_events_nback                  -0.155405            0.878005
# prop_events_sum_nback_pt           -0.159462            0.094955
# WAR                                -0.037778            0.144758
# FIP                                -0.128927           -0.394380
# K/9                                 0.061700           -0.412154
# BB/9                               -0.043112            0.355730
# H/9                                 0.355480            0.187403
# HR/9                                0.056311            0.488232
#
#                           PlayerB_2019-08-17  PlayerB_2019-08-18  \
# p_throws                           -0.293359           -0.265918
# prop_events_nback                   0.622981            0.476453
# prop_events_sum_nback_pt            0.203337           -0.024123
# WAR                                 0.229503           -0.082944
# FIP                                -0.080961           -0.335932
# K/9                                -0.215582           -0.118653
# BB/9                                0.232510            0.131986
# H/9                                -0.047102           -0.255306
# HR/9                                0.529779            0.218419
#
#                           PlayerB_2019-08-20  PlayerB_2019-08-21  ...  \
# p_throws                           -0.311312           -0.367694  ...
# prop_events_nback                   0.386934            0.411467  ...
# prop_events_sum_nback_pt           -0.349857           -0.136359  ...
# WAR                                -0.223099            0.109918  ...
# FIP                                -0.477198           -0.531311  ...
# K/9                                -0.348529           -0.167405  ...
# BB/9                                0.060924            0.149797  ...
# H/9                                -0.348814           -0.141317  ...
# HR/9                               -0.103288            0.317852  ...
#
#                           PlayerB_2019-08-28  PlayerB_2019-08-30  \
# p_throws                           -0.631299           -0.591448
# prop_events_nback                   0.301367            0.430914
# prop_events_sum_nback_pt           -0.526610           -0.391056
# WAR                                 0.618154            0.509239
# FIP                                -0.237494            0.008508
# K/9                                -0.210464           -0.203400
# BB/9                                0.212321            0.503487
# H/9                                -0.240663           -0.381920
# HR/9                                0.400476            0.005505
#
#                           PlayerB_2019-08-31  PlayerB_2019-09-01  \
# p_throws                           -0.477829           -0.195099
# prop_events_nback                   0.659678            0.347793
# prop_events_sum_nback_pt           -0.722762           -0.372282
# WAR                                 0.161554            0.739938
# FIP                                -0.371945           -0.078956
# K/9                                -0.325037           -0.324914
# BB/9                                0.139587            0.299229
# H/9                                 0.018177           -0.110162
# HR/9                                0.119245            0.357333
#
#                           PlayerB_2019-09-03  PlayerB_2019-09-04  \
# p_throws                            0.148615            0.355802
# prop_events_nback                   0.249765            0.474150
# prop_events_sum_nback_pt            0.130661           -0.425447
# WAR                                 0.284367            0.282187
# FIP                                -0.466624           -0.022848
# K/9                                -0.101731            0.137892
# BB/9                                0.174125            0.255161
# H/9                                -0.162543            0.225578
# HR/9                                0.227969            0.274829
#
#                           PlayerB_2019-09-10  PlayerB_2019-09-12  \
# p_throws                            0.287138            0.287866
# prop_events_nback                   0.485921            0.733203
# prop_events_sum_nback_pt           -0.142086           -0.659062
# WAR                                 0.055079           -0.239467
# FIP                                -0.315983           -0.319783
# K/9                                -0.067129            0.079845
# BB/9                                0.117162           -0.024788
# H/9                                 0.049232           -0.332886
# HR/9                                0.421483            0.270006
#
#                           PlayerB_2019-09-21  PlayerB_2019-09-24
# p_throws                           -0.470792           -0.515752
# prop_events_nback                   0.383133            0.707092
# prop_events_sum_nback_pt           -0.100198           -0.349897
# WAR                                -0.232203           -0.349272
# FIP                                -0.135380           -0.614483
# K/9                                -0.016823           -0.155589
# BB/9                                0.192903            0.280813
# H/9                                -0.118870           -0.120126
# HR/9                               -0.081885            0.264149
#
# [9 rows x 24 columns]

# %%
pred_right = 0
pred_wrong = 0
pred_halfwrong = 0

for i in range(df_pred_actual_bydate.shape[1]):
    pred = df_pred_actual_bydate.loc["prediction", :].iloc[i]
    actual = df_pred_actual_bydate.loc["actual", :].iloc[i]
    # print(pred, actual)
    if pred == actual:
        pred_right += 1
    elif (pred != actual) and ("even" in pred or "even" in actual):
        pred_halfwrong += 1
    else:
        pred_wrong += 1

print(
    "correct: ",
    str(pred_right),
    "half right: ",
    str(pred_halfwrong),
    "wrong: ",
    str(pred_wrong),
)
# Out:
# correct:  12 half right:  6 wrong:  6

# %% [markdown]
# ### Medium case

# %%
df_sc_events_b2.head()
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF 2019-08-02           77.9        -2.2730         5.9418
# 1         FF 2019-08-02           94.2        -2.7468         5.6427
# 2         FF 2019-08-02           89.5        -0.4280         6.2591
# 3         FF 2019-08-02           96.8        -2.1726         6.3117
# 4         KC 2019-08-02           71.8         3.3912         5.2599
#
#     player_name    batter   pitcher     events           description  ...  \
# 0   Roman Quinn  544725.0  596451.0     single  hit_into_play_no_out  ...
# 1    Zach Eflin  544725.0  621107.0  field_out         hit_into_play  ...
# 2  Blake Parker  544725.0  453284.0  field_out         hit_into_play  ...
# 3  Nick Pivetta  544725.0  601713.0  strikeout              foul_tip  ...
# 4  Jason Vargas  544725.0  450306.0  strikeout       swinging_strike  ...
#
#   if_fielding_alignment of_fielding_alignment name_last name_first  key_mlbam  \
# 0              Standard              Standard    garcia      leury     544725
# 1              Standard              Standard    garcia      leury     544725
# 2              Standard              Standard    garcia      leury     544725
# 3             Strategic              Standard    garcia      leury     544725
# 4              Standard              Standard    garcia      leury     544725
#
#   key_retro  key_bbref key_fangraphs mlb_played_first mlb_played_last
# 0  garcl004  garcile02          5913           2013.0          2019.0
# 1  garcl004  garcile02          5913           2013.0          2019.0
# 2  garcl004  garcile02          5913           2013.0          2019.0
# 3  garcl004  garcile02          5913           2013.0          2019.0
# 4  garcl004  garcile02          5913           2013.0          2019.0
#
# [5 rows x 97 columns]

# %%
df4model_b2_wp_dayof.head()
# Out:
# Empty DataFrame
# Columns: [game_date, inning, outs_when_up, events, player_name, pitcher, event_code, p_throws, prop_events_nback, prop_events_sum_nback_pt, WAR, FIP, K/9, BB/9, H/9, HR/9]
# Index: []

# %%
# Reynolds and Garcia (668804, 544725)
# Bryan Reynolds (PIT)

pid1 = 668804
pid2 = 544725

# (35 dates)
date_list = [
    "'2019-08-02'",
    "'2019-08-03'",
    "'2019-08-04'",
    "'2019-08-05'",
    "'2019-08-06'",
    "'2019-08-07'",
    "'2019-08-09'",
    "'2019-08-10'",
    "'2019-08-16'",
    "'2019-08-17'",
    "'2019-08-18'",
    "'2019-08-19'",
    "'2019-08-20'",
    "'2019-08-21'",
    "'2019-08-22'",
    "'2019-08-23'",
    "'2019-08-24'",
    "'2019-08-25'",
    "'2019-08-27'",
    "'2019-08-28'",
    "'2019-08-29'",
    "'2019-08-30'",
    "'2019-08-31'",
    "'2019-09-01'",
    "'2019-09-03'",
    "'2019-09-04'",
    "'2019-09-10'",
    "'2019-09-11'",
    "'2019-09-12'",
    "'2019-09-13'",
    "'2019-09-18'",
    "'2019-09-21'",
    "'2019-09-22'",
    "'2019-09-24'",
    "'2019-09-25'",
]

# date_list = [
#  ""'2019-09-04'",
#  ""'2019-09-10'",
# ]

no_total_ab_events = 1000

# GOAL
# Tabulate the prediction and the actual performance
# prediction A, prediction B, performance A, performance B

df_player1_coef = pd.DataFrame()
df_player2_coef = pd.DataFrame()
df_pred_actual_bydate = pd.DataFrame()
df_pred_actual_bydate_detail = pd.DataFrame()


for date_of_interest in date_list:

    print(date_of_interest)

    # Input batters, date
    df_sc_events_b1 = get_sc_batter_df(pid1, date_of_interest, 1000)
    df_sc_events_b2 = get_sc_batter_df(pid2, date_of_interest, 1000)

    # Add pitcher features
    df_sc_events_b1_wp = pd.merge(
        df_sc_events_b1,
        df_pitching_stats19_wpid[col4pitch2merge],
        left_on="pitcher",
        right_on="key_mlbam",
    )

    df_sc_events_b2_wp = pd.merge(
        df_sc_events_b2,
        df_pitching_stats19_wpid[col4pitch2merge],
        left_on="pitcher",
        right_on="key_mlbam",
    )

    # Build model dataframe
    df4model_b1_wp = get_df4model_wp(
        df=df_sc_events_b1_wp.copy(), n_back_PA=100, m_size=200
    )
    df4model_b2_wp = get_df4model_wp(
        df=df_sc_events_b2_wp.copy(), n_back_PA=100, m_size=200
    )

    # Separate "day of" from "pre-date"
    df4model_b1_wp_dayof = df4model_b1_wp[
        df4model_b1_wp["game_date"] == date_of_interest
    ].copy()
    df4model_b2_wp_dayof = df4model_b2_wp[
        df4model_b2_wp["game_date"] == date_of_interest
    ].copy()

    # Format dataframe for model
    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
        "WAR",
        "FIP",
        "K/9",
        "BB/9",
        "H/9",
        "HR/9",
    ]

    df4model_b1_wp_lim = df4model_b1_wp.loc[
        df4model_b1_wp["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b2_wp_lim = df4model_b2_wp.loc[
        df4model_b2_wp["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b1_wp_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
    df4model_b2_wp_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

    # Split data
    X_train_scale_b1, X_test_scale_b1, y_train_b1, y_test_b1 = get_split_data(
        df4model_b1_wp_lim, 0.4
    )
    X_train_scale_b2, X_test_scale_b2, y_train_b2, y_test_b2 = get_split_data(
        df4model_b2_wp_lim, 0.4
    )

    # Run models
    log_reg_b1, df_eval_b1 = run_logreg_model(
        X_train_scale_b1, y_train_b1, X_test_scale_b1, y_test_b1
    )

    log_reg_b2, df_eval_b2 = run_logreg_model(
        X_train_scale_b2, y_train_b2, X_test_scale_b2, y_test_b2
    )

    #     print("Player 1 coefficients: ", log_reg_b1.coef_)
    #     print(
    #         colored("perc. RHP: " + str(df4model_b1_wp_lim["p_throws"].sum() / 200), "red")
    #     )
    #     print("Player 2 coefficients: ", log_reg_b2.coef_)
    #     print(
    #         colored("perc. RHP: " + str(df4model_b2_wp_lim["p_throws"].sum() / 200), "red")
    #     )

    # Assess day of performance  ---------
    # Get at-bats against first pitcher
    df4model_b1_wp_dayof_sp = get_df_ab_vs_startingp(df4model_b1_wp_dayof)
    df4model_b2_wp_dayof_sp = get_df_ab_vs_startingp(df4model_b2_wp_dayof)

    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
        "WAR",
        "FIP",
        "K/9",
        "BB/9",
        "H/9",
        "HR/9",
    ]

    df4model_b1_wp_dayof_sp_lim = df4model_b1_wp_dayof_sp.loc[:, col4model].copy()
    df4model_b2_wp_dayof_sp_lim = df4model_b2_wp_dayof_sp.loc[:, col4model].copy()

    # Return series of player prediction counts

    df_pred_actual, val_entries = return_series_of_player_prediction_counts(
        df4model_b1_wp_dayof_sp_lim,
        df4model_b2_wp_dayof_sp_lim,
        log_reg_b1_wps,
        log_reg_b2_wps,
    )

    colname = "A_vs_B_" + str(date_of_interest).strip("'")
    df_pred_actual_bydate[colname] = [i for i in val_entries]

    df_pred_actual_bydate.index = [
        "game_date",
        "key_batterA",
        "key_batterB",
        "prediction",
        "actual",
    ]

    df_pred_actual_bydate_detail[colname] = df_pred_actual

    # Coefficients
    colname = "PlayerA_" + str(date_of_interest).strip("'")
    df_player1_coef[colname] = log_reg_b1.coef_[0]
    df_player1_coef.index = df4model_b1_wp_lim.columns[1:]
    colname = "PlayerB_" + str(date_of_interest).strip("'")
    df_player2_coef[colname] = log_reg_b2.coef_[0]
    df_player2_coef.index = df4model_b2_wp_lim.columns[1:]

    if date_of_interest == date_list[-1]:
        print("done getting dates")
# Out:
# '2019-08-02'
# '2019-08-03'
# '2019-08-04'
# '2019-08-05'
# '2019-08-06'
# '2019-08-07'
# '2019-08-09'
# '2019-08-10'
# '2019-08-16'
# '2019-08-17'
# '2019-08-18'
# '2019-08-19'
# '2019-08-20'
# '2019-08-21'
# '2019-08-22'
# '2019-08-23'
# '2019-08-24'
# '2019-08-25'
# '2019-08-27'
# '2019-08-28'
# '2019-08-29'
# '2019-08-30'
# '2019-08-31'
# '2019-09-01'
# '2019-09-03'
# '2019-09-04'
# '2019-09-10'
# '2019-09-11'
# '2019-09-12'
# '2019-09-13'
# '2019-09-18'
# '2019-09-21'
# '2019-09-22'
# '2019-09-24'
# '2019-09-25'
# done getting dates

# %%
df_pred_actual_bydate_detail
# Out:
#                             A_vs_B_2019-08-02 A_vs_B_2019-08-03  \
# actual_performance_batterA                  1                 3
# actual_performance_batterB                  1                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00273699        0.00181035
# pred_vs_gamepitcher_batterB        0.00181061        0.00137152
#
#                             A_vs_B_2019-08-04 A_vs_B_2019-08-05  \
# actual_performance_batterA                  1                 1
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA       0.000846609        0.00265184
# pred_vs_gamepitcher_batterB       0.000530415       0.000901451
#
#                             A_vs_B_2019-08-06 A_vs_B_2019-08-07  \
# actual_performance_batterA                  1                 0
# actual_performance_batterB                  0                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00512924        0.00108123
# pred_vs_gamepitcher_batterB        0.00160232       0.000911455
#
#                             A_vs_B_2019-08-09 A_vs_B_2019-08-10  \
# actual_performance_batterA                  0                 1
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00803519        0.00311673
# pred_vs_gamepitcher_batterB        0.00242629       0.000861417
#
#                             A_vs_B_2019-08-16 A_vs_B_2019-08-17  ...  \
# actual_performance_batterA                  0                 0  ...
# actual_performance_batterB                  1                 1  ...
# pred_var_batterA                         None              None  ...
# pred_var_batterB                         None              None  ...
# pred_vs_gamepitcher_batterA         0.0018005        0.00148638  ...
# pred_vs_gamepitcher_batterB        0.00103315        0.00104088  ...
#
#                             A_vs_B_2019-09-04 A_vs_B_2019-09-10  \
# actual_performance_batterA                  1                 0
# actual_performance_batterB                  1                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA         0.0149369         0.0130708
# pred_vs_gamepitcher_batterB        0.00249377       0.000773826
#
#                             A_vs_B_2019-09-11 A_vs_B_2019-09-12  \
# actual_performance_batterA                  0                 1
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA         0.0048659        0.00729143
# pred_vs_gamepitcher_batterB       0.000746757       0.000688593
#
#                             A_vs_B_2019-09-13 A_vs_B_2019-09-18  \
# actual_performance_batterA                  1                 1
# actual_performance_batterB                  1                 2
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00148067         0.0168389
# pred_vs_gamepitcher_batterB       0.000937641        0.00173356
#
#                             A_vs_B_2019-09-21 A_vs_B_2019-09-22  \
# actual_performance_batterA                  0                 0
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA         0.0103435       0.000746993
# pred_vs_gamepitcher_batterB       0.000898512       0.000191517
#
#                             A_vs_B_2019-09-24 A_vs_B_2019-09-25
# actual_performance_batterA                  0                 0
# actual_performance_batterB                  1                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00181938        0.00147439
# pred_vs_gamepitcher_batterB        0.00196865        0.00258159
#
# [6 rows x 35 columns]

# %%
df_pred_actual_bydate
# Out:
#             A_vs_B_2019-08-02 A_vs_B_2019-08-03 A_vs_B_2019-08-04  \
# game_date        '2019-08-02'      '2019-08-03'      '2019-08-04'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                   even                 A              even
#
#             A_vs_B_2019-08-05 A_vs_B_2019-08-06 A_vs_B_2019-08-07  \
# game_date        '2019-08-05'      '2019-08-06'      '2019-08-07'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      A                 A              even
#
#             A_vs_B_2019-08-09 A_vs_B_2019-08-10 A_vs_B_2019-08-16  \
# game_date        '2019-08-09'      '2019-08-10'      '2019-08-16'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      B                 A                 B
#
#             A_vs_B_2019-08-17  ... A_vs_B_2019-09-04 A_vs_B_2019-09-10  \
# game_date        '2019-08-17'  ...      '2019-09-04'      '2019-09-10'
# key_batterA            668804  ...            668804            668804
# key_batterB            544725  ...            544725            544725
# prediction                  A  ...                 A                 A
# actual                      B  ...              even                 B
#
#             A_vs_B_2019-09-11 A_vs_B_2019-09-12 A_vs_B_2019-09-13  \
# game_date        '2019-09-11'      '2019-09-12'      '2019-09-13'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      B                 A              even
#
#             A_vs_B_2019-09-18 A_vs_B_2019-09-21 A_vs_B_2019-09-22  \
# game_date        '2019-09-18'      '2019-09-21'      '2019-09-22'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      B                 B              even
#
#             A_vs_B_2019-09-24 A_vs_B_2019-09-25
# game_date        '2019-09-24'      '2019-09-25'
# key_batterA            668804            668804
# key_batterB            544725            544725
# prediction                  B                 B
# actual                      B                 B
#
# [5 rows x 35 columns]

# %%
# Predicting rare
#df_pred_actual_bydate.loc["prediction", :]=='A'.sum()
# Out:
# 29

# %%
df_pred_actual_bydate.shape[1]
# Out:
# 35

# %%
pred_right = 0
pred_wrong = 0
pred_halfwrong = 0

for i in range(df_pred_actual_bydate.shape[1]):
    pred = df_pred_actual_bydate.loc["prediction", :].iloc[i]
    actual = df_pred_actual_bydate.loc["actual", :].iloc[i]
    # print(pred, actual)
    if pred == actual:
        pred_right += 1
    elif (pred != actual) and ("even" in pred or "even" in actual):
        pred_halfwrong += 1
    else:
        pred_wrong += 1

print(
    "correct: ",
    str(pred_right),
    "half right: ",
    str(pred_halfwrong),
    "wrong: ",
    str(pred_wrong),
)
# Out:
# correct:  16 half right:  10 wrong:  9

# %%
df_player1_coef
# Out:
#                           PlayerA_2019-09-04  PlayerA_2019-09-10  \
# p_throws                           -0.365981           -0.323070
# prop_events_nback                  -0.053420           -0.182604
# prop_events_sum_nback_pt            0.787819            0.515565
# WAR                                -0.232452           -0.014455
# FIP                                -0.125515            0.010853
# K/9                                -0.087176           -0.230112
# BB/9                                0.051061            0.122538
# H/9                                -0.173436           -0.118706
# HR/9                               -0.047004            0.106005
#
#                           PlayerA_2019-09-11  PlayerA_2019-09-12  \
# p_throws                           -0.497995           -0.519436
# prop_events_nback                  -0.346862           -0.015246
# prop_events_sum_nback_pt            0.722308            0.664903
# WAR                                -0.247686           -0.184370
# FIP                                -0.034288            0.003202
# K/9                                -0.271948           -0.526276
# BB/9                                0.046151           -0.164391
# H/9                                -0.112653           -0.159503
# HR/9                               -0.054546            0.149846
#
#                           PlayerA_2019-09-13  PlayerA_2019-09-18  \
# p_throws                            0.171209            0.777420
# prop_events_nback                  -0.090830            0.558781
# prop_events_sum_nback_pt           -0.261237           -0.584180
# WAR                                -0.209025           -0.092310
# FIP                                -0.467079           -0.115260
# K/9                                -0.348999           -0.421589
# BB/9                               -0.054196           -0.096374
# H/9                                 0.064377           -0.316046
# HR/9                                0.370011           -0.058479
#
#                           PlayerA_2019-09-21  PlayerA_2019-09-22  \
# p_throws                            0.302285            0.055297
# prop_events_nback                   0.378422            0.458968
# prop_events_sum_nback_pt           -0.123107            0.077888
# WAR                                -0.116095           -0.345195
# FIP                                 0.063426           -0.318797
# K/9                                -0.489309           -0.478041
# BB/9                                0.112876            0.017315
# H/9                                 0.206915           -0.171609
# HR/9                                0.037250            0.110000
#
#                           PlayerA_2019-09-24  PlayerA_2019-09-25
# p_throws                           -0.220867            0.230064
# prop_events_nback                  -0.236757            0.234799
# prop_events_sum_nback_pt            0.644911           -0.354377
# WAR                                -0.028783           -0.374700
# FIP                                -0.269196           -0.087870
# K/9                                -0.102148           -0.431244
# BB/9                                0.554859            0.042280
# H/9                                 0.280136           -0.065670
# HR/9                                0.015498            0.286699

# %%
df_player2_coef
# Out:
#                           PlayerB2019-09-04  PlayerB2019-09-10  \
# p_throws                           0.016012          -0.169170
# prop_events_nback                  0.385106           0.333039
# prop_events_sum_nback_pt           0.298884           0.221257
# WAR                               -0.404729           0.103217
# FIP                               -0.307526          -0.163972
# K/9                                0.058419           0.109998
# BB/9                               0.013261           0.090301
# H/9                               -0.243360          -0.070899
# HR/9                               0.291703           0.338105
#
#                           PlayerB2019-09-11  PlayerB2019-09-12  \
# p_throws                          -0.193373          -0.329698
# prop_events_nback                  0.616754           0.563476
# prop_events_sum_nback_pt           0.003435           0.028827
# WAR                               -0.279202          -0.127190
# FIP                               -0.359217          -0.294098
# K/9                               -0.026399          -0.023241
# BB/9                               0.082877           0.233465
# H/9                               -0.394628          -0.000556
# HR/9                               0.348276          -0.050907
#
#                           PlayerB2019-09-13  PlayerB2019-09-18  \
# p_throws                          -0.219995          -0.609336
# prop_events_nback                  0.657780           0.625406
# prop_events_sum_nback_pt           0.119846          -0.467526
# WAR                               -0.073354          -0.005209
# FIP                               -0.124040           0.220427
# K/9                                0.115055          -0.322397
# BB/9                              -0.143520          -0.342470
# H/9                               -0.077662          -0.543503
# HR/9                               0.317906           0.313618
#
#                           PlayerB2019-09-21  PlayerB2019-09-22  \
# p_throws                          -0.455195          -0.198674
# prop_events_nback                  0.583849           0.397379
# prop_events_sum_nback_pt          -0.401480          -0.081128
# WAR                                0.344809           0.243362
# FIP                               -0.029774           0.060117
# K/9                               -0.501076           0.065777
# BB/9                               0.112377          -0.027872
# H/9                               -0.171467           0.244472
# HR/9                               0.303975           0.208051
#
#                           PlayerB2019-09-24  PlayerB2019-09-25
# p_throws                          -0.287066          -0.320266
# prop_events_nback                  0.396763           0.611094
# prop_events_sum_nback_pt          -0.032474          -0.240990
# WAR                                0.034394           0.150582
# FIP                                0.072176          -0.086835
# K/9                               -0.018289          -0.194177
# BB/9                               0.031986          -0.178473
# H/9                               -0.107250          -0.355942
# HR/9                              -0.024049           0.188140

# %%
df_sc_events_b1_test1["p_throws"]
# Out:
# 0    L
# 1    R
# 2    R
# 3    R
# 4    R
# 5    R
# 6    R
# 7    R
# 8    R
# 9    R
# Name: p_throws, dtype: object

# %%
# Input batters, date
df_sc_events_b1_test1 = get_sc_batter_df(pid1, "'2019-09-12'", 10)
df_sc_events_b1_test1
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SL 2019-09-12           88.0         1.7842         6.4511
# 1         FT 2019-09-12           92.8        -2.9275         5.9333
# 2         SL 2019-09-12           85.9        -3.0655         6.0450
# 3         FF 2019-09-12           90.0        -3.0280         5.9273
# 4         CU 2019-09-11           81.5        -2.7457         5.7236
# 5         CU 2019-09-11           84.4        -2.3998         5.9435
# 6         CH 2019-09-11           84.9        -2.2438         5.4235
# 7         SL 2019-09-11           82.6        -1.9272         5.4782
# 8         FT 2019-09-11           92.8        -1.9919         5.5667
# 9       None 2019-09-10            NaN            NaN            NaN
#
#         player_name    batter   pitcher               events  \
# 0     Andrew Suarez  668804.0  605498.0            strikeout
# 1   Jeff Samardzija  668804.0  502188.0  fielders_choice_out
# 2   Jeff Samardzija  668804.0  502188.0            strikeout
# 3   Jeff Samardzija  668804.0  502188.0               single
# 4  Kyle Barraclough  668804.0  607457.0            strikeout
# 5       Sam Coonrod  668804.0  656322.0            field_out
# 6        Logan Webb  668804.0  657277.0            strikeout
# 7        Logan Webb  668804.0  657277.0            strikeout
# 8        Logan Webb  668804.0  657277.0            field_out
# 9       Sam Coonrod  668804.0  656322.0               single
#
#                description  ... if_fielding_alignment of_fielding_alignment  \
# 0          swinging_strike  ...              Standard              Standard
# 1            hit_into_play  ...         Infield shift              Standard
# 2            called_strike  ...         Infield shift              Standard
# 3     hit_into_play_no_out  ...              Standard              Standard
# 4  swinging_strike_blocked  ...              Standard              Standard
# 5            hit_into_play  ...              Standard              Standard
# 6          swinging_strike  ...              Standard              Standard
# 7          swinging_strike  ...              Standard              Standard
# 8            hit_into_play  ...              Standard              Standard
# 9     hit_into_play_no_out  ...                  None                  None
#
#   name_last name_first  key_mlbam key_retro  key_bbref key_fangraphs  \
# 0  reynolds      bryan     668804  reynb001  reynobr01         19326
# 1  reynolds      bryan     668804  reynb001  reynobr01         19326
# 2  reynolds      bryan     668804  reynb001  reynobr01         19326
# 3  reynolds      bryan     668804  reynb001  reynobr01         19326
# 4  reynolds      bryan     668804  reynb001  reynobr01         19326
# 5  reynolds      bryan     668804  reynb001  reynobr01         19326
# 6  reynolds      bryan     668804  reynb001  reynobr01         19326
# 7  reynolds      bryan     668804  reynb001  reynobr01         19326
# 8  reynolds      bryan     668804  reynb001  reynobr01         19326
# 9  reynolds      bryan     668804  reynb001  reynobr01         19326
#
#   mlb_played_first mlb_played_last
# 0           2019.0          2019.0
# 1           2019.0          2019.0
# 2           2019.0          2019.0
# 3           2019.0          2019.0
# 4           2019.0          2019.0
# 5           2019.0          2019.0
# 6           2019.0          2019.0
# 7           2019.0          2019.0
# 8           2019.0          2019.0
# 9           2019.0          2019.0
#
# [10 rows x 97 columns]

# %%
df_sc_events_b1_test2 = get_sc_batter_df(pid1, "'2019-09-13'", 10)
df_sc_events_b1_test2
# Out:
#   pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF 2019-09-13           93.6         1.5137         6.2251
# 1         FF 2019-09-13           91.5         2.7389         5.5907
# 2         CH 2019-09-13           83.4         2.5857         5.7340
# 3         FC 2019-09-13           89.0         2.6932         5.6271
# 4         SL 2019-09-12           88.0         1.7842         6.4511
# 5         FT 2019-09-12           92.8        -2.9275         5.9333
# 6         SL 2019-09-12           85.9        -3.0655         6.0450
# 7         FF 2019-09-12           90.0        -3.0280         5.9273
# 8         CU 2019-09-11           81.5        -2.7457         5.7236
# 9         CU 2019-09-11           84.4        -2.3998         5.9435
#
#         player_name    batter   pitcher               events  \
# 0        Brad Wieck  668804.0  623364.0            strikeout
# 1        Jon Lester  668804.0  452657.0            strikeout
# 2        Jon Lester  668804.0  452657.0            field_out
# 3        Jon Lester  668804.0  452657.0                 walk
# 4     Andrew Suarez  668804.0  605498.0            strikeout
# 5   Jeff Samardzija  668804.0  502188.0  fielders_choice_out
# 6   Jeff Samardzija  668804.0  502188.0            strikeout
# 7   Jeff Samardzija  668804.0  502188.0               single
# 8  Kyle Barraclough  668804.0  607457.0            strikeout
# 9       Sam Coonrod  668804.0  656322.0            field_out
#
#                description  ... if_fielding_alignment of_fielding_alignment  \
# 0            called_strike  ...              Standard              Standard
# 1            called_strike  ...              Standard              Standard
# 2            hit_into_play  ...              Standard              Standard
# 3                     ball  ...              Standard              Standard
# 4          swinging_strike  ...              Standard              Standard
# 5            hit_into_play  ...         Infield shift              Standard
# 6            called_strike  ...         Infield shift              Standard
# 7     hit_into_play_no_out  ...              Standard              Standard
# 8  swinging_strike_blocked  ...              Standard              Standard
# 9            hit_into_play  ...              Standard              Standard
#
#   name_last name_first  key_mlbam key_retro  key_bbref key_fangraphs  \
# 0  reynolds      bryan     668804  reynb001  reynobr01         19326
# 1  reynolds      bryan     668804  reynb001  reynobr01         19326
# 2  reynolds      bryan     668804  reynb001  reynobr01         19326
# 3  reynolds      bryan     668804  reynb001  reynobr01         19326
# 4  reynolds      bryan     668804  reynb001  reynobr01         19326
# 5  reynolds      bryan     668804  reynb001  reynobr01         19326
# 6  reynolds      bryan     668804  reynb001  reynobr01         19326
# 7  reynolds      bryan     668804  reynb001  reynobr01         19326
# 8  reynolds      bryan     668804  reynb001  reynobr01         19326
# 9  reynolds      bryan     668804  reynb001  reynobr01         19326
#
#   mlb_played_first mlb_played_last
# 0           2019.0          2019.0
# 1           2019.0          2019.0
# 2           2019.0          2019.0
# 3           2019.0          2019.0
# 4           2019.0          2019.0
# 5           2019.0          2019.0
# 6           2019.0          2019.0
# 7           2019.0          2019.0
# 8           2019.0          2019.0
# 9           2019.0          2019.0
#
# [10 rows x 97 columns]

# %% [markdown]
# ### Hard case

# %%
# Santander and Garcia (668804, 544725)

pid1 = 623993
pid2 = 544725

# (35 dates)
date_list = [
    "'2019-08-02'",
    "'2019-08-03'",
    "'2019-08-04'",
    "'2019-08-05'",
    "'2019-08-06'",
    "'2019-08-07'",
    "'2019-08-09'",
    "'2019-08-10'",
    "'2019-08-16'",
    "'2019-08-17'",
    "'2019-08-18'",
    "'2019-08-19'",
    "'2019-08-20'",
    "'2019-08-21'",
    "'2019-08-22'",
    "'2019-08-23'",
    "'2019-08-24'",
    "'2019-08-25'",
    "'2019-08-27'",
    "'2019-08-28'",
    "'2019-08-30'",
    "'2019-08-31'",
    "'2019-09-01'",
    "'2019-09-02'",
    "'2019-09-03'",
    "'2019-09-10'",
    "'2019-09-11'",
    "'2019-09-12'",
    "'2019-09-16'",
    "'2019-09-18'",
    "'2019-09-21'",
]

# date_list = [
#  """'2019-09-04'",
#  """'2019-09-10'",
# ]

no_total_ab_events = 1000

# GOAL
# Tabulate the prediction and the actual performance
# prediction A, prediction B, performance A, performance B

df_player1_coef = pd.DataFrame()
df_player2_coef = pd.DataFrame()
df_pred_actual_bydate = pd.DataFrame()
df_pred_actual_bydate_detail = pd.DataFrame()


for date_of_interest in date_list:

    print(date_of_interest)

    # Input batters, date
    df_sc_events_b1 = get_sc_batter_df(pid1, date_of_interest, 1000)
    df_sc_events_b2 = get_sc_batter_df(pid2, date_of_interest, 1000)

    # Add pitcher features
    df_sc_events_b1_wp = pd.merge(
        df_sc_events_b1,
        df_pitching_stats19_wpid[col4pitch2merge],
        left_on="pitcher",
        right_on="key_mlbam",
    )

    df_sc_events_b2_wp = pd.merge(
        df_sc_events_b2,
        df_pitching_stats19_wpid[col4pitch2merge],
        left_on="pitcher",
        right_on="key_mlbam",
    )

    # Build model dataframe
    df4model_b1_wp = get_df4model_wp(
        df=df_sc_events_b1_wp.copy(), n_back_PA=100, m_size=200
    )
    df4model_b2_wp = get_df4model_wp(
        df=df_sc_events_b2_wp.copy(), n_back_PA=100, m_size=200
    )

    # Separate "day of" from "pre-date"
    df4model_b1_wp_dayof = df4model_b1_wp[
        df4model_b1_wp["game_date"] == date_of_interest
    ].copy()
    df4model_b2_wp_dayof = df4model_b2_wp[
        df4model_b2_wp["game_date"] == date_of_interest
    ].copy()

    # Format dataframe for model
    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
        "WAR",
        "FIP",
        "K/9",
        "BB/9",
        "H/9",
        "HR/9",
    ]

    df4model_b1_wp_lim = df4model_b1_wp.loc[
        df4model_b1_wp["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b2_wp_lim = df4model_b2_wp.loc[
        df4model_b2_wp["game_date"] < date_of_interest, col4model
    ].copy()

    df4model_b1_wp_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)
    df4model_b2_wp_lim["p_throws"].replace({"L": 0, "R": 1}, inplace=True)

    # Split data
    X_train_scale_b1, X_test_scale_b1, y_train_b1, y_test_b1 = get_split_data(
        df4model_b1_wp_lim, 0.4
    )
    X_train_scale_b2, X_test_scale_b2, y_train_b2, y_test_b2 = get_split_data(
        df4model_b2_wp_lim, 0.4
    )

    # Run models
    log_reg_b1, df_eval_b1 = run_logreg_model(
        X_train_scale_b1, y_train_b1, X_test_scale_b1, y_test_b1
    )

    log_reg_b2, df_eval_b2 = run_logreg_model(
        X_train_scale_b2, y_train_b2, X_test_scale_b2, y_test_b2
    )

    #     print("Player 1 coefficients: ", log_reg_b1.coef_)
    #     print(
    #         colored("perc. RHP: " + str(df4model_b1_wp_lim["p_throws"].sum() / 200), "red")
    #     )
    #     print("Player 2 coefficients: ", log_reg_b2.coef_)
    #     print(
    #         colored("perc. RHP: " + str(df4model_b2_wp_lim["p_throws"].sum() / 200), "red")
    #     )

    # Assess day of performance  ---------
    # Get at-bats against first pitcher
    df4model_b1_wp_dayof_sp = get_df_ab_vs_startingp(df4model_b1_wp_dayof)
    df4model_b2_wp_dayof_sp = get_df_ab_vs_startingp(df4model_b2_wp_dayof)

    col4model = [
        "event_code",
        "p_throws",
        "prop_events_nback",
        "prop_events_sum_nback_pt",
        "WAR",
        "FIP",
        "K/9",
        "BB/9",
        "H/9",
        "HR/9",
    ]

    df4model_b1_wp_dayof_sp_lim = df4model_b1_wp_dayof_sp.loc[:, col4model].copy()
    df4model_b2_wp_dayof_sp_lim = df4model_b2_wp_dayof_sp.loc[:, col4model].copy()

    # Return series of player prediction counts

    df_pred_actual, val_entries = return_series_of_player_prediction_counts(
        df4model_b1_wp_dayof_sp_lim,
        df4model_b2_wp_dayof_sp_lim,
        log_reg_b1_wps,
        log_reg_b2_wps,
    )

    colname = "A_vs_B_" + str(date_of_interest).strip("'")
    df_pred_actual_bydate[colname] = [i for i in val_entries]

    df_pred_actual_bydate.index = [
        "game_date",
        "key_batterA",
        "key_batterB",
        "prediction",
        "actual",
    ]

    df_pred_actual_bydate_detail[colname] = df_pred_actual

    # Coefficients
    colname = "PlayerA_" + str(date_of_interest).strip("'")
    df_player1_coef[colname] = log_reg_b1.coef_[0]
    df_player1_coef.index = df4model_b1_wp_lim.columns[1:]
    colname = "PlayerB_" + str(date_of_interest).strip("'")
    df_player2_coef[colname] = log_reg_b2.coef_[0]
    df_player2_coef.index = df4model_b2_wp_lim.columns[1:]

    if date_of_interest == date_list[-1]:
        print("done getting dates")
# Out:
# '2019-08-02'
# '2019-08-03'
# '2019-08-04'
# '2019-08-05'
# '2019-08-06'
# '2019-08-07'
# '2019-08-09'
# '2019-08-10'
# '2019-08-16'
# '2019-08-17'
# '2019-08-18'
# '2019-08-19'
# '2019-08-20'
# '2019-08-21'
# '2019-08-22'
# '2019-08-23'
# '2019-08-24'
# '2019-08-25'
# '2019-08-27'
# '2019-08-28'
# '2019-08-30'
# '2019-08-31'
# '2019-09-01'
# '2019-09-02'
# '2019-09-03'
# '2019-09-10'
# '2019-09-11'
# '2019-09-12'
# '2019-09-16'
# '2019-09-18'
# '2019-09-21'
# done getting dates

# %%
df_pred_actual_bydate_detail
# Out:
#                             A_vs_B_2019-08-02 A_vs_B_2019-08-03  \
# actual_performance_batterA                  1                 0
# actual_performance_batterB                  1                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00303417        0.00519772
# pred_vs_gamepitcher_batterB        0.00181061        0.00137152
#
#                             A_vs_B_2019-08-04 A_vs_B_2019-08-05  \
# actual_performance_batterA                  1                 2
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00803813        0.00289515
# pred_vs_gamepitcher_batterB       0.000530415       0.000901451
#
#                             A_vs_B_2019-08-06 A_vs_B_2019-08-07  \
# actual_performance_batterA                  0                 0
# actual_performance_batterB                  0                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00297792       0.000488255
# pred_vs_gamepitcher_batterB        0.00160232       0.000911455
#
#                             A_vs_B_2019-08-09 A_vs_B_2019-08-10  \
# actual_performance_batterA                  0                 2
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00349289        0.00566979
# pred_vs_gamepitcher_batterB        0.00242629       0.000861417
#
#                             A_vs_B_2019-08-16 A_vs_B_2019-08-17  ...  \
# actual_performance_batterA                  0                 0  ...
# actual_performance_batterB                  1                 1  ...
# pred_var_batterA                         None              None  ...
# pred_var_batterB                         None              None  ...
# pred_vs_gamepitcher_batterA        0.00483573       0.000837142  ...
# pred_vs_gamepitcher_batterB        0.00103315        0.00104088  ...
#
#                             A_vs_B_2019-08-31 A_vs_B_2019-09-01  \
# actual_performance_batterA                  1                 1
# actual_performance_batterB                  1                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00859819        0.00402398
# pred_vs_gamepitcher_batterB        0.00140436        0.00129422
#
#                             A_vs_B_2019-09-02 A_vs_B_2019-09-03  \
# actual_performance_batterA                  1                 0
# actual_performance_batterB                  2                 0
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00277092        0.00213423
# pred_vs_gamepitcher_batterB        0.00291577        0.00190223
#
#                             A_vs_B_2019-09-10 A_vs_B_2019-09-11  \
# actual_performance_batterA                  0                 0
# actual_performance_batterB                  1                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA       0.000419573        0.00237375
# pred_vs_gamepitcher_batterB       0.000773826       0.000746757
#
#                             A_vs_B_2019-09-12 A_vs_B_2019-09-16  \
# actual_performance_batterA                  1                 1
# actual_performance_batterB                  0                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA        0.00141503        0.00388423
# pred_vs_gamepitcher_batterB       0.000688593        0.00192087
#
#                             A_vs_B_2019-09-18 A_vs_B_2019-09-21
# actual_performance_batterA                  2                 0
# actual_performance_batterB                  2                 1
# pred_var_batterA                         None              None
# pred_var_batterB                         None              None
# pred_vs_gamepitcher_batterA         0.0168555        0.00281051
# pred_vs_gamepitcher_batterB        0.00173356       0.000898512
#
# [6 rows x 31 columns]

# %%
df_pred_actual_bydate
# Out:
#             A_vs_B_2019-08-02 A_vs_B_2019-08-03 A_vs_B_2019-08-04  \
# game_date        '2019-08-02'      '2019-08-03'      '2019-08-04'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                   even                 B              even
#
#             A_vs_B_2019-08-05 A_vs_B_2019-08-06 A_vs_B_2019-08-07  \
# game_date        '2019-08-05'      '2019-08-06'      '2019-08-07'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 B
# actual                      A              even              even
#
#             A_vs_B_2019-08-09 A_vs_B_2019-08-10 A_vs_B_2019-08-16  \
# game_date        '2019-08-09'      '2019-08-10'      '2019-08-16'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      B                 A                 B
#
#             A_vs_B_2019-08-17  ... A_vs_B_2019-08-31 A_vs_B_2019-09-01  \
# game_date        '2019-08-17'  ...      '2019-08-31'      '2019-09-01'
# key_batterA            668804  ...            668804            668804
# key_batterB            544725  ...            544725            544725
# prediction                  B  ...                 A                 A
# actual                      B  ...              even                 A
#
#             A_vs_B_2019-09-02 A_vs_B_2019-09-03 A_vs_B_2019-09-10  \
# game_date        '2019-09-02'      '2019-09-03'      '2019-09-10'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  B                 A                 B
# actual                      B              even                 B
#
#             A_vs_B_2019-09-11 A_vs_B_2019-09-12 A_vs_B_2019-09-16  \
# game_date        '2019-09-11'      '2019-09-12'      '2019-09-16'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      B                 A              even
#
#             A_vs_B_2019-09-18 A_vs_B_2019-09-21
# game_date        '2019-09-18'      '2019-09-21'
# key_batterA            668804            668804
# key_batterB            544725            544725
# prediction                  A                 A
# actual                   even                 B
#
# [5 rows x 31 columns]

# %%
# Predicting rare
# df_pred_actual_bydate.loc["prediction", :]=='A'.sum()

# %%
df_pred_actual_bydate
# Out:
#             A_vs_B_2019-08-02 A_vs_B_2019-08-03 A_vs_B_2019-08-04  \
# game_date        '2019-08-02'      '2019-08-03'      '2019-08-04'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                   even                 B              even
#
#             A_vs_B_2019-08-05 A_vs_B_2019-08-06 A_vs_B_2019-08-07  \
# game_date        '2019-08-05'      '2019-08-06'      '2019-08-07'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 B
# actual                      A              even              even
#
#             A_vs_B_2019-08-09 A_vs_B_2019-08-10 A_vs_B_2019-08-16  \
# game_date        '2019-08-09'      '2019-08-10'      '2019-08-16'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      B                 A                 B
#
#             A_vs_B_2019-08-17  ... A_vs_B_2019-08-31 A_vs_B_2019-09-01  \
# game_date        '2019-08-17'  ...      '2019-08-31'      '2019-09-01'
# key_batterA            668804  ...            668804            668804
# key_batterB            544725  ...            544725            544725
# prediction                  B  ...                 A                 A
# actual                      B  ...              even                 A
#
#             A_vs_B_2019-09-02 A_vs_B_2019-09-03 A_vs_B_2019-09-10  \
# game_date        '2019-09-02'      '2019-09-03'      '2019-09-10'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  B                 A                 B
# actual                      B              even                 B
#
#             A_vs_B_2019-09-11 A_vs_B_2019-09-12 A_vs_B_2019-09-16  \
# game_date        '2019-09-11'      '2019-09-12'      '2019-09-16'
# key_batterA            668804            668804            668804
# key_batterB            544725            544725            544725
# prediction                  A                 A                 A
# actual                      B                 A              even
#
#             A_vs_B_2019-09-18 A_vs_B_2019-09-21
# game_date        '2019-09-18'      '2019-09-21'
# key_batterA            668804            668804
# key_batterB            544725            544725
# prediction                  A                 A
# actual                   even                 B
#
# [5 rows x 31 columns]

# %%
pred_right = 0
pred_wrong = 0
pred_halfwrong = 0

for i in range(df_pred_actual_bydate.shape[1]):
    pred = df_pred_actual_bydate.loc["prediction", :].iloc[i]
    actual = df_pred_actual_bydate.loc["actual", :].iloc[i]
    # print(pred, actual)
    if pred == actual:
        pred_right += 1
    elif (pred != actual) and ("even" in pred or "even" in actual):
        pred_halfwrong += 1
    else:
        pred_wrong += 1

print(
    "correct: ",
    str(pred_right),
    "half right: ",
    str(pred_halfwrong),
    "wrong: ",
    str(pred_wrong),
)
# Out:
# correct:  8 half right:  12 wrong:  11

# %%
df_player1_coef
# Out:
#                           PlayerA_2019-08-02  PlayerA_2019-08-03  \
# p_throws                           -0.223787           -0.027624
# prop_events_nback                   0.317089            0.399650
# prop_events_sum_nback_pt           -0.025285           -0.136109
# WAR                                -0.131564           -0.202433
# FIP                                 0.003046           -0.135827
# K/9                                -0.107512           -0.020730
# BB/9                               -0.237465           -0.201920
# H/9                                 0.512963            0.341077
# HR/9                               -0.121259            0.041493
#
#                           PlayerA_2019-08-04  PlayerA_2019-08-05  \
# p_throws                            0.010901            0.082800
# prop_events_nback                   0.068268            0.075157
# prop_events_sum_nback_pt           -0.204523           -0.364067
# WAR                                -0.531610           -0.437082
# FIP                                -0.039470           -0.090627
# K/9                                -0.058115            0.036124
# BB/9                                0.278422            0.109461
# H/9                                -0.006697            0.017470
# HR/9                                0.126400            0.114018
#
#                           PlayerA_2019-08-06  PlayerA_2019-08-07  \
# p_throws                            0.455093            0.174962
# prop_events_nback                   0.373031            0.402625
# prop_events_sum_nback_pt           -0.408700           -0.533381
# WAR                                -0.058465            0.100835
# FIP                                -0.116304            0.118348
# K/9                                -0.236997           -0.031754
# BB/9                                0.286970            0.278631
# H/9                                 0.442841            0.098339
# HR/9                               -0.111328           -0.035958
#
#                           PlayerA_2019-08-09  PlayerA_2019-08-10  \
# p_throws                           -0.213927            0.137708
# prop_events_nback                   0.406626            0.272365
# prop_events_sum_nback_pt            0.069694           -0.551895
# WAR                                -0.201803           -0.369405
# FIP                                -0.096474           -0.205139
# K/9                                -0.280623            0.065423
# BB/9                                0.130048           -0.164500
# H/9                                 0.214735            0.409249
# HR/9                               -0.060682            0.318605
#
#                           PlayerA_2019-08-16  PlayerA_2019-08-17  ...  \
# p_throws                           -0.089229            0.184445  ...
# prop_events_nback                   0.356955            0.280644  ...
# prop_events_sum_nback_pt            0.037719           -0.212221  ...
# WAR                                -0.269420           -0.204580  ...
# FIP                                -0.027940           -0.002463  ...
# K/9                                 0.094595            0.392302  ...
# BB/9                                0.233241           -0.087323  ...
# H/9                                 0.087296            0.198512  ...
# HR/9                                0.028222            0.055893  ...
#
#                           PlayerA_2019-08-31  PlayerA_2019-09-01  \
# p_throws                           -0.324242           -0.392722
# prop_events_nback                   0.459281            0.230915
# prop_events_sum_nback_pt            0.466146            0.397687
# WAR                                -0.264845           -0.131659
# FIP                                 0.084881            0.080587
# K/9                                 0.557844            0.474773
# BB/9                               -0.145884           -0.137254
# H/9                                 0.281854           -0.262938
# HR/9                                0.024201            0.353604
#
#                           PlayerA_2019-09-02  PlayerA_2019-09-03  \
# p_throws                           -0.167665           -0.413489
# prop_events_nback                   0.389264            0.067569
# prop_events_sum_nback_pt            0.116534            0.600468
# WAR                                -0.476529            0.083926
# FIP                                 0.003571           -0.095343
# K/9                                 0.315275            0.447004
# BB/9                                0.038018            0.093599
# H/9                                 0.627362            0.486044
# HR/9                               -0.287253           -0.031117
#
#                           PlayerA_2019-09-10  PlayerA_2019-09-11  \
# p_throws                           -0.226565           -0.028647
# prop_events_nback                   0.370903            0.210355
# prop_events_sum_nback_pt            0.165961            0.143623
# WAR                                -0.177974           -0.128266
# FIP                                 0.088282           -0.199953
# K/9                                 0.360551            0.498711
# BB/9                               -0.416588           -0.045278
# H/9                                 0.197508            0.097850
# HR/9                               -0.170812           -0.068672
#
#                           PlayerA_2019-09-12  PlayerA_2019-09-16  \
# p_throws                           -0.249514           -0.324629
# prop_events_nback                   0.606089            0.329974
# prop_events_sum_nback_pt            0.126509            0.441750
# WAR                                -0.161515            0.064208
# FIP                                -0.029768           -0.017448
# K/9                                 0.539113            0.206251
# BB/9                               -0.255321            0.106319
# H/9                                 0.424539            0.007568
# HR/9                               -0.278406            0.021399
#
#                           PlayerA_2019-09-18  PlayerA_2019-09-21
# p_throws                           -0.168551           -0.203577
# prop_events_nback                   0.312859           -0.177056
# prop_events_sum_nback_pt           -0.047951           -0.132702
# WAR                                -0.039225           -0.347291
# FIP                                -0.150031           -0.233906
# K/9                                 0.055006            0.075103
# BB/9                               -0.341520           -0.074461
# H/9                                 0.129547            0.152329
# HR/9                               -0.323205           -0.281578
#
# [9 rows x 31 columns]

# %%
df_sc_events_b1_test1["p_throws"]
# Out:
# 0    L
# 1    R
# 2    R
# 3    L
# 4    R
# 5    R
# 6    R
# 7    R
# 8    R
# 9    R
# Name: p_throws, dtype: object

# %%
df_player2_coef
# Out:
#                           PlayerB_2019-08-02  PlayerB_2019-08-03  \
# p_throws                           -0.579436           -0.024039
# prop_events_nback                   0.173106            0.271687
# prop_events_sum_nback_pt           -0.725292           -0.141046
# WAR                                -0.081133            0.209013
# FIP                                 0.265791            0.000236
# K/9                                 0.052645           -0.266696
# BB/9                                0.089117            0.186502
# H/9                                 0.061428            0.013921
# HR/9                                0.122716            0.002939
#
#                           PlayerB_2019-08-04  PlayerB_2019-08-05  \
# p_throws                           -0.218230           -0.159734
# prop_events_nback                   0.196757            0.352738
# prop_events_sum_nback_pt           -0.060951           -0.216620
# WAR                                 0.014586            0.156948
# FIP                                -0.075283           -0.131659
# K/9                                 0.068150           -0.228874
# BB/9                                0.304064            0.367046
# H/9                                 0.240506           -0.048571
# HR/9                               -0.066412            0.005521
#
#                           PlayerB_2019-08-06  PlayerB_2019-08-07  \
# p_throws                            0.168425            0.053448
# prop_events_nback                   0.534147            0.319624
# prop_events_sum_nback_pt            0.331290            0.157505
# WAR                                 0.007244           -0.011537
# FIP                                -0.194384           -0.257982
# K/9                                -0.097084           -0.268433
# BB/9                                0.069881            0.139056
# H/9                                 0.294537           -0.049966
# HR/9                                0.290114            0.260040
#
#                           PlayerB_2019-08-09  PlayerB_2019-08-10  \
# p_throws                           -0.302823           -0.190940
# prop_events_nback                   0.446627           -0.155405
# prop_events_sum_nback_pt           -0.032668           -0.159462
# WAR                                -0.109462           -0.037778
# FIP                                -0.444602           -0.128927
# K/9                                 0.024653            0.061700
# BB/9                                0.079165           -0.043112
# H/9                                -0.132286            0.355480
# HR/9                                0.182712            0.056311
#
#                           PlayerB_2019-08-16  PlayerB_2019-08-17  ...  \
# p_throws                           -0.248984           -0.293359  ...
# prop_events_nback                   0.878005            0.622981  ...
# prop_events_sum_nback_pt            0.094955            0.203337  ...
# WAR                                 0.144758            0.229503  ...
# FIP                                -0.394380           -0.080961  ...
# K/9                                -0.412154           -0.215582  ...
# BB/9                                0.355730            0.232510  ...
# H/9                                 0.187403           -0.047102  ...
# HR/9                                0.488232            0.529779  ...
#
#                           PlayerB_2019-08-31  PlayerB_2019-09-01  \
# p_throws                           -0.477829           -0.195099
# prop_events_nback                   0.659678            0.347793
# prop_events_sum_nback_pt           -0.722762           -0.372282
# WAR                                 0.161554            0.739938
# FIP                                -0.371945           -0.078956
# K/9                                -0.325037           -0.324914
# BB/9                                0.139587            0.299229
# H/9                                 0.018177           -0.110162
# HR/9                                0.119245            0.357333
#
#                           PlayerB_2019-09-02  PlayerB_2019-09-03  \
# p_throws                           -0.737154            0.148615
# prop_events_nback                   0.534219            0.249765
# prop_events_sum_nback_pt           -0.650824            0.130661
# WAR                                 0.340942            0.284367
# FIP                                -0.359176           -0.466624
# K/9                                -0.471121           -0.101731
# BB/9                                0.149031            0.174125
# H/9                                -0.162349           -0.162543
# HR/9                                0.131263            0.227969
#
#                           PlayerB_2019-09-10  PlayerB_2019-09-11  \
# p_throws                            0.287138           -0.185210
# prop_events_nback                   0.485921            0.452957
# prop_events_sum_nback_pt           -0.142086           -0.618789
# WAR                                 0.055079            0.078148
# FIP                                -0.315983            0.073807
# K/9                                -0.067129            0.374282
# BB/9                                0.117162           -0.054394
# H/9                                 0.049232            0.182032
# HR/9                                0.421483            0.420517
#
#                           PlayerB_2019-09-12  PlayerB_2019-09-16  \
# p_throws                            0.287866            0.015106
# prop_events_nback                   0.733203            0.439415
# prop_events_sum_nback_pt           -0.659062           -0.752922
# WAR                                -0.239467            0.404773
# FIP                                -0.319783            0.025203
# K/9                                 0.079845           -0.268374
# BB/9                               -0.024788            0.200826
# H/9                                -0.332886            0.349079
# HR/9                                0.270006           -0.151032
#
#                           PlayerB_2019-09-18  PlayerB_2019-09-21
# p_throws                           -0.192725           -0.470792
# prop_events_nback                   0.473013            0.383133
# prop_events_sum_nback_pt           -0.210487           -0.100198
# WAR                                -0.065695           -0.232203
# FIP                                -0.135779           -0.135380
# K/9                                -0.054018           -0.016823
# BB/9                               -0.094247            0.192903
# H/9                                 0.002710           -0.118870
# HR/9                                0.233086           -0.081885
#
# [9 rows x 31 columns]

# %%
df_sc_events_b2_test1["p_throws"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1273-9bb947fb6a95> in <module>
# ----> 1 df_sc_events_b2_test1["p_throws"]
#
# NameError: name 'df_sc_events_b2_test1' is not defined

# %% [markdown]
# # Game condition features
#
# - add simple home and away
